# %%
# 导入必要的库
import torch
import torch.nn as nn
import numpy as np
import torch.optim as optim
from torchvision import transforms, datasets, models, utils
from torchsummary import summary # 可视化训练过程
from torch.utils.data import DataLoader
import time
import matplotlib.pyplot as plt
import os
import seaborn as sns
import pandas as pd
from mlxtend.plotting import plot_confusion_matrix
from sklearn.metrics import confusion_matrix
from PIL import Image

# %%
# 分为为train, val, test定义transform
image_transforms = {
    'train' : transforms.Compose([
        transforms.RandomResizedCrop(size=300, scale=(0.8, 1.1)), #功能：随机长宽比裁剪原始图片, 表示随机crop出来的图片会在的0.08倍至1.1倍之间
        transforms.RandomRotation(degrees=10), #功能：根据degrees随机旋转一定角度, 则表示在（-10，+10）度之间随机旋转
        transforms.ColorJitter(0.4, 0.4, 0.4), #功能：修改亮度、对比度和饱和度
        transforms.RandomHorizontalFlip(), #功能：水平翻转
        transforms.CenterCrop(size=256), #功能：根据给定的size从中心裁剪，size - 若为sequence,则为(h,w)，若为int，则(size,size)
        transforms.ToTensor(), #numpy --> tensor
        # 功能：对数据按通道进行标准化（RGB），即先减均值，再除以标准差
        transforms.Normalize([0.485, 0.456, 0.406],# mean
                             [0.229, 0.224, 0.225])# std 
    ]),
    
    'val' : transforms.Compose([
        transforms.Resize(300),
        transforms.CenterCrop(256),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406],# mean
                             [0.229, 0.224, 0.225])# std 
    ]),
    
    'test' : transforms.Compose([
        transforms.Resize(300),
        transforms.CenterCrop(256),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406],# mean
                             [0.229, 0.224, 0.225])# std 
    ])
}

# %%
# 加载数据集

# 数据集所在目录路径
data_dir = 'normalViralANDbacCovid/'
# train路径
train_dir = data_dir + 'train/'
# val路径
val_dir = data_dir + 'val/'
# test路径
test_dir = data_dir + 'test/'

# 从文件中读取数据
datasets = {
    'train' : datasets.ImageFolder(train_dir, transform=image_transforms['train']), # 读取train中的数据集，并transform
    'val' : datasets.ImageFolder(val_dir, transform=image_transforms['val']),  # 读取val中的数据集，并transform
    'test' : datasets.ImageFolder(test_dir, transform=image_transforms['test']) #  读取test中的数据集，并transform
}

# 定义BATCH_SIZE
BATCH_SIZE = 128 # 每批读取128张图片

# DataLoader : 创建iterator, 按批读取数据
dataloaders = {
    'train' : DataLoader(datasets['train'], batch_size=BATCH_SIZE, shuffle=True), # 训练集
    'val' : DataLoader(datasets['val'], batch_size=BATCH_SIZE, shuffle=True), # 验证集
    'test' : DataLoader(datasets['test'], batch_size=BATCH_SIZE, shuffle=True) # 测试集
}

# 创建label的键值对
LABEL = dict((v, k) for k, v in datasets['train'].class_to_idx.items())

LABEL
# Out:
# {0: 'bacCovid', 1: 'normalViral'}

# %%
# train 简介
dataloaders['train'].dataset
# Out:
# Dataset ImageFolder
#     Number of datapoints: 12535
#     Root location: normalViralANDbacCovid/train/
#     StandardTransform
# Transform: Compose(
#                RandomResizedCrop(size=(300, 300), scale=(0.8, 1.1), ratio=(0.75, 1.3333), interpolation=bilinear)
#                RandomRotation(degrees=[-10.0, 10.0], interpolation=nearest, expand=False, fill=0)
#                ColorJitter(brightness=[0.6, 1.4], contrast=[0.6, 1.4], saturation=[0.6, 1.4], hue=None)
#                RandomHorizontalFlip(p=0.5)
#                CenterCrop(size=(256, 256))
#                ToTensor()
#                Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
#            )

# %%
dataloaders['train'].dataset.classes # train下的类别
# Out:
# ['bacCovid', 'normalViral']

# %%
dataloaders['train'].dataset.root # train的路径
# Out:
# 'normalViralANDbacCovid/train/'

# %%
# 肺部细菌感染的图片
files_bacCovid_pneumonia = os.listdir(os.path.join(str(dataloaders['train'].dataset.root), 'bacCovid'))
files_bacCovid_pneumonia
# Out:
# ['Bacteria (3112).jpeg',
#  'Bacteria (513).jpeg',
#  'Bacteria (1839).jpeg',
#  'Covid19 (2235).png',
#  'Bacteria (2569).jpeg',
#  'Bacteria (2097).jpeg',
#  'Covid19 (316).jpg',
#  'Covid19 (272).jpg',
#  'Covid19 (2351).png',
#  'Covid19 (2199).png',
#  'Covid19 (1392).png',
#  'Bacteria (2594).jpeg',
#  'Covid19 (328).png',
#  'Bacteria (56).jpeg',
#  'Bacteria (334).jpeg',
#  'Bacteria (637).jpeg',
#  'Covid19 (94).jpg',
#  'Bacteria (1418).jpeg',
#  'Bacteria (2948).jpeg',
#  'Covid19 (195).jpg',
#  'Covid19 (207).png',
#  'Covid19 (363).png',
#  'Covid19 (1075).png',
#  'Covid19 (1111).png',
#  'Bacteria (932).jpeg',
#  'Covid19 (239).jpg',
#  'Covid19 (1831).png',
#  'Bacteria (2321).jpeg',
#  'Covid19 (1955).png',
#  'Covid19 (593).png',
#  'Covid19 (1529).png',
#  'Bacteria (2622).jpeg',
#  'Covid19 (1685).png',
#  'Bacteria (1174).jpeg',
#  'Bacteria (39).jpeg',
#  'Bacteria (658).jpeg',
#  'Bacteria (1477).jpeg',
#  'Bacteria (1189).jpeg',
#  'Bacteria (2927).jpeg',
#  'Bacteria (1856).jpeg',
#  'Covid19 (674).png',
#  'Bacteria (2506).jpeg',
#  'Covid19 (710).png',
#  'Covid19 (1406).png',
#  'Covid19 (1562).png',
#  'Bacteria (2005).jpeg',
#  'Bacteria (1753).jpeg',
#  'Bacteria (1250).jpeg',
#  'Bacteria (581).jpeg',
#  'Bacteria (3180).jpeg',
#  'Bacteria (258).jpeg',
#  'Bacteria (1589).jpeg',
#  'Bacteria (1077).jpeg',
#  'Bacteria (2824).jpeg',
#  'Bacteria (1574).jpeg',
#  'Covid19 (1743).png',
#  'Bacteria (2222).jpeg',
#  'Covid19 (2548).png',
#  'Covid19 (1627).png',
#  'Covid19 (531).png',
#  'Covid19 (1893).png',
#  'Covid19 (829).png',
#  'Covid19 (455).png',
#  'Bacteria (2721).jpeg',
#  'Bacteria (1650).jpeg',
#  'Bacteria (181).jpeg',
#  'Bacteria (482).jpeg',
#  'Bacteria (3083).jpeg',
#  'Bacteria (1353).jpeg',
#  'Covid19 (906).png',
#  'Covid19 (862).png',
#  'Bacteria (2405).jpeg',
#  'Bacteria (1955).jpeg',
#  'Bacteria (2106).jpeg',
#  'Covid19 (1708).png',
#  'Covid19 (2503).png',
#  'Covid19 (420).jpg',
#  'Covid19 (2467).png',
#  'Covid19 (1330).png',
#  'Bacteria (2194).jpeg',
#  'Covid19 (1254).png',
#  'Bacteria (2497).jpeg',
#  'Bacteria (2169).jpeg',
#  'Covid19 (142).png',
#  'Covid19 (2297).png',
#  'Covid19 (43).png',
#  'Bacteria (3011).jpeg',
#  'Bacteria (410).jpeg',
#  'Bacteria (113).jpeg',
#  'Covid19 (109).png',
#  'Covid19 (2170).png',
#  'Covid19 (51).jpeg',
#  'Bacteria (831).jpeg',
#  'Covid19 (137).jpg',
#  'Covid19 (2014).png',
#  'Bacteria (237).jpeg',
#  'Bacteria (1018).jpeg',
#  'Covid19 (36).jpg',
#  'Bacteria (734).jpeg',
#  'Bacteria (18).jpeg',
#  'Bacteria (1155).jpeg',
#  'Bacteria (684).jpeg',
#  'Bacteria (387).jpeg',
#  'Bacteria (679).jpeg',
#  'Bacteria (2906).jpeg',
#  'Bacteria (1456).jpeg',
#  'Covid19 (2456).png',
#  'Bacteria (981).jpeg',
#  'Covid19 (783).png',
#  'Covid19 (1739).png',
#  'Bacteria (2300).jpeg',
#  'Covid19 (411).jpg',
#  'Covid19 (2532).png',
#  'Covid19 (853).png',
#  'Bacteria (2603).jpeg',
#  'Covid19 (1495).png',
#  'Covid19 (937).png',
#  'Bacteria (1772).jpeg',
#  'Bacteria (1271).jpeg',
#  'Bacteria (2527).jpeg',
#  'Covid19 (818).png',
#  'Bacteria (1877).jpeg',
#  'Covid19 (464).png',
#  'Covid19 (500).png',
#  'Covid19 (1616).png',
#  'Covid19 (1772).png',
#  'Bacteria (2024).jpeg',
#  'Covid19 (2579).png',
#  'Covid19 (2025).png',
#  'Bacteria (2548).jpeg',
#  'Covid19 (106).jpg',
#  'Covid19 (294).png',
#  'Bacteria (1818).jpeg',
#  'Covid19 (2141).png',
#  'Covid19 (1182).png',
#  'Covid19 (138).png',
#  'Covid19 (2389).png',
#  'Bacteria (532).jpeg',
#  'Bacteria (3133).jpeg',
#  'Covid19 (39).png',
#  'Covid19 (385).jpg',
#  'Covid19 (173).png',
#  'Bacteria (2691).jpeg',
#  'Bacteria (2392).jpeg',
#  'Covid19 (1265).png',
#  'Covid19 (1301).png',
#  'Bacteria (913).jpeg',
#  'Bacteria (2994).jpeg',
#  'Bacteria (77).jpeg',
#  'Bacteria (315).jpeg',
#  'Bacteria (616).jpeg',
#  'Bacteria (2969).jpeg',
#  'Bacteria (1439).jpeg',
#  'Covid19 (72).png',
#  'Bacteria (431).jpeg',
#  'Bacteria (3030).jpeg',
#  'Bacteria (132).jpeg',
#  'Covid19 (1120).png',
#  'Covid19 (208).jpg',
#  'Covid19 (1044).png',
#  'Bacteria (2148).jpeg',
#  'Covid19 (352).png',
#  'Covid19 (2087).png',
#  'Covid19 (236).png',
#  'Bacteria (216).jpeg',
#  'Bacteria (1039).jpeg',
#  'Bacteria (2897).jpeg',
#  'Bacteria (715).jpeg',
#  'Bacteria (2792).jpeg',
#  'Covid19 (319).png',
#  'Bacteria (810).jpeg',
#  'Covid19 (2360).png',
#  'Covid19 (243).jpg',
#  'Bacteria (2291).jpeg',
#  'Covid19 (327).jpg',
#  'Covid19 (2204).png',
#  'Covid19 (995).png',
#  'Bacteria (2203).jpeg',
#  'Covid19 (1553).png',
#  'Bacteria (882).jpeg',
#  'Covid19 (1437).png',
#  'Covid19 (721).png',
#  'Covid19 (2590).png',
#  'Covid19 (645).png',
#  'Bacteria (2700).jpeg',
#  'Bacteria (279).jpeg',
#  'Bacteria (787).jpeg',
#  'Bacteria (1056).jpeg',
#  'Bacteria (1555).jpeg',
#  'Bacteria (2805).jpeg',
#  'Bacteria (284).jpeg',
#  'Bacteria (1974).jpeg',
#  'Bacteria (2424).jpeg',
#  'Bacteria (1989).jpeg',
#  'Covid19 (1964).png',
#  'Bacteria (2127).jpeg',
#  'Covid19 (1518).png',
#  'Covid19 (1800).png',
#  'Bacteria (1671).jpeg',
#  'Covid19 (3).jpg',
#  'Bacteria (1372).jpeg',
#  'Covid19 (65).jpg',
#  'Bacteria (1612).jpeg',
#  'Bacteria (1311).jpeg',
#  'Bacteria (2447).jpeg',
#  'Bacteria (1917).jpeg',
#  'Covid19 (1084).png',
#  'Covid19 (2047).png',
#  'Covid19 (164).jpg',
#  'Covid19 (392).png',
#  'Covid19 (1328).png',
#  'Bacteria (2144).jpeg',
#  'Covid19 (2123).png',
#  'Bacteria (1035).jpeg',
#  'Covid19 (10).png',
#  'Bacteria (719).jpeg',
#  'Bacteria (2866).jpeg',
#  'Bacteria (1536).jpeg',
#  'Covid19 (1207).png',
#  'Covid19 (1363).png',
#  'Covid19 (2168).png',
#  'Bacteria (2260).jpeg',
#  'Bacteria (2763).jpeg',
#  'Covid19 (283).jpg',
#  'Covid19 (111).png',
#  'Covid19 (831).png',
#  'Covid19 (1593).png',
#  'Covid19 (529).png',
#  'Covid19 (955).png',
#  'Covid19 (2434).png',
#  'Covid19 (685).png',
#  'Covid19 (2550).png',
#  'Bacteria (873).jpeg',
#  'Covid19 (13).jpeg',
#  'Bacteria (275).jpeg',
#  'Bacteria (288).jpeg',
#  'Bacteria (776).jpeg',
#  'Bacteria (2809).jpeg',
#  'Bacteria (1559).jpeg',
#  'Bacteria (2428).jpeg',
#  'Covid19 (1674).png',
#  'Bacteria (1978).jpeg',
#  'Covid19 (438).jpg',
#  'Covid19 (1710).png',
#  'Covid19 (406).png',
#  'Covid19 (562).png',
#  'Bacteria (1985).jpeg',
#  'Bacteria (3053).jpeg',
#  'Bacteria (452).jpeg',
#  'Bacteria (1383).jpeg',
#  'Bacteria (1680).jpeg',
#  'Bacteria (151).jpeg',
#  'Bacteria (376).jpeg',
#  'Bacteria (688).jpeg',
#  'Bacteria (1159).jpeg',
#  'Bacteria (14).jpeg',
#  'Bacteria (675).jpeg',
#  'Covid19 (743).png',
#  'Covid19 (2496).png',
#  'Covid19 (627).png',
#  'Covid19 (1531).png',
#  'Bacteria (970).jpeg',
#  'Covid19 (1455).png',
#  'Covid19 (893).png',
#  'Covid19 (1829).png',
#  'Bacteria (1280).jpeg',
#  'Bacteria (3150).jpeg',
#  'Bacteria (551).jpeg',
#  'Bacteria (1783).jpeg',
#  'Covid19 (1906).png',
#  'Covid19 (1862).png',
#  'Bacteria (1886).jpeg',
#  'Covid19 (708).png',
#  'Bacteria (2028).jpeg',
#  'Covid19 (330).png',
#  'Covid19 (2181).png',
#  'Covid19 (254).png',
#  'Bacteria (1814).jpeg',
#  'Bacteria (2544).jpeg',
#  'Covid19 (2349).png',
#  'Bacteria (2047).jpeg',
#  'Covid19 (1142).png',
#  'Covid19 (1026).png',
#  'Bacteria (1711).jpeg',
#  'Bacteria (1212).jpeg',
#  'Covid19 (2302).png',
#  'Bacteria (2363).jpeg',
#  'Covid19 (221).jpg',
#  'Covid19 (1109).png',
#  'Covid19 (345).jpg',
#  'Covid19 (2266).png',
#  'Bacteria (2660).jpeg',
#  'Bacteria (319).jpeg',
#  'Bacteria (1136).jpeg',
#  'Bacteria (2998).jpeg',
#  'Bacteria (1435).jpeg',
#  'Bacteria (2965).jpeg',
#  'Bacteria (86).jpeg',
#  'Bacteria (1585).jpeg',
#  'Bacteria (254).jpeg',
#  'Bacteria (757).jpeg',
#  'Bacteria (1578).jpeg',
#  'Bacteria (1086).jpeg',
#  'Bacteria (2828).jpeg',
#  'Covid19 (2588).png',
#  'Covid19 (1783).png',
#  'Covid19 (739).png',
#  'Covid19 (495).png',
#  'Covid19 (1853).png',
#  'Bacteria (852).jpeg',
#  'Covid19 (32).jpeg',
#  'Covid19 (1937).png',
#  'Bacteria (473).jpeg',
#  'Bacteria (3072).jpeg',
#  'Bacteria (170).jpeg',
#  'Covid19 (1464).png',
#  'Bacteria (1959).jpeg',
#  'Covid19 (1818).png',
#  'Bacteria (2409).jpeg',
#  'Covid19 (1500).png',
#  'Covid19 (616).png',
#  'Covid19 (772).png',
#  'Bacteria (1936).jpeg',
#  'Covid19 (1294).png',
#  'Bacteria (2466).jpeg',
#  'Bacteria (2198).jpeg',
#  'Covid19 (2257).png',
#  'Covid19 (374).jpg',
#  'Covid19 (210).jpg',
#  'Covid19 (2333).png',
#  'Covid19 (182).png',
#  'Covid19 (1138).png',
#  'Bacteria (2165).jpeg',
#  'Covid19 (83).png',
#  'Bacteria (1633).jpeg',
#  'Bacteria (1330).jpeg',
#  'Covid19 (1017).png',
#  'Covid19 (2378).png',
#  'Bacteria (2241).jpeg',
#  'Covid19 (1173).png',
#  'Bacteria (2742).jpeg',
#  'Covid19 (265).png',
#  'Covid19 (301).png',
#  'Bacteria (1014).jpeg',
#  'Bacteria (738).jpeg',
#  'Bacteria (1517).jpeg',
#  'Bacteria (2847).jpeg',
#  'Bacteria (1730).jpeg',
#  'Covid19 (21).png',
#  'Bacteria (1233).jpeg',
#  'Covid19 (2391).png',
#  'Covid19 (120).png',
#  'Bacteria (2565).jpeg',
#  'Bacteria (1835).jpeg',
#  'Bacteria (2598).jpeg',
#  'Bacteria (2066).jpeg',
#  'Covid19 (1352).png',
#  'Covid19 (2159).png',
#  'Covid19 (1236).png',
#  'Bacteria (338).jpeg',
#  'Bacteria (1117).jpeg',
#  'Bacteria (2944).jpeg',
#  'Bacteria (1414).jpeg',
#  'Covid19 (54).jpg',
#  'Covid19 (1319).png',
#  'Covid19 (2112).png',
#  'Bacteria (2342).jpeg',
#  'Covid19 (155).jpg',
#  'Covid19 (2076).png',
#  'Bacteria (2641).jpeg',
#  'Covid19 (553).png',
#  'Covid19 (1995).png',
#  'Covid19 (437).png',
#  'Covid19 (409).jpg',
#  'Covid19 (1721).png',
#  'Bacteria (951).jpeg',
#  'Covid19 (1645).png',
#  'Bacteria (357).jpeg',
#  'Bacteria (35).jpeg',
#  'Bacteria (1486).jpeg',
#  'Bacteria (1178).jpeg',
#  'Bacteria (1185).jpeg',
#  'Bacteria (654).jpeg',
#  'Covid19 (2561).png',
#  'Covid19 (442).jpg',
#  'Covid19 (2405).png',
#  'Covid19 (518).png',
#  'Bacteria (2009).jpeg',
#  'Covid19 (964).png',
#  'Covid19 (800).png',
#  'Bacteria (570).jpeg',
#  'Bacteria (3171).jpeg',
#  'Covid19 (460).png',
#  'Bacteria (1861).jpeg',
#  'Covid19 (504).png',
#  'Bacteria (2531).jpeg',
#  'Covid19 (978).png',
#  'Covid19 (2419).png',
#  'Bacteria (2032).jpeg',
#  'Covid19 (1612).png',
#  'Covid19 (1776).png',
#  'Bacteria (1764).jpeg',
#  'Bacteria (1267).jpeg',
#  'Bacteria (1799).jpeg',
#  'Covid19 (2452).png',
#  'Bacteria (2316).jpeg',
#  'Covid19 (1659).png',
#  'Covid19 (415).jpg',
#  'Bacteria (997).jpeg',
#  'Covid19 (2536).png',
#  'Covid19 (787).png',
#  'Covid19 (1491).png',
#  'Covid19 (857).png',
#  'Bacteria (2615).jpeg',
#  'Covid19 (933).png',
#  'Covid19 (1989).png',
#  'Bacteria (692).jpeg',
#  'Bacteria (1143).jpeg',
#  'Bacteria (1440).jpeg',
#  'Bacteria (2910).jpeg',
#  'Bacteria (391).jpeg',
#  'Covid19 (48).jpg',
#  'Bacteria (303).jpeg',
#  'Bacteria (61).jpeg',
#  'Bacteria (2982).jpeg',
#  'Covid19 (76).png',
#  'Bacteria (600).jpeg',
#  'Covid19 (381).jpg',
#  'Bacteria (2379).jpeg',
#  'Bacteria (2687).jpeg',
#  'Covid19 (177).png',
#  'Covid19 (1261).png',
#  'Bacteria (905).jpeg',
#  'Covid19 (149).jpg',
#  'Bacteria (2384).jpeg',
#  'Covid19 (1305).png',
#  'Bacteria (524).jpeg',
#  'Bacteria (3125).jpeg',
#  'Bacteria (1208).jpeg',
#  'Covid19 (290).png',
#  'Covid19 (2021).png',
#  'Covid19 (102).jpg',
#  'Covid19 (2145).png',
#  'Covid19 (1186).png',
#  'Covid19 (279).png',
#  'Bacteria (2784).jpeg',
#  'Covid19 (2364).png',
#  'Covid19 (247).jpg',
#  'Bacteria (2287).jpeg',
#  'Bacteria (2779).jpeg',
#  'Covid19 (323).jpg',
#  'Covid19 (2200).png',
#  'Bacteria (806).jpeg',
#  'Bacteria (2881).jpeg',
#  'Bacteria (200).jpeg',
#  'Bacteria (703).jpeg',
#  'Covid19 (1124).png',
#  'Covid19 (368).jpg',
#  'Covid19 (1040).png',
#  'Covid19 (356).png',
#  'Covid19 (232).png',
#  'Covid19 (1288).png',
#  'Covid19 (2083).png',
#  'Bacteria (427).jpeg',
#  'Bacteria (3026).jpeg',
#  'Bacteria (1608).jpeg',
#  'Bacteria (124).jpeg',
#  'Bacteria (3049).jpeg',
#  'Bacteria (448).jpeg',
#  'Bacteria (1399).jpeg',
#  'Bacteria (1667).jpeg',
#  'Covid19 (7).jpg',
#  'Bacteria (1364).jpeg',
#  'Bacteria (2432).jpeg',
#  'Bacteria (1962).jpeg',
#  'Covid19 (1960).png',
#  'Bacteria (2131).jpeg',
#  'Covid19 (1478).png',
#  'Covid19 (1804).png',
#  'Bacteria (5).jpeg',
#  'Bacteria (1040).jpeg',
#  'Bacteria (791).jpeg',
#  'Bacteria (292).jpeg',
#  'Bacteria (2813).jpeg',
#  'Bacteria (1543).jpeg',
#  'Covid19 (1557).png',
#  'Bacteria (894).jpeg',
#  'Covid19 (991).png',
#  'Covid19 (1433).png',
#  'Covid19 (489).png',
#  'Bacteria (2215).jpeg',
#  'Covid19 (2594).png',
#  'Covid19 (725).png',
#  'Bacteria (2716).jpeg',
#  'Covid19 (641).png',
#  'Bacteria (869).jpeg',
#  'Covid19 (203).png',
#  'Covid19 (191).jpg',
#  'Bacteria (2358).jpeg',
#  'Covid19 (367).png',
#  'Covid19 (359).jpg',
#  'Covid19 (1071).png',
#  'Bacteria (924).jpeg',
#  'Covid19 (1115).png',
#  'Bacteria (322).jpeg',
#  'Bacteria (40).jpeg',
#  'Covid19 (90).jpg',
#  'Bacteria (621).jpeg',
#  'Covid19 (2231).png',
#  'Covid19 (312).jpg',
#  'Covid19 (276).jpg',
#  'Covid19 (2355).png',
#  'Bacteria (2081).jpeg',
#  'Bacteria (2582).jpeg',
#  'Covid19 (248).png',
#  'Covid19 (1396).png',
#  'Bacteria (3104).jpeg',
#  'Bacteria (505).jpeg',
#  'Bacteria (1229).jpeg',
#  'Bacteria (1745).jpeg',
#  'Bacteria (597).jpeg',
#  'Bacteria (1246).jpeg',
#  'Covid19 (670).png',
#  'Bacteria (2510).jpeg',
#  'Bacteria (1840).jpeg',
#  'Covid19 (714).png',
#  'Bacteria (2013).jpeg',
#  'Covid19 (1402).png',
#  'Covid19 (1566).png',
#  'Bacteria (1162).jpeg',
#  'Bacteria (2931).jpeg',
#  'Covid19 (8).png',
#  'Bacteria (1461).jpeg',
#  'Covid19 (1449).png',
#  'Bacteria (2337).jpeg',
#  'Covid19 (1835).png',
#  'Covid19 (597).png',
#  'Covid19 (1951).png',
#  'Covid19 (1681).png',
#  'Bacteria (2634).jpeg',
#  'Bacteria (1943).jpeg',
#  'Bacteria (2413).jpeg',
#  'Covid19 (902).png',
#  'Covid19 (866).png',
#  'Covid19 (2507).png',
#  'Covid19 (424).jpg',
#  'Covid19 (2463).png',
#  'Bacteria (2110).jpeg',
#  'Covid19 (1668).png',
#  'Bacteria (469).jpeg',
#  'Bacteria (197).jpeg',
#  'Bacteria (3068).jpeg',
#  'Bacteria (1646).jpeg',
#  'Bacteria (1345).jpeg',
#  'Bacteria (494).jpeg',
#  'Bacteria (3095).jpeg',
#  'Covid19 (1747).png',
#  'Bacteria (2234).jpeg',
#  'Covid19 (2428).png',
#  'Covid19 (1623).png',
#  'Covid19 (699).png',
#  'Covid19 (535).png',
#  'Bacteria (2737).jpeg',
#  'Covid19 (949).png',
#  'Bacteria (848).jpeg',
#  'Covid19 (451).png',
#  'Covid19 (28).jpeg',
#  'Covid19 (1897).png',
#  'Bacteria (1061).jpeg',
#  'Bacteria (1562).jpeg',
#  'Bacteria (2832).jpeg',
#  'Covid19 (32).jpg',
#  'Bacteria (221).jpeg',
#  'Bacteria (722).jpeg',
#  'Bacteria (2758).jpeg',
#  'Covid19 (2174).png',
#  'Bacteria (827).jpeg',
#  'Covid19 (47).jpeg',
#  'Covid19 (133).jpg',
#  'Covid19 (2010).png',
#  'Bacteria (3007).jpeg',
#  'Covid19 (47).png',
#  'Bacteria (406).jpeg',
#  'Bacteria (1629).jpeg',
#  'Bacteria (105).jpeg',
#  'Covid19 (79).jpg',
#  'Covid19 (1334).png',
#  'Bacteria (2182).jpeg',
#  'Covid19 (1250).png',
#  'Covid19 (178).jpg',
#  'Covid19 (146).png',
#  'Covid19 (2293).png',
#  'Bacteria (2481).jpeg',
#  'Covid19 (1098).png',
#  'Covid19 (1460).png',
#  'Covid19 (1978).png',
#  'Covid19 (1504).png',
#  'Covid19 (612).png',
#  'Covid19 (776).png',
#  'Bacteria (465).jpeg',
#  'Bacteria (3064).jpeg',
#  'Bacteria (498).jpeg',
#  'Bacteria (3099).jpeg',
#  'Bacteria (166).jpeg',
#  'Bacteria (1349).jpeg',
#  'Covid19 (659).png',
#  'Bacteria (2238).jpeg',
#  'Covid19 (1787).png',
#  'Covid19 (1857).png',
#  'Covid19 (24).jpeg',
#  'Covid19 (491).png',
#  'Bacteria (844).jpeg',
#  'Covid19 (1933).png',
#  'Covid19 (989).png',
#  'Bacteria (242).jpeg',
#  'Bacteria (1593).jpeg',
#  'Bacteria (1090).jpeg',
#  'Bacteria (741).jpeg',
#  'Bacteria (1002).jpeg',
#  'Bacteria (2851).jpeg',
#  'Bacteria (1501).jpeg',
#  'Covid19 (1013).png',
#  'Covid19 (2218).png',
#  'Bacteria (2257).jpeg',
#  'Covid19 (1177).png',
#  'Covid19 (261).png',
#  'Bacteria (2754).jpeg',
#  'Covid19 (305).png',
#  'Bacteria (1625).jpeg',
#  'Covid19 (87).png',
#  'Bacteria (109).jpeg',
#  'Bacteria (1326).jpeg',
#  'Covid19 (1290).png',
#  'Bacteria (2470).jpeg',
#  'Bacteria (1920).jpeg',
#  'Covid19 (1058).png',
#  'Bacteria (2173).jpeg',
#  'Covid19 (2253).png',
#  'Covid19 (370).jpg',
#  'Covid19 (186).png',
#  'Covid19 (214).jpg',
#  'Covid19 (2337).png',
#  'Covid19 (2116).png',
#  'Bacteria (2354).jpeg',
#  'Covid19 (151).jpg',
#  'Covid19 (2072).png',
#  'Covid19 (1279).png',
#  'Bacteria (2657).jpeg',
#  'Bacteria (928).jpeg',
#  'Covid19 (399).jpg',
#  'Bacteria (1101).jpeg',
#  'Bacteria (1402).jpeg',
#  'Covid19 (50).jpg',
#  'Bacteria (2952).jpeg',
#  'Covid19 (124).png',
#  'Bacteria (1823).jpeg',
#  'Covid19 (2395).png',
#  'Bacteria (2573).jpeg',
#  'Covid19 (1356).png',
#  'Covid19 (2039).png',
#  'Covid19 (1232).png',
#  'Bacteria (2070).jpeg',
#  'Covid19 (288).png',
#  'Bacteria (3108).jpeg',
#  'Bacteria (509).jpeg',
#  'Bacteria (1726).jpeg',
#  'Bacteria (1225).jpeg',
#  'Covid19 (25).png',
#  'Bacteria (566).jpeg',
#  'Bacteria (3167).jpeg',
#  'Bacteria (1749).jpeg',
#  'Covid19 (2565).png',
#  'Covid19 (446).jpg',
#  'Covid19 (2401).png',
#  'Covid19 (960).png',
#  'Covid19 (804).png',
#  'Covid19 (478).png',
#  'Bacteria (1490).jpeg',
#  'Bacteria (23).jpeg',
#  'Bacteria (341).jpeg',
#  'Bacteria (642).jpeg',
#  'Bacteria (1193).jpeg',
#  'Covid19 (1991).png',
#  'Covid19 (557).png',
#  'Covid19 (433).png',
#  'Covid19 (1489).png',
#  'Bacteria (2638).jpeg',
#  'Covid19 (1725).png',
#  'Covid19 (1641).png',
#  'Bacteria (947).jpeg',
#  'Covid19 (2008).png',
#  'Bacteria (2276).jpeg',
#  'Bacteria (2788).jpeg',
#  'Covid19 (1203).png',
#  'Covid19 (1367).png',
#  'Bacteria (2775).jpeg',
#  'Covid19 (115).png',
#  'Covid19 (287).jpg',
#  'Bacteria (1023).jpeg',
#  'Covid19 (14).png',
#  'Bacteria (1520).jpeg',
#  'Bacteria (2870).jpeg',
#  'Covid19 (1080).png',
#  'Bacteria (1901).jpeg',
#  'Bacteria (2451).jpeg',
#  'Covid19 (2043).png',
#  'Covid19 (160).jpg',
#  'Covid19 (1248).png',
#  'Bacteria (2152).jpeg',
#  'Covid19 (2127).png',
#  'Covid19 (396).png',
#  'Bacteria (1604).jpeg',
#  'Covid19 (61).jpg',
#  'Bacteria (128).jpeg',
#  'Bacteria (1307).jpeg',
#  'Bacteria (1395).jpeg',
#  'Bacteria (3045).jpeg',
#  'Bacteria (444).jpeg',
#  'Bacteria (147).jpeg',
#  'Bacteria (1368).jpeg',
#  'Bacteria (1696).jpeg',
#  'Covid19 (1670).png',
#  'Covid19 (1714).png',
#  'Bacteria (1993).jpeg',
#  'Covid19 (402).png',
#  'Covid19 (566).png',
#  'Bacteria (263).jpeg',
#  'Bacteria (9).jpeg',
#  'Bacteria (760).jpeg',
#  'Covid19 (835).png',
#  'Bacteria (2219).jpeg',
#  'Covid19 (449).png',
#  'Covid19 (951).png',
#  'Bacteria (898).jpeg',
#  'Covid19 (1597).png',
#  'Bacteria (865).jpeg',
#  'Covid19 (681).png',
#  'Covid19 (2430).png',
#  'Covid19 (2554).png',
#  'Covid19 (1902).png',
#  'Covid19 (1866).png',
#  'Covid19 (668).png',
#  'Bacteria (1890).jpeg',
#  'Bacteria (3146).jpeg',
#  'Bacteria (547).jpeg',
#  'Bacteria (1296).jpeg',
#  'Bacteria (1768).jpeg',
#  'Bacteria (1795).jpeg',
#  'Covid19 (747).png',
#  'Covid19 (623).png',
#  'Covid19 (1699).png',
#  'Covid19 (2492).png',
#  'Covid19 (1949).png',
#  'Bacteria (2619).jpeg',
#  'Covid19 (1535).png',
#  'Covid19 (897).png',
#  'Covid19 (1451).png',
#  'Bacteria (966).jpeg',
#  'Bacteria (360).jpeg',
#  'Bacteria (663).jpeg',
#  'Bacteria (1120).jpeg',
#  'Covid19 (88).jpg',
#  'Bacteria (90).jpeg',
#  'Bacteria (2973).jpeg',
#  'Bacteria (1423).jpeg',
#  'Covid19 (2306).png',
#  'Covid19 (225).jpg',
#  'Covid19 (1069).png',
#  'Bacteria (2375).jpeg',
#  'Covid19 (341).jpg',
#  'Covid19 (2262).png',
#  'Bacteria (2388).jpeg',
#  'Bacteria (2676).jpeg',
#  'Covid19 (189).jpg',
#  'Bacteria (909).jpeg',
#  'Bacteria (528).jpeg',
#  'Bacteria (3129).jpeg',
#  'Bacteria (1707).jpeg',
#  'Bacteria (1204).jpeg',
#  'Covid19 (2185).png',
#  'Bacteria (2552).jpeg',
#  'Covid19 (334).png',
#  'Bacteria (1802).jpeg',
#  'Covid19 (250).png',
#  'Covid19 (1146).png',
#  'Covid19 (1022).png',
#  'Bacteria (2051).jpeg',
#  'Covid19 (2229).png',
#  'Covid19 (430).jpg',
#  'Covid19 (2513).png',
#  'Covid19 (1718).png',
#  'Bacteria (2107).jpeg',
#  'Covid19 (2477).png',
#  'Covid19 (916).png',
#  'Bacteria (1954).jpeg',
#  'Bacteria (2404).jpeg',
#  'Covid19 (872).png',
#  'Bacteria (3082).jpeg',
#  'Bacteria (483).jpeg',
#  'Bacteria (1352).jpeg',
#  'Bacteria (1651).jpeg',
#  'Bacteria (180).jpeg',
#  'Covid19 (521).png',
#  'Bacteria (2720).jpeg',
#  'Covid19 (445).png',
#  'Covid19 (839).png',
#  'Covid19 (1883).png',
#  'Covid19 (2558).png',
#  'Bacteria (2223).jpeg',
#  'Covid19 (1753).png',
#  'Covid19 (1637).png',
#  'Bacteria (1575).jpeg',
#  'Bacteria (2825).jpeg',
#  'Bacteria (259).jpeg',
#  'Bacteria (1076).jpeg',
#  'Bacteria (1588).jpeg',
#  'Covid19 (18).png',
#  'Bacteria (735).jpeg',
#  'Bacteria (236).jpeg',
#  'Covid19 (26).jpg',
#  'Bacteria (1019).jpeg',
#  'Bacteria (830).jpeg',
#  'Covid19 (50).jpeg',
#  'Covid19 (2160).png',
#  'Covid19 (2004).png',
#  'Covid19 (127).jpg',
#  'Covid19 (119).png',
#  'Bacteria (112).jpeg',
#  'Covid19 (53).png',
#  'Bacteria (411).jpeg',
#  'Bacteria (3010).jpeg',
#  'Covid19 (152).png',
#  'Bacteria (2168).jpeg',
#  'Bacteria (2496).jpeg',
#  'Covid19 (2287).png',
#  'Covid19 (1320).png',
#  'Covid19 (1244).png',
#  'Bacteria (2195).jpeg',
#  'Covid19 (1065).png',
#  'Covid19 (229).jpg',
#  'Covid19 (1101).png',
#  'Bacteria (933).jpeg',
#  'Covid19 (217).png',
#  'Covid19 (185).jpg',
#  'Covid19 (373).png',
#  'Covid19 (84).jpg',
#  'Bacteria (636).jpeg',
#  'Bacteria (2949).jpeg',
#  'Bacteria (1419).jpeg',
#  'Bacteria (57).jpeg',
#  'Bacteria (335).jpeg',
#  'Covid19 (338).png',
#  'Bacteria (2595).jpeg',
#  'Covid19 (1382).png',
#  'Covid19 (2189).png',
#  'Covid19 (306).jpg',
#  'Bacteria (2096).jpeg',
#  'Bacteria (2568).jpeg',
#  'Covid19 (2225).png',
#  'Bacteria (1838).jpeg',
#  'Covid19 (2341).png',
#  'Covid19 (262).jpg',
#  'Bacteria (512).jpeg',
#  'Bacteria (3113).jpeg',
#  'Bacteria (1251).jpeg',
#  'Bacteria (580).jpeg',
#  'Bacteria (1752).jpeg',
#  'Covid19 (1416).png',
#  'Bacteria (2004).jpeg',
#  'Covid19 (1572).png',
#  'Bacteria (2507).jpeg',
#  'Covid19 (664).png',
#  'Bacteria (1857).jpeg',
#  'Covid19 (700).png',
#  'Bacteria (659).jpeg',
#  'Bacteria (2926).jpeg',
#  'Bacteria (1188).jpeg',
#  'Bacteria (1476).jpeg',
#  'Bacteria (38).jpeg',
#  'Bacteria (1175).jpeg',
#  'Covid19 (1695).png',
#  'Bacteria (2623).jpeg',
#  'Covid19 (1821).png',
#  'Covid19 (1539).png',
#  'Covid19 (583).png',
#  'Covid19 (1945).png',
#  'Bacteria (2320).jpeg',
#  'Covid19 (253).jpg',
#  'Covid19 (2370).png',
#  'Bacteria (811).jpeg',
#  'Covid19 (2214).png',
#  'Covid19 (337).jpg',
#  'Bacteria (2290).jpeg',
#  'Covid19 (309).png',
#  'Bacteria (2793).jpeg',
#  'Bacteria (714).jpeg',
#  'Bacteria (217).jpeg',
#  'Bacteria (2896).jpeg',
#  'Bacteria (1038).jpeg',
#  'Covid19 (342).png',
#  'Bacteria (2149).jpeg',
#  'Covid19 (226).png',
#  'Covid19 (2097).png',
#  'Covid19 (218).jpg',
#  'Covid19 (1130).png',
#  'Covid19 (1054).png',
#  'Bacteria (133).jpeg',
#  'Bacteria (3031).jpeg',
#  'Bacteria (430).jpeg',
#  'Bacteria (1373).jpeg',
#  'Bacteria (1670).jpeg',
#  'Covid19 (1508).png',
#  'Bacteria (2126).jpeg',
#  'Covid19 (1974).png',
#  'Bacteria (1988).jpeg',
#  'Covid19 (1810).png',
#  'Bacteria (2425).jpeg',
#  'Bacteria (1975).jpeg',
#  'Bacteria (2804).jpeg',
#  'Bacteria (1554).jpeg',
#  'Bacteria (285).jpeg',
#  'Bacteria (786).jpeg',
#  'Bacteria (278).jpeg',
#  'Bacteria (1057).jpeg',
#  'Covid19 (2580).png',
#  'Covid19 (731).png',
#  'Bacteria (2701).jpeg',
#  'Covid19 (655).png',
#  'Covid19 (1543).png',
#  'Bacteria (2202).jpeg',
#  'Covid19 (985).png',
#  'Covid19 (1427).png',
#  'Bacteria (883).jpeg',
#  'Covid19 (1606).png',
#  'Covid19 (2569).png',
#  'Bacteria (2025).jpeg',
#  'Covid19 (1762).png',
#  'Covid19 (474).png',
#  'Bacteria (1876).jpeg',
#  'Covid19 (808).png',
#  'Bacteria (2526).jpeg',
#  'Covid19 (510).png',
#  'Bacteria (1270).jpeg',
#  'Bacteria (1773).jpeg',
#  'Covid19 (1485).png',
#  'Bacteria (2602).jpeg',
#  'Covid19 (843).png',
#  'Covid19 (927).png',
#  'Bacteria (980).jpeg',
#  'Covid19 (2446).png',
#  'Covid19 (2522).png',
#  'Bacteria (2301).jpeg',
#  'Covid19 (401).jpg',
#  'Covid19 (1729).png',
#  'Covid19 (793).png',
#  'Bacteria (678).jpeg',
#  'Bacteria (386).jpeg',
#  'Bacteria (1457).jpeg',
#  'Bacteria (2907).jpeg',
#  'Bacteria (1154).jpeg',
#  'Bacteria (19).jpeg',
#  'Bacteria (685).jpeg',
#  'Bacteria (617).jpeg',
#  'Covid19 (62).png',
#  'Bacteria (1438).jpeg',
#  'Bacteria (2968).jpeg',
#  'Bacteria (76).jpeg',
#  'Bacteria (2995).jpeg',
#  'Bacteria (314).jpeg',
#  'Covid19 (1275).png',
#  'Bacteria (2393).jpeg',
#  'Covid19 (1311).png',
#  'Bacteria (912).jpeg',
#  'Covid19 (395).jpg',
#  'Bacteria (2690).jpeg',
#  'Covid19 (163).png',
#  'Covid19 (17).jpg',
#  'Bacteria (3132).jpeg',
#  'Bacteria (533).jpeg',
#  'Covid19 (29).png',
#  'Covid19 (2399).png',
#  'Covid19 (128).png',
#  'Covid19 (1192).png',
#  'Bacteria (1819).jpeg',
#  'Covid19 (284).png',
#  'Covid19 (116).jpg',
#  'Bacteria (2549).jpeg',
#  'Covid19 (2035).png',
#  'Covid19 (2151).png',
#  'Bacteria (2029).jpeg',
#  'Covid19 (718).png',
#  'Bacteria (1887).jpeg',
#  'Covid19 (1916).png',
#  'Covid19 (1872).png',
#  'Bacteria (1782).jpeg',
#  'Bacteria (1281).jpeg',
#  'Bacteria (550).jpeg',
#  'Bacteria (3151).jpeg',
#  'Covid19 (1521).png',
#  'Bacteria (971).jpeg',
#  ...]

# %%
# 肺部感染的图片
files_normalViral_pneumonia = os.listdir(os.path.join(str(dataloaders['train'].dataset.root), 'normalViral'))
files_normalViral_pneumonia
# Out:
# ['Viral (1205).png',
#  'Normal (121).png',
#  'Viral (458).jpeg',
#  'Normal (923).jpeg',
#  'Normal (82).jpeg',
#  'Viral (478).png',
#  'Viral (804).png',
#  'Viral (960).png',
#  'Normal (325).jpeg',
#  'Normal (1028).jpeg',
#  'Normal (626).jpeg',
#  'Normal (1618).png',
#  'Viral (1086).png',
#  'Viral (282).jpeg',
#  'Viral (40).png',
#  'Viral (781).jpeg',
#  'Viral (1738).jpeg',
#  'Normal (502).jpeg',
#  'Normal (1737).png',
#  'Normal (1653).png',
#  'Viral (879).jpeg',
#  'Viral (433).png',
#  'Viral (884).jpeg',
#  'Viral (557).png',
#  'Viral (816).jpeg',
#  'Normal (590).jpeg',
#  'Viral (1254).jpeg',
#  'Normal (552).png',
#  'Viral (713).jpeg',
#  'Normal (436).png',
#  'Viral (210).jpeg',
#  'Normal (1344).png',
#  'Viral (288).png',
#  'Normal (1220).png',
#  'Viral (1170).jpeg',
#  'Normal (1047).jpeg',
#  'Normal (649).jpeg',
#  'Viral (1473).jpeg',
#  'Viral (124).png',
#  'Normal (10).jpeg',
#  'Viral (134).jpeg',
#  'Normal (519).png',
#  'Viral (437).jpeg',
#  'Normal (965).png',
#  'Normal (801).png',
#  'Viral (610).jpeg',
#  'Normal (738).png',
#  'Normal (494).png',
#  'Viral (313).jpeg',
#  'Viral (305).png',
#  'Viral (915).jpeg',
#  'Normal (1260).jpeg',
#  'Viral (261).png',
#  'Normal (190).jpeg',
#  'Viral (1654).jpeg',
#  'Normal (1001).png',
#  'Viral (1357).jpeg',
#  'Normal (493).jpeg',
#  'Normal (1165).png',
#  'Normal (617).png',
#  'Viral (534).jpeg',
#  'Normal (773).png',
#  'Normal (249).jpeg',
#  'Viral (1073).jpeg',
#  'Viral (186).png',
#  'Normal (1282).png',
#  'Viral (1570).jpeg',
#  'Normal (1144).jpeg',
#  'Normal (226).jpeg',
#  'Viral (776).png',
#  'Viral (612).png',
#  'Normal (1472).png',
#  'Normal (725).jpeg',
#  'Normal (1516).png',
#  'Normal (820).jpeg',
#  'Normal (183).png',
#  'Normal (1439).png',
#  'Viral (989).png',
#  'Viral (24).jpeg',
#  'Viral (491).png',
#  'Normal (401).jpeg',
#  'Viral (1338).jpeg',
#  'Normal (102).jpeg',
#  'Viral (987).jpeg',
#  'Viral (659).png',
#  'Normal (1795).png',
#  'Viral (381).jpeg',
#  'Viral (1140).png',
#  'Normal (264).png',
#  'Viral (682).jpeg',
#  'Normal (300).png',
#  'Viral (1024).png',
#  'Viral (732).jpeg',
#  'Normal (742).png',
#  'Normal (626).png',
#  'Normal (97).png',
#  'Viral (231).jpeg',
#  'Normal (892).png',
#  'Viral (1288).jpeg',
#  'Viral (837).jpeg',
#  'Viral (1275).jpeg',
#  'Normal (31).jpeg',
#  'Normal (990).jpeg',
#  'Viral (115).jpeg',
#  'Viral (416).jpeg',
#  'Normal (709).png',
#  'Normal (1154).png',
#  'Viral (1151).jpeg',
#  'Normal (695).jpeg',
#  'Normal (1030).png',
#  'Normal (668).jpeg',
#  'Viral (250).png',
#  'Normal (396).jpeg',
#  'Viral (1452).jpeg',
#  'Normal (1066).jpeg',
#  'Viral (334).png',
#  'Viral (668).png',
#  'Normal (304).jpeg',
#  'Normal (607).jpeg',
#  'Normal (1009).jpeg',
#  'Normal (1408).png',
#  'Normal (331).png',
#  'Viral (1015).png',
#  'Viral (1171).png',
#  'Normal (255).png',
#  'Viral (484).jpeg',
#  'Viral (187).jpeg',
#  'Viral (479).jpeg',
#  'Normal (902).jpeg',
#  'Normal (1527).png',
#  'Viral (1719).jpeg',
#  'Viral (897).png',
#  'Normal (523).jpeg',
#  'Normal (1443).png',
#  'Viral (858).jpeg',
#  'Viral (623).png',
#  'Viral (747).png',
#  'Viral (1296).png',
#  'Viral (98).png',
#  'Viral (587).jpeg',
#  'Normal (801).jpeg',
#  'Normal (393).png',
#  'Viral (71).png',
#  'Viral (566).png',
#  'Normal (207).jpeg',
#  'Viral (402).png',
#  'Normal (1662).png',
#  'Normal (1706).png',
#  'Normal (704).jpeg',
#  'Viral (1198).png',
#  'Viral (1234).png',
#  'Normal (110).png',
#  'Normal (1629).png',
#  'Normal (420).jpeg',
#  'Viral (681).png',
#  'Viral (1319).jpeg',
#  'Normal (123).jpeg',
#  'Viral (951).png',
#  'Viral (449).png',
#  'Normal (1585).png',
#  'Viral (835).png',
#  'Viral (115).png',
#  'Viral (934).jpeg',
#  'Viral (1675).jpeg',
#  'Normal (1241).jpeg',
#  'Viral (1376).jpeg',
#  'Normal (1211).png',
#  'Viral (1688).jpeg',
#  'Viral (97).jpeg',
#  'Normal (1375).png',
#  'Normal (830).png',
#  'Viral (631).jpeg',
#  'Normal (528).png',
#  'Normal (954).png',
#  'Normal (35).png',
#  'Viral (332).jpeg',
#  'Normal (684).png',
#  'Viral (396).png',
#  'Normal (1198).jpeg',
#  'Normal (796).jpeg',
#  'Normal (268).jpeg',
#  'Viral (1052).jpeg',
#  'Normal (1092).png',
#  'Normal (1165).jpeg',
#  'Viral (1551).jpeg',
#  'Normal (295).jpeg',
#  'Normal (893).jpeg',
#  'Normal (407).png',
#  'Normal (563).png',
#  'Viral (5).jpeg',
#  'Viral (515).jpeg',
#  'Viral (576).jpeg',
#  'Viral (1077).png',
#  'Normal (353).png',
#  'Normal (237).png',
#  'Viral (1113).png',
#  'Viral (1031).jpeg',
#  'Normal (708).jpeg',
#  'Viral (1532).jpeg',
#  'Normal (1106).jpeg',
#  'Normal (318).png',
#  'Viral (652).jpeg',
#  'Viral (1158).png',
#  'Viral (351).jpeg',
#  'Viral (641).png',
#  'Normal (1222).jpeg',
#  'Viral (1616).jpeg',
#  'Viral (957).jpeg',
#  'Viral (725).png',
#  'Normal (1545).png',
#  'Viral (489).png',
#  'Viral (991).png',
#  'Normal (1421).png',
#  'Viral (1315).jpeg',
#  'Viral (66).jpeg',
#  'Viral (1387).jpeg',
#  'Viral (1679).jpeg',
#  'Normal (443).jpeg',
#  'Normal (1019).png',
#  'Viral (938).jpeg',
#  'Viral (279).png',
#  'Normal (140).jpeg',
#  'Viral (1684).jpeg',
#  'Normal (994).png',
#  'Normal (720).png',
#  'Normal (644).png',
#  'Viral (232).png',
#  'Normal (264).jpeg',
#  'Viral (356).png',
#  'Normal (1194).jpeg',
#  'Normal (767).jpeg',
#  'Normal (1136).png',
#  'Normal (299).jpeg',
#  'Normal (1169).jpeg',
#  'Normal (1052).png',
#  'Viral (519).jpeg',
#  'Viral (9).jpeg',
#  'Normal (862).jpeg',
#  'Normal (782).png',
#  'Normal (852).png',
#  'Normal (936).png',
#  'Normal (57).png',
#  'Normal (1273).png',
#  'Normal (540).jpeg',
#  'Viral (1284).jpeg',
#  'Normal (1317).png',
#  'Viral (1279).jpeg',
#  'Viral (177).png',
#  'Normal (819).png',
#  'Viral (119).jpeg',
#  'Normal (465).png',
#  'Normal (501).png',
#  'Normal (961).jpeg',
#  'Normal (1097).jpeg',
#  'Normal (699).jpeg',
#  'Normal (367).jpeg',
#  'Normal (1194).png',
#  'Normal (1238).png',
#  'Viral (290).png',
#  'Normal (664).jpeg',
#  'Normal (1600).png',
#  'Normal (308).jpeg',
#  'Viral (1132).jpeg',
#  'Normal (1764).png',
#  'Viral (978).png',
#  'Viral (504).png',
#  'Normal (1005).jpeg',
#  'Viral (1431).jpeg',
#  'Viral (460).png',
#  'Viral (176).jpeg',
#  'Viral (488).jpeg',
#  'Normal (295).png',
#  'Viral (13).png',
#  'Normal (52).jpeg',
#  'Normal (139).png',
#  'Viral (475).jpeg',
#  'Viral (933).png',
#  'Normal (1483).png',
#  'Viral (854).jpeg',
#  'Viral (857).png',
#  'Viral (1715).jpeg',
#  'Normal (1321).jpeg',
#  'Viral (787).png',
#  'Viral (1216).jpeg',
#  'Viral (1332).png',
#  'Normal (172).png',
#  'Viral (751).jpeg',
#  'Viral (1256).png',
#  'Viral (252).jpeg',
#  'Viral (58).png',
#  'Normal (530).png',
#  'Normal (828).png',
#  'Normal (454).png',
#  'Viral (1658).jpeg',
#  'Normal (462).jpeg',
#  'Viral (47).jpeg',
#  'Normal (1209).png',
#  'Viral (919).jpeg',
#  'Normal (161).jpeg',
#  'Normal (1291).jpeg',
#  'Normal (66).png',
#  'Normal (907).png',
#  'Normal (863).png',
#  'Viral (538).jpeg',
#  'Normal (843).jpeg',
#  'Viral (146).png',
#  'Viral (1581).jpeg',
#  'Normal (245).jpeg',
#  'Normal (1148).jpeg',
#  'Normal (1326).png',
#  'Normal (746).jpeg',
#  'Viral (1082).jpeg',
#  'Normal (1242).png',
#  'Viral (1010).jpeg',
#  'Viral (866).png',
#  'Normal (1127).jpeg',
#  'Normal (729).jpeg',
#  'Viral (1513).jpeg',
#  'Viral (902).png',
#  'Viral (69).png',
#  'Normal (143).png',
#  'Viral (1267).png',
#  'Viral (557).jpeg',
#  'Viral (1303).png',
#  'Viral (1637).jpeg',
#  'Viral (451).png',
#  'Viral (28).jpeg',
#  'Normal (1203).jpeg',
#  'Viral (949).png',
#  'Viral (976).jpeg',
#  'Viral (535).png',
#  'Normal (1755).png',
#  'Viral (699).png',
#  'Viral (1334).jpeg',
#  'Normal (1631).png',
#  'Normal (108).png',
#  'Viral (673).jpeg',
#  'Viral (22).png',
#  'Viral (370).jpeg',
#  'Viral (1180).png',
#  'Viral (157).jpeg',
#  'Normal (73).jpeg',
#  'Viral (1169).png',
#  'Viral (454).jpeg',
#  'Normal (329).png',
#  'Normal (329).jpeg',
#  'Viral (1113).jpeg',
#  'Normal (1410).png',
#  'Normal (1574).png',
#  'Viral (714).png',
#  'Viral (1410).jpeg',
#  'Viral (670).png',
#  'Normal (1024).jpeg',
#  'Normal (206).png',
#  'Viral (1122).png',
#  'Viral (80).png',
#  'Viral (1046).png',
#  'Viral (770).jpeg',
#  'Normal (362).png',
#  'Viral (273).jpeg',
#  'Normal (1693).png',
#  'Viral (875).jpeg',
#  'Normal (1300).jpeg',
#  'Viral (1734).jpeg',
#  'Viral (1237).jpeg',
#  'Viral (597).png',
#  'Viral (888).jpeg',
#  'Normal (1063).png',
#  'Normal (1107).png',
#  'Normal (561).jpeg',
#  'Viral (367).png',
#  'Viral (1258).jpeg',
#  'Viral (203).png',
#  'Normal (592).png',
#  'Normal (346).jpeg',
#  'Viral (1482).jpeg',
#  'Viral (248).png',
#  'Normal (1384).png',
#  'Normal (1028).png',
#  'Viral (1181).jpeg',
#  'Normal (645).jpeg',
#  'Viral (138).jpeg',
#  'Normal (675).png',
#  'Normal (711).png',
#  'Normal (940).jpeg',
#  'Normal (1150).png',
#  'Normal (683).jpeg',
#  'Viral (1147).jpeg',
#  'Normal (1034).png',
#  'Viral (254).png',
#  'Normal (1398).png',
#  'Normal (1070).jpeg',
#  'Viral (1444).jpeg',
#  'Viral (330).png',
#  'Normal (380).jpeg',
#  'Viral (103).jpeg',
#  'Normal (986).jpeg',
#  'Normal (27).jpeg',
#  'Normal (669).png',
#  'Viral (400).jpeg',
#  'Viral (821).jpeg',
#  'Viral (8).png',
#  'Viral (1263).jpeg',
#  'Normal (746).png',
#  'Viral (724).jpeg',
#  'Normal (622).png',
#  'Normal (93).png',
#  'Viral (227).jpeg',
#  'Normal (896).png',
#  'Viral (1292).png',
#  'Viral (248).jpeg',
#  'Viral (893).png',
#  'Normal (1523).png',
#  'Normal (535).jpeg',
#  'Normal (1447).png',
#  'Viral (627).png',
#  'Viral (743).png',
#  'Viral (492).jpeg',
#  'Viral (1011).png',
#  'Normal (335).png',
#  'Normal (251).png',
#  'Viral (1175).png',
#  'Normal (48).jpeg',
#  'Normal (914).jpeg',
#  'Viral (191).jpeg',
#  'Normal (312).jpeg',
#  'Viral (1128).jpeg',
#  'Viral (708).png',
#  'Normal (1568).png',
#  'Normal (611).jpeg',
#  'Viral (13).jpeg',
#  'Normal (1238).jpeg',
#  'Normal (436).jpeg',
#  'Normal (1749).png',
#  'Viral (685).png',
#  'Viral (955).png',
#  'Viral (529).png',
#  'Viral (831).png',
#  'Normal (135).jpeg',
#  'Normal (1581).png',
#  'Viral (648).jpeg',
#  'Normal (1).jpeg',
#  'Normal (114).png',
#  'Viral (1230).png',
#  'Viral (562).png',
#  'Normal (211).jpeg',
#  'Viral (406).png',
#  'Normal (712).jpeg',
#  'Normal (1666).png',
#  'Viral (1528).jpeg',
#  'Normal (1702).png',
#  'Viral (591).jpeg',
#  'Viral (75).png',
#  'Normal (397).png',
#  'Normal (817).jpeg',
#  'Normal (885).jpeg',
#  'Viral (503).jpeg',
#  'Normal (403).png',
#  'Normal (878).jpeg',
#  'Normal (567).png',
#  'Viral (392).png',
#  'Viral (1044).jpeg',
#  'Normal (780).jpeg',
#  'Normal (1096).png',
#  'Normal (283).jpeg',
#  'Viral (1547).jpeg',
#  'Normal (1173).jpeg',
#  'Normal (834).png',
#  'Normal (448).png',
#  'Viral (627).jpeg',
#  'Normal (950).png',
#  'Normal (31).png',
#  'Normal (680).png',
#  'Viral (324).jpeg',
#  'Viral (111).png',
#  'Normal (1257).jpeg',
#  'Viral (1663).jpeg',
#  'Normal (459).jpeg',
#  'Viral (922).jpeg',
#  'Normal (1215).png',
#  'Viral (81).jpeg',
#  'Viral (1360).jpeg',
#  'Normal (1371).png',
#  'Normal (1733).png',
#  'Normal (1657).png',
#  'Normal (514).jpeg',
#  'Viral (437).png',
#  'Viral (892).jpeg',
#  'Viral (553).png',
#  'Viral (44).png',
#  'Viral (1082).png',
#  'Viral (294).jpeg',
#  'Viral (797).jpeg',
#  'Viral (269).jpeg',
#  'Viral (800).png',
#  'Normal (333).jpeg',
#  'Viral (1109).jpeg',
#  'Viral (964).png',
#  'Viral (518).png',
#  'Normal (1778).png',
#  'Normal (630).jpeg',
#  'Normal (125).png',
#  'Viral (1201).png',
#  'Normal (69).jpeg',
#  'Normal (94).jpeg',
#  'Normal (935).jpeg',
#  'Normal (289).png',
#  'Viral (122).jpeg',
#  'Normal (961).png',
#  'Normal (805).png',
#  'Viral (421).jpeg',
#  'Normal (479).png',
#  'Viral (1498).jpeg',
#  'Viral (1166).jpeg',
#  'Normal (1340).png',
#  'Normal (1224).png',
#  'Normal (1188).png',
#  'Viral (1465).jpeg',
#  'Viral (120).png',
#  'Normal (1051).jpeg',
#  'Normal (556).png',
#  'Normal (432).png',
#  'Viral (705).jpeg',
#  'Viral (206).jpeg',
#  'Viral (800).jpeg',
#  'Viral (1741).jpeg',
#  'Viral (1242).jpeg',
#  'Normal (586).jpeg',
#  'Viral (182).png',
#  'Viral (1065).jpeg',
#  'Normal (1152).jpeg',
#  'Normal (1286).png',
#  'Viral (1566).jpeg',
#  'Viral (1098).jpeg',
#  'Normal (613).png',
#  'Viral (522).jpeg',
#  'Normal (777).png',
#  'Normal (859).jpeg',
#  'Viral (1642).jpeg',
#  'Normal (186).jpeg',
#  'Normal (478).jpeg',
#  'Viral (301).png',
#  'Normal (1276).jpeg',
#  'Viral (265).png',
#  'Viral (903).jpeg',
#  'Normal (1005).png',
#  'Normal (485).jpeg',
#  'Normal (1161).png',
#  'Viral (1341).jpeg',
#  'Normal (658).png',
#  'Viral (606).jpeg',
#  'Normal (490).png',
#  'Viral (305).jpeg',
#  'Normal (988).png',
#  'Viral (669).jpeg',
#  'Viral (397).jpeg',
#  'Normal (260).png',
#  'Viral (1144).png',
#  'Viral (694).jpeg',
#  'Viral (1020).png',
#  'Normal (304).png',
#  'Normal (417).jpeg',
#  'Viral (32).jpeg',
#  'Normal (1219).jpeg',
#  'Normal (1559).png',
#  'Viral (495).png',
#  'Viral (739).png',
#  'Viral (991).jpeg',
#  'Normal (114).jpeg',
#  'Normal (1791).png',
#  'Normal (836).jpeg',
#  'Normal (187).png',
#  'Viral (772).png',
#  'Normal (8).png',
#  'Viral (616).png',
#  'Normal (230).jpeg',
#  'Normal (1476).png',
#  'Normal (733).jpeg',
#  'Viral (1509).jpeg',
#  'Normal (1512).png',
#  'Normal (253).jpeg',
#  'Viral (1597).jpeg',
#  'Viral (1069).jpeg',
#  'Viral (142).png',
#  'Normal (1322).png',
#  'Viral (1094).jpeg',
#  'Normal (750).jpeg',
#  'Normal (1246).png',
#  'Normal (62).png',
#  'Normal (903).png',
#  'Normal (867).png',
#  'Normal (855).jpeg',
#  'Normal (1369).png',
#  'Viral (51).jpeg',
#  'Normal (474).jpeg',
#  'Normal (1287).jpeg',
#  'Normal (177).jpeg',
#  'Normal (489).jpeg',
#  'Viral (109).png',
#  'Normal (698).png',
#  'Normal (534).png',
#  'Normal (948).png',
#  'Viral (309).jpeg',
#  'Normal (29).png',
#  'Normal (450).png',
#  'Viral (1228).png',
#  'Viral (665).jpeg',
#  'Viral (26).png',
#  'Viral (698).jpeg',
#  'Viral (366).jpeg',
#  'Viral (1184).png',
#  'Viral (960).jpeg',
#  'Viral (455).png',
#  'Normal (1599).png',
#  'Viral (829).png',
#  'Normal (1215).jpeg',
#  'Viral (531).png',
#  'Viral (1621).jpeg',
#  'Viral (1322).jpeg',
#  'Normal (1751).png',
#  'Normal (118).jpeg',
#  'Normal (1635).png',
#  'Viral (1263).png',
#  'Normal (147).png',
#  'Viral (541).jpeg',
#  'Viral (1307).png',
#  'Viral (1006).jpeg',
#  'Viral (862).png',
#  'Viral (1505).jpeg',
#  'Viral (906).png',
#  'Normal (1131).jpeg',
#  'Viral (1722).jpeg',
#  'Normal (518).jpeg',
#  'Normal (1697).png',
#  'Normal (1316).jpeg',
#  'Viral (863).jpeg',
#  'Viral (593).png',
#  'Viral (1221).jpeg',
#  'Viral (766).jpeg',
#  'Viral (1126).png',
#  'Viral (298).jpeg',
#  'Normal (202).png',
#  'Normal (366).png',
#  'Viral (1042).png',
#  'Viral (84).png',
#  'Viral (265).jpeg',
#  'Normal (1414).png',
#  'Normal (1570).png',
#  'Viral (1105).jpeg',
#  'Normal (1032).jpeg',
#  'Viral (710).png',
#  'Viral (1406).jpeg',
#  'Viral (674).png',
#  'Normal (65).jpeg',
#  'Viral (141).jpeg',
#  'Normal (249).png',
#  'Viral (442).jpeg',
#  'Normal (939).jpeg',
#  'Viral (1009).png',
#  'Normal (98).jpeg',
#  'Normal (671).png',
#  'Normal (715).png',
#  'Normal (956).jpeg',
#  'Viral (328).png',
#  'Normal (1380).png',
#  'Viral (1494).jpeg',
#  'Normal (350).jpeg',
#  'Normal (653).jpeg',
#  'Viral (1469).jpeg',
#  'Viral (1197).jpeg',
#  'Normal (1148).png',
#  'Viral (709).jpeg',
#  'Normal (596).png',
#  'Normal (577).jpeg',
#  'Normal (1067).png',
#  'Normal (1103).png',
#  'Viral (363).png',
#  'Viral (207).png',
#  'Viral (941).jpeg',
#  'Viral (645).png',
#  'Normal (1789).png',
#  'Viral (1600).jpeg',
#  'Normal (1234).jpeg',
#  'Viral (721).png',
#  'Normal (1541).png',
#  'Viral (1303).jpeg',
#  'Normal (139).jpeg',
#  'Normal (1425).png',
#  'Viral (995).png',
#  'Viral (1038).png',
#  'Viral (644).jpeg',
#  'Normal (278).png',
#  'Viral (347).jpeg',
#  'Viral (1027).jpeg',
#  'Normal (1110).jpeg',
#  'Viral (1524).jpeg',
#  'Normal (357).png',
#  'Viral (1073).png',
#  'Viral (1117).png',
#  'Normal (233).png',
#  'Viral (560).jpeg',
#  'Normal (889).jpeg',
#  'Normal (874).jpeg',
#  'Viral (236).png',
#  'Normal (1182).jpeg',
#  'Normal (272).jpeg',
#  'Viral (1048).jpeg',
#  'Viral (352).png',
#  'Normal (1132).png',
#  'Normal (1056).png',
#  'Normal (771).jpeg',
#  'Normal (990).png',
#  'Normal (488).png',
#  'Viral (328).jpeg',
#  'Normal (724).png',
#  'Normal (640).png',
#  'Normal (1179).png',
#  'Normal (455).jpeg',
#  'Viral (1391).jpeg',
#  'Viral (70).jpeg',
#  'Viral (1692).jpeg',
#  'Normal (156).jpeg',
#  'Viral (319).png',
#  'Viral (138).png',
#  'Normal (371).jpeg',
#  'Normal (1190).png',
#  'Normal (1081).jpeg',
#  'Normal (672).jpeg',
#  'Viral (1448).jpeg',
#  'Normal (1358).png',
#  'Viral (294).png',
#  'Normal (461).png',
#  'Normal (505).png',
#  'Normal (18).png',
#  'Normal (979).png',
#  'Normal (977).jpeg',
#  'Normal (1277).png',
#  'Viral (1292).jpeg',
#  'Normal (556).jpeg',
#  'Normal (1313).png',
#  'Viral (173).png',
#  'Viral (728).jpeg',
#  'Normal (786).png',
#  'Normal (856).png',
#  'Normal (932).png',
#  'Normal (53).png',
#  'Viral (1336).png',
#  'Viral (747).jpeg',
#  'Viral (1252).png',
#  'Normal (176).png',
#  'Viral (244).jpeg',
#  'Normal (1487).png',
#  'Normal (1337).jpeg',
#  'Viral (1703).jpeg',
#  'Viral (937).png',
#  'Normal (539).jpeg',
#  'Viral (842).jpeg',
#  'Viral (853).png',
#  'Viral (783).png',
#  'Viral (1200).jpeg',
#  'Normal (44).jpeg',
#  'Normal (291).png',
#  'Viral (160).jpeg',
#  'Viral (17).png',
#  'Viral (463).jpeg',
#  'Normal (918).jpeg',
#  'Viral (1219).png',
#  'Normal (1604).png',
#  'Viral (1124).jpeg',
#  'Normal (1760).png',
#  'Viral (500).png',
#  'Viral (1427).jpeg',
#  'Normal (1013).jpeg',
#  'Viral (464).png',
#  'Viral (818).png',
#  'Normal (1292).png',
#  'Normal (1145).jpeg',
#  'Viral (1571).jpeg',
#  'Viral (196).png',
#  'Viral (1072).jpeg',
#  'Normal (248).jpeg',
#  'Normal (607).png',
#  'Normal (763).png',
#  'Viral (535).jpeg',
#  'Normal (492).jpeg',
#  'Viral (1356).jpeg',
#  'Normal (1011).png',
#  'Normal (1175).png',
#  'Viral (914).jpeg',
#  'Viral (315).png',
#  'Viral (1655).jpeg',
#  'Normal (191).jpeg',
#  'Viral (271).png',
#  'Normal (1261).jpeg',
#  'Viral (312).jpeg',
#  'Normal (484).png',
#  'Normal (728).png',
#  'Viral (611).jpeg',
#  'Viral (683).jpeg',
#  'Normal (274).png',
#  'Viral (1150).png',
#  'Viral (1034).png',
#  'Normal (310).png',
#  'Viral (380).jpeg',
#  'Normal (103).jpeg',
#  'Viral (1339).jpeg',
#  'Normal (1785).png',
#  'Viral (649).png',
#  'Viral (986).jpeg',
#  'Viral (999).png',
#  'Normal (1429).png',
#  'Normal (400).jpeg',
#  'Viral (481).png',
#  'Viral (25).jpeg',
#  'Normal (821).jpeg',
#  'Normal (193).png',
#  'Normal (1462).png',
#  'Normal (724).jpeg',
#  'Normal (1506).png',
#  'Viral (766).png',
#  'Normal (227).jpeg',
#  'Viral (602).png',
#  'Viral (885).jpeg',
#  'Viral (423).png',
#  'Viral (547).png',
#  'Normal (1727).png',
#  'Normal (503).jpeg',
#  'Viral (1739).jpeg',
#  'Viral (878).jpeg',
#  'Normal (1643).png',
#  'Viral (780).jpeg',
#  'Viral (50).png',
#  'Viral (283).jpeg',
#  'Viral (1096).png',
#  'Normal (627).jpeg',
#  'Normal (1029).jpeg',
#  'Normal (1608).png',
#  'Viral (814).png',
#  'Viral (468).png',
#  'Normal (324).jpeg',
#  'Viral (970).png',
#  'Viral (459).jpeg',
#  'Normal (83).jpeg',
#  'Normal (922).jpeg',
#  'Normal (131).png',
#  'Viral (1215).png',
#  'Normal (975).png',
#  'Viral (436).jpeg',
#  'Normal (14).png',
#  'Normal (509).png',
#  'Normal (811).png',
#  'Normal (11).jpeg',
#  'Viral (135).jpeg',
#  'Viral (1472).jpeg',
#  'Normal (648).jpeg',
#  'Normal (1046).jpeg',
#  'Viral (134).png',
#  'Viral (298).png',
#  'Normal (1354).png',
#  'Viral (1171).jpeg',
#  'Normal (1230).png',
#  'Viral (211).jpeg',
#  'Viral (712).jpeg',
#  'Normal (542).png',
#  'Normal (426).png',
#  'Viral (1255).jpeg',
#  'Normal (591).jpeg',
#  'Viral (817).jpeg',
#  'Viral (941).png',
#  'Normal (122).jpeg',
#  'Viral (1318).jpeg',
#  'Viral (825).png',
#  'Normal (1595).png',
#  'Viral (459).png',
#  'Normal (1639).png',
#  'Viral (691).png',
#  'Normal (421).jpeg',
#  'Viral (1340).png',
#  'Normal (100).png',
#  'Viral (1224).png',
#  'Viral (1188).png',
#  'Normal (1672).png',
#  'Normal (1716).png',
#  'Normal (705).jpeg',
#  'Normal (206).jpeg',
#  'Viral (576).png',
#  'Viral (412).png',
#  'Normal (800).jpeg',
#  'Viral (61).png',
#  'Normal (383).png',
#  'Viral (586).jpeg',
#  'Normal (417).png',
#  'Viral (514).jpeg',
#  'Viral (4).jpeg',
#  'Normal (573).png',
#  'Normal (892).jpeg',
#  'Normal (1082).png',
#  'Normal (294).jpeg',
#  'Viral (1550).jpeg',
#  'Normal (1164).jpeg',
#  'Viral (1053).jpeg',
#  'Normal (269).jpeg',
#  'Normal (797).jpeg',
#  'Normal (1199).jpeg',
#  'Viral (386).png',
#  'Normal (694).png',
#  'Viral (333).jpeg',
#  'Normal (820).png',
#  'Normal (25).png',
#  'Normal (944).png',
#  'Normal (538).png',
#  'Viral (630).jpeg',
#  'Viral (96).jpeg',
#  'Normal (1201).png',
#  'Viral (1689).jpeg',
#  'Viral (1377).jpeg',
#  'Normal (1365).png',
#  'Viral (935).jpeg',
#  'Viral (105).png',
#  'Normal (1240).jpeg',
#  'Viral (1674).jpeg',
#  'Normal (1067).jpeg',
#  'Viral (1453).jpeg',
#  'Normal (397).jpeg',
#  'Normal (669).jpeg',
#  'Viral (240).png',
#  'Viral (324).png',
#  'Normal (1144).png',
#  'Normal (1020).png',
#  'Normal (694).jpeg',
#  'Viral (1150).jpeg',
#  'Normal (719).png',
#  'Viral (417).jpeg',
#  'Normal (991).jpeg',
#  'Normal (30).jpeg',
#  'Viral (114).jpeg',
#  'Viral (1274).jpeg',
#  'Viral (1289).jpeg',
#  'Viral (836).jpeg',
#  'Normal (87).png',
#  'Normal (882).png',
#  'Viral (230).jpeg',
#  'Normal (752).png',
#  'Viral (733).jpeg',
#  'Normal (636).png',
#  'Viral (88).png',
#  'Viral (1286).png',
#  'Viral (633).png',
#  'Viral (757).png',
#  'Normal (522).jpeg',
#  'Viral (1718).jpeg',
#  'Viral (887).png',
#  'Normal (1537).png',
#  'Viral (859).jpeg',
#  'Normal (1453).png',
#  'Viral (478).jpeg',
#  'Viral (186).jpeg',
#  'Normal (903).jpeg',
#  'Viral (1005).png',
#  'Normal (321).png',
#  'Viral (485).jpeg',
#  'Normal (245).png',
#  'Viral (1161).png',
#  'Normal (1008).jpeg',
#  'Normal (606).jpeg',
#  'Normal (1418).png',
#  'Viral (678).png',
#  'Normal (305).jpeg',
#  'Normal (1228).png',
#  'Viral (280).png',
#  'Normal (665).jpeg',
#  'Normal (366).jpeg',
#  'Normal (698).jpeg',
#  'Normal (1096).jpeg',
#  'Normal (1184).png',
#  'Normal (960).jpeg',
#  'Normal (475).png',
#  'Viral (118).jpeg',
#  'Normal (809).png',
#  'Normal (511).png',
#  'Viral (167).png',
#  'Viral (1278).jpeg',
#  'Normal (1263).png',
#  'Normal (1307).png',
#  'Viral (1285).jpeg',
#  'Normal (541).jpeg',
#  'Normal (842).png',
#  'Normal (47).png',
#  'Normal (926).png',
#  'Normal (792).png',
#  'Viral (253).jpeg',
#  'Viral (48).png',
#  'Viral (1322).png',
#  'Viral (750).jpeg',
#  'Viral (1246).png',
#  'Normal (162).png',
#  'Viral (1217).jpeg',
#  'Viral (797).png',
#  'Viral (855).jpeg',
#  'Normal (1493).png',
#  ...]

# %%
# val 简介
dataloaders['val'].dataset
# Out:
# Dataset ImageFolder
#     Number of datapoints: 32
#     Root location: normalViralANDbacCovid/val/
#     StandardTransform
# Transform: Compose(
#                Resize(size=300, interpolation=bilinear, max_size=None, antialias=None)
#                CenterCrop(size=(256, 256))
#                ToTensor()
#                Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
#            )

# %%
# test 简介
dataloaders['test'].dataset
# Out:
# Dataset ImageFolder
#     Number of datapoints: 846
#     Root location: normalViralANDbacCovid/test/
#     StandardTransform
# Transform: Compose(
#                Resize(size=300, interpolation=bilinear, max_size=None, antialias=None)
#                CenterCrop(size=(256, 256))
#                ToTensor()
#                Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
#            )

# %% [markdown]
# ### 提示：需要安装库：tb-nightly
# ### pip3 install tb-nightly

# %%
# 导入SummaryWriter
from torch.utils.tensorboard import SummaryWriter
# SummaryWriter() 向事件文件写入事件和概要

# 定义日志路径
log_path = 'logdir2/'

# 定义函数：获取tensorboard writer
def tb_writer():
    timestr = time.strftime("%Y%m%d_%H%M%S") # 时间格式
    writer = SummaryWriter(log_path+timestr) # 写入日志
    return writer


writer = tb_writer()

# 第1种方法：显示部分图片集
images, labels = next(iter(dataloaders['train'])) # 获取到一批数据

# 定义图片显示方法
def imshow(img):
    img = img / 2 + 0.5 # 逆正则化
    np_img = img.numpy() # tensor --> numpy
    plt.imshow(np.transpose(np_img, (1, 2, 0))) # 改变通道顺序
    plt.show()
    
grid = utils.make_grid(images) # make_grid的作用是将若干幅图像拼成一幅图像
imshow(grid) # 展示图片

# 在summary中添加图片数据
writer.add_image('X-Ray grid', grid, 0) # add_image(tag, img_tensor, global_step=None, walltime=None, dataformats='CHW')

writer.flush() # 把事件文件写入到磁盘
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
# 获取一张图片tensor
dataloaders['train'].dataset[4] # 返回：tensor, label
# Out:
# (tensor([[[-0.6281, -0.5082, -0.4226,  ...,  0.3309,  0.3138,  0.2453],
#           [-0.6965, -0.6452, -0.6109,  ...,  0.3309,  0.3138,  0.1939],
#           [-0.6794, -0.6281, -0.6281,  ...,  0.2624,  0.1939,  0.2967],
#           ...,
#           [-1.7069, -1.7412, -1.7925,  ...,  1.6838,  1.5810,  1.5810],
#           [-1.7069, -1.7754, -1.8097,  ...,  1.6324,  1.6324,  1.6324],
#           [-1.7240, -1.7925, -1.8097,  ...,  1.6838,  1.6324,  1.6324]],
#
#          [[-0.5126, -0.3901, -0.3025,  ...,  0.4678,  0.4503,  0.3803],
#           [-0.5826, -0.5301, -0.4951,  ...,  0.4678,  0.4503,  0.3277],
#           [-0.5651, -0.5126, -0.5126,  ...,  0.3978,  0.3277,  0.4328],
#           ...,
#           [-1.6155, -1.6506, -1.7031,  ...,  1.8508,  1.7458,  1.7458],
#           [-1.6155, -1.6856, -1.7206,  ...,  1.7983,  1.7983,  1.7983],
#           [-1.6331, -1.7031, -1.7206,  ...,  1.8508,  1.7983,  1.7983]],
#
#          [[-0.2881, -0.1661, -0.0790,  ...,  0.6879,  0.6705,  0.6008],
#           [-0.3578, -0.3055, -0.2707,  ...,  0.6879,  0.6705,  0.5485],
#           [-0.3404, -0.2881, -0.2881,  ...,  0.6182,  0.5485,  0.6531],
#           ...,
#           [-1.3861, -1.4210, -1.4733,  ...,  2.0648,  1.9603,  1.9603],
#           [-1.3861, -1.4559, -1.4907,  ...,  2.0125,  2.0125,  2.0125],
#           [-1.4036, -1.4733, -1.4907,  ...,  2.0648,  2.0125,  2.0125]]]),
#  0)

# %%
# 第2种方法：显示一张图片
def show_sample(img, label):
    print("Label : ", dataloaders['train'].dataset.classes[label]) # 输出标签
    img = img.numpy().transpose((1, 2, 0)) # 改变shape顺序
    mean = np.array([0.485, 0.456, 0.406]) # 均值
    std = np.array([0.229, 0.224, 0.225]) # 标准差
    img = img * std + mean # 逆向复原
    img = np.clip(img, 0, 1) # np.clip() 将inp中的元素值限制在(0,1)之间，最小值为0，最大值为1。小于min的等于min，大于max等于max
    plt.imshow(img)
    plt.axis('off') # 关闭坐标轴

show_sample(*dataloaders['train'].dataset[4]) # 显示第5张图片
# Out:
# Label :  bacCovid

# %%
# 第3种方法：显示一张图片
def show_image(img):
    plt.figure(figsize=(8,8)) # 显示大小
    plt.imshow(img) # 显示图片
    plt.axis('off') # 关闭坐标轴
    plt.show()
    
# 读取图片
one_img = Image.open(dataloaders['train'].dataset.root+'bacCovid/bacteria (1001).jpeg')

# 调用函数
show_image(one_img)

# %%
# 记录错误分类的图片
def misclassified_images(pred, writer, target, images, output, epoch, count=10):
    misclassified = (pred != target.data) # 判断是否一致
    for index, image_tensor in enumerate(images[misclassified][:count]):
        img_name = 'Epoch:{}-->Predict:{}-->Actual:{}'.format(epoch, LABEL[pred[misclassified].tolist()[index]],
                                                              LABEL[target.data[misclassified].tolist()[index]])
        writer.add_image(img_name, image_tensor, epoch)

# %%
# 自定义池化层

class AdaptiveConcatPool2d(nn.Module):
    def __init__(self, size=None):
        super(AdaptiveConcatPool2d,self).__init__()
        size = size or (1, 1) # kernel大小
        # 自适应算法能够自动帮助我们计算核的大小和每次移动的步长。
        self.avgPooling = nn.AdaptiveAvgPool2d(size) # 自适应平均池化
        self.maxPooling = nn.AdaptiveMaxPool2d(size) # 最大池化
    def forward(self, x):
        # 拼接avg和max
        return torch.cat([self.maxPooling(x), self.avgPooling(x)], dim=1)

# %%
# 迁移学习：获取预训练模型，并替换池化层和全连接层
# def get_model():
#     # 获取欲训练模型 restnet50
#     model = models.resnet50(pretrained=True) 
#     # 冻结模型参数
#     for param in model.parameters():
#         param.requires_grad = False 
#     # 替换最后2层：池化层和全连接层
#     # 池化层
#     model.avgpool = AdaptiveConcatPool2d()
#     # 全连接层
#     model.fc = nn.Sequential(
#         nn.Flatten(), # 拉平
#         nn.BatchNorm1d(4096), # 加速神经网络的收敛过程，提高训练过程中的稳定性
#         nn.Dropout(0.5), # 丢掉部分神经元
#         nn.Linear(4096, 512), # 全连接层
#         nn.ReLU(), # 激活函数
#         nn.BatchNorm1d(512), 
#         nn.Dropout(0.5),
#         nn.Linear(512, 2), # 2个输出
#         nn.LogSoftmax(dim=1) # 损失函数：将input转换成概率分布的形式，输出2个概率
#     )
#     return model
# def get_model():
#     # 使用VGG-16预训练模型
#     model = models.vgg16(pretrained=True)
#     # 冻结模型参数
#     for param in model.parameters():
#         param.requires_grad = False
#     # 替换最后两层
#     model.avgpool = AdaptiveConcatPool2d()
#     model.classifier = nn.Sequential(
#         nn.Dropout(),
#         nn.Linear(2 * 512, 256),
#         nn.ReLU(inplace=True),
#         nn.Dropout(),
#         nn.Linear(256, 4),
#         nn.LogSoftmax(dim=1)
#     )
#     return model

def get_model():
    # 获取欲训练模型 restnet50
    model = models.resnet101(pretrained=True) 
    # 冻结模型参数
    for param in model.parameters():
        param.requires_grad = False 
    # 替换最后2层：池化层和全连接层
    # 池化层
    model.avgpool = AdaptiveConcatPool2d()
    # 全连接层
    model.fc = nn.Sequential(
        nn.Flatten(), # 拉平
        nn.BatchNorm1d(4096), # 加速神经网络的收敛过程，提高训练过程中的稳定性
        nn.Dropout(0.5), # 丢掉部分神经元
        nn.Linear(4096, 512), # 全连接层
        nn.ReLU(), # 激活函数
        nn.BatchNorm1d(512), 
        nn.Dropout(0.5),
        nn.Linear(512, 2), # 2个输出
        nn.LogSoftmax(dim=1) # 损失函数：将input转换成概率分布的形式，输出2个概率
    )
    return model

# %%
# 定义训练函数
def train_val(model, device, train_loader, val_loader, optimizer, criterion, epoch, writer):
    model.train()
    total_loss = 0.0
    val_loss = 0.0
    val_acc = 0
    for batch_id, (images, labels) in enumerate(train_loader):
        # 部署到device上
        images, labels = images.to(device), labels.to(device)
        # 梯度置0
        optimizer.zero_grad()
        # 模型输出
        outputs = model(images)
        # 计算损失
        loss = criterion(outputs, labels)
        # 反向传播
        loss.backward()
        # 更新参数
        optimizer.step()
        # 累计损失
        total_loss += loss.item() * images.size(0)
    # 平均训练损失
    train_loss = total_loss / len(train_loader.dataset)
    #写入到writer中
    writer.add_scalar('Training Loss', train_loss, epoch)
    # 写入到磁盘
    writer.flush()
    
    model.eval() 
    with torch.no_grad():
        for images, labels in val_loader:
            images, labels = images.to(device), labels.to(device)
            outputs = model(images) # 前向传播输出
            loss = criterion(outputs, labels) # 损失
            val_loss += loss.item() * images.size(0) # 累计损失
            _, pred = torch.max(outputs, dim=1) # 获取最大概率的索引
            correct = pred.eq(labels.view_as(pred)) # 返回：tensor([ True,False,True,...,False])
            accuracy = torch.mean(correct.type(torch.FloatTensor)) # 准确率
            val_acc += accuracy.item() * images.size(0) # 累计准确率
        # 平均验证损失
        val_loss = val_loss / len(val_loader.dataset)
        # 平均准确率
        val_acc = val_acc / len(val_loader.dataset)
        
    return train_loss, val_loss, val_acc

# %%
# 定义测试函数
def test(model, device, test_loader, criterion, epoch, writer):
    model.eval()
    total_loss = 0.0
    correct = 0.0 # 正确数
    with torch.no_grad():
        for batch_id, (images, labels) in enumerate(test_loader):
            images, labels = images.to(device), labels.to(device)
            # 输出
            outputs = model(images)
            # 损失
            loss = criterion(outputs, labels)
            # 累计损失
            total_loss += loss.item()
            # 获取预测概率最大值的索引
            _, predicted = torch.max(outputs, dim=1)
            # 累计正确预测的数
            correct += predicted.eq(labels.view_as(predicted)).sum().item()
            # 错误分类的图片
            misclassified_images(predicted, writer, labels, images, outputs, epoch)
        # 平均损失
        avg_loss = total_loss / len(test_loader.dataset)
        # 计算正确率
        accuracy = 100 * correct / len(test_loader.dataset)
        # 将test的结果写入write
        writer.add_scalar("Test Loss", total_loss, epoch)
        writer.add_scalar("Accuracy", accuracy, epoch)
        writer.flush()
        return total_loss, accuracy

# %%
# 定义训练流程

# 是否有GPU
device = torch.device('cuda:4' if torch.cuda.is_available() else 'cpu')

print(device.type)

# 模型部署到device
model = get_model().to(device)

# 损失函数
criterion = nn.NLLLoss()

# 优化器
optimizer = optim.SGD(model.parameters(), lr=0.001)

# 定义训练流程函数
def train_epochs(model, device, dataloaders, criterion, optimizer, epochs, writer):
    # 输出信息
    print("{0:>15} | {1:>15} | {2:>15} | {3:>15} | {4:>15} | {5:>15}".format('Epoch', 'Train Loss', 'val_loss', 'val_acc', 'Test Loss', 'Test_acc'))
    # 初始最小的损失
    best_loss = np.inf
    # 开始训练、测试
    for epoch in range(epochs):
        # 训练，return: loss
        train_loss, val_loss, val_acc = train_val(model, device, dataloaders['train'], dataloaders['val'], optimizer, criterion, epoch, writer)
        # 测试，return: loss + accuracy
        test_loss, test_acc = test(model, device, dataloaders['test'], criterion, epoch, writer)
        # 判断损失是否最小
        if test_loss < best_loss:
            best_loss = test_loss # 保存最小损失
            # 保存模型
            torch.save(model.state_dict(), 'model3.pth')
        # 输出结果
        print("{0:>15} | {1:>15} | {2:>15} | {3:>15} | {4:>15} | {5:>15}".format(epoch, train_loss, val_loss, val_acc, test_loss, test_acc))
        writer.flush()
# Out:
# cuda
# /home/huang/anaconda3/envs/pt1.12/lib/python3.7/site-packages/torchvision/models/_utils.py:209: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and will be removed in 0.15, please use 'weights' instead.
#   f"The parameter '{pretrained_param}' is deprecated since 0.13 and will be removed in 0.15, "
# /home/huang/anaconda3/envs/pt1.12/lib/python3.7/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and will be removed in 0.15. The current behavior is equivalent to passing `weights=ResNet101_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet101_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)

# %%
# 调用函数
epochs=40
train_epochs(model, device, dataloaders, criterion, optimizer, epochs, writer)
writer.close()
# Out:
#           Epoch |      Train Loss |        val_loss |         val_acc |       Test Loss |        Test_acc
#               0 | 0.6264651720344093 | 0.5076162219047546 |         0.78125 | 3.5207629799842834 | 77.06855791962175
#               1 | 0.5359364414053416 | 0.5260545015335083 |         0.78125 | 3.287103623151779 | 78.36879432624113
#               2 | 0.5029551646126472 | 0.5393900871276855 |          0.8125 | 3.1681706607341766 | 79.31442080378251
#               3 | 0.4829336398737717 | 0.5445416569709778 |          0.8125 | 3.0983338057994843 | 79.55082742316785
#               4 | 0.4817374677595314 | 0.536474347114563 |         0.78125 | 3.1039279401302338 | 80.49645390070921
#               5 | 0.47197803656418674 | 0.5320228338241577 |         0.78125 | 2.990575909614563 | 81.08747044917257
#               6 | 0.4613820722438826 | 0.5240442156791687 |         0.78125 | 3.00632107257843 | 80.85106382978724
#               7 | 0.4592397626054016 | 0.516579806804657 |         0.78125 | 2.905603766441345 | 81.56028368794327
#               8 | 0.4514470029100746 | 0.5264177918434143 |         0.78125 | 2.8862204551696777 | 81.7966903073286
#               9 | 0.4534491470338436 | 0.5390419960021973 |         0.78125 | 2.9325001537799835 | 82.03309692671395
#              10 | 0.4443577000164729 | 0.5212929248809814 |         0.78125 | 2.920243203639984 | 81.08747044917257
#              11 | 0.4477727789017229 | 0.523933470249176 |         0.78125 | 2.8470514714717865 | 82.03309692671395
#              12 | 0.44418395833518337 | 0.5344668030738831 |         0.78125 | 2.836960554122925 | 82.50591016548464
#              13 | 0.43988908267277954 | 0.5168143510818481 |         0.78125 | 2.8094360530376434 | 82.15130023640661
#              14 | 0.4349126468367628 | 0.5272138118743896 |         0.78125 | 2.7294581532478333 | 82.50591016548464
#              15 | 0.4323969864517177 | 0.5234061479568481 |         0.78125 | 2.8512074947357178 | 81.7966903073286
#              16 | 0.43194266090984595 | 0.526573657989502 |         0.78125 | 2.7952792942523956 | 82.26950354609929
#              17 | 0.4272513429815188 | 0.535456657409668 |         0.78125 | 2.763984888792038 | 82.50591016548464
#              18 | 0.42603869461946675 | 0.5031547546386719 |         0.78125 | 2.7420064508914948 | 82.62411347517731
#              19 | 0.42316472485191947 | 0.5174294710159302 |         0.78125 | 2.717115193605423 | 82.74231678486997
#              20 | 0.4238368172568537 | 0.5027018785476685 |         0.78125 | 2.7478410601615906 | 82.86052009456264
#              21 | 0.4218482238460833 | 0.5256392955780029 |         0.78125 | 2.7228184640407562 | 84.27895981087471
#              22 | 0.42067624299375006 | 0.5180547833442688 |         0.78125 | 2.7517720758914948 | 83.451536643026
#              23 | 0.4152541012344581 | 0.5186987519264221 |         0.78125 | 2.7191544473171234 | 82.86052009456264
#              24 | 0.42220289635857977 | 0.5274823904037476 |         0.78125 | 2.772138327360153 | 83.21513002364067
#              25 | 0.4197512054091485 | 0.5104934573173523 |         0.78125 | 2.729647547006607 | 82.50591016548464
#              26 | 0.4194029391810482 | 0.5072388052940369 |         0.78125 | 2.736120790243149 | 83.56973995271868
#              27 | 0.41182225966862485 | 0.5176579356193542 |         0.78125 | 2.7135116159915924 | 83.56973995271868
#              28 | 0.4122036024731947 | 0.5140619277954102 |         0.78125 | 2.6610385179519653 | 84.39716312056737
#              29 | 0.4126471675650076 | 0.5154048204421997 |         0.78125 | 2.7351874113082886 | 83.68794326241135
#              30 | 0.4118539364394031 | 0.5045998692512512 |         0.78125 | 2.736852467060089 | 83.80614657210401
#              31 | 0.4121772066905863 | 0.5068433284759521 |         0.78125 | 2.7587470710277557 | 83.33333333333333
#              32 | 0.4091146210773941 | 0.5100859999656677 |         0.78125 | 2.714089810848236 | 83.68794326241135
#              33 | 0.4082426368120328 | 0.5101032257080078 |         0.78125 | 2.694840520620346 | 84.16075650118204
#              34 | 0.4064531163457004 | 0.5093414783477783 |         0.78125 | 2.6888311207294464 | 83.56973995271868
#              35 | 0.4042408655091116 | 0.502800703048706 |         0.78125 | 2.6710901856422424 | 84.63356973995272
#              36 | 0.40113964421985915 | 0.503220796585083 |         0.78125 | 2.6895126402378082 | 84.27895981087471
#              37 | 0.40941357519886246 | 0.4954802989959717 |         0.78125 | 2.6688864529132843 | 84.04255319148936
#              38 | 0.40564665708068265 | 0.5016719698905945 |         0.78125 | 2.705013155937195 | 84.04255319148936
#              39 | 0.40237137371674925 | 0.49853312969207764 |         0.78125 | 2.661414235830307 | 84.16075650118204

# %%
# import cv2


# # 定义 Grad-CAM 类
# class GradCAM:
#     def __init__(self, model, target_layer):
#         self.model = model
#         self.target_layer = target_layer
#         self.feature_maps = None
#         self.gradient = None

#     def save_gradient(self, gradient):
#         self.gradient = gradient
        
#     def __call__(self, input):
#         # 调整维度
#         input = input.squeeze(0)
#         input = torch.transpose(input, 0, 1)

#         # 前向传播，记录目标层的特征图
#         for name, module in self.model.named_modules():
#             input = module(input)
#             if name == self.target_layer:
#                 input.register_hook(self.save_gradient)
#                 self.feature_maps = input.detach()
#         output = input

#         # 反向传播，计算梯度
#         output.backward(torch.ones_like(output))
#         # 计算梯度加权特征图
#         gradients = self.gradient.detach().cpu().numpy()[0]
#         weights = np.mean(gradients, axis=(1, 2), keepdims=True)
#         cam = np.sum(weights * self.feature_maps.cpu().numpy()[0], axis=0)
#         cam = np.maximum(cam, 0)  # ReLU
#         cam = cv2.resize(cam, input.shape[1:])  # 调整特征图尺寸
#         cam = cam - np.min(cam)  # 线性规范化
#         cam = cam / np.max(cam)

#         return cam


#     def __call__(self, x):
#         # 前向传播，记录目标层的特征图
#         for name, module in self.model.named_modules():
#             x = module(x)
#             if name == self.target_layer:
#                 x.register_hook(self.save_gradient)
#                 self.feature_maps = x.detach()
#         output = x
#         # 反向传播，计算梯度
#         output.backward(torch.ones_like(output))
#         # 计算梯度加权特征图
#         gradients = self.gradient.detach().cpu().numpy()[0]
#         weights = np.mean(gradients, axis=(1, 2), keepdims=True)
#         cam = np.sum(weights * self.feature_maps.cpu().numpy()[0], axis=0)
#         cam = np.maximum(cam, 0)  # ReLU
#         cam = cv2.resize(cam, x.shape[2:])  # 调整特征图尺寸
#         cam = cam - np.min(cam)  # 线性规范化
#         cam = cam / np.max(cam)
#         return cam

# 获取模型
# model = get_model()
# # 加载预训练权重
# model.load_state_dict(torch.load('model2.pth', map_location=torch.device('cpu')))
# # 设置为评估模式
# model.eval()
# # 定义 Grad-CAM 对象
# grad_cam = GradCAM(model, 'layer4') # 这里选择 ResNet50 的 layer4 层作为目标层

# # 加载目标图像并预处理
# image = cv2.imread('newDataset_binary/train/BacterialPneumonia/101.jpeg')
# image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
# image = cv2.resize(image, (224, 224))
# image = image / 255.
# image = (image - [0.485, 0.456, 0.406]) / [0.229, 0.224, 0.225]
# image = np.transpose(image, (2, 0, 1))
# image = np.expand_dims(image, axis=0)
# image = torch.from_numpy(image).float()

# # 使用 Grad-CAM 进行可视化
# with torch.set_grad_enabled(True):
#     output = model(image)
#     _, pred = output.max(dim=1)
#     cam = grad_cam(image)
#     cam = cv2.resize(cam, (224, 224))
#     heatmap = cv2.applyColorMap(np.uint8(255*cam), cv2.COLORMAP_JET)
#     heatmap = np.float32(heatmap) / 255
#     cam_on_image = heatmap + np.float32(cv2.cvtColor(np.uint8(255*image[0].permute(1,2,0).cpu().numpy()), cv2.COLOR_BGR2RGB))
#     cam_on_image = cam_on_image / np.max(cam_on_image)

# # 显示结果
# import matplotlib.pyplot as plt
# plt.imshow(cam_on_image)
# plt.axis('off')
# plt.show()

# %%
# import cv2
# import numpy as np
# import torch
# from torchvision import models, transforms
# from torch.nn import functional as F
# from matplotlib import pyplot as plt

# # 定义Grad-CAM可视化函数
# class GradCam:
#     def __init__(self, model, target_layer_names):
#         self.model = model
#         self.target_layer_names = target_layer_names
#         self.feature_maps = []
#         self.gradient_maps = []
#         self.model.eval()
#         self.handlers = []
#         for name in self.target_layer_names:
#             self.handlers.append(
#                 self.register_hook(self.model._modules.get(name))
#             )

#     def register_hook(self, module):
#         def hook(module, input, output):
#             self.feature_maps.append(output.cpu().data.numpy())

#         return module.register_forward_hook(hook)

#     def remove_handlers(self):
#         for handle in self.handlers:
#             handle.remove()

#     def __call__(self, x):
#         self.feature_maps = []
#         self.gradient_maps = []
#         self.handlers = []
#         for name in self.target_layer_names:
#             self.handlers.append(
#                 self.register_hook(self.model._modules.get(name))
#             )

#         outputs = self.model(x)
#         one_hot = outputs.detach().zero_()
#         one_hot[0][torch.argmax(outputs)] = 1
#         one_hot.requires_grad = True
#         one_hot = torch.sum(one_hot * outputs)

#         self.model.zero_grad()
#         one_hot.backward(retain_graph=True)

#         self.gradient_maps = []
#         for i, name in enumerate(self.target_layer_names):
#             gradient_map = (
#                 self.feature_maps[i][0] * self.gradient_maps[-1]
#                 if len(self.gradient_maps) > 0
#                 else self.feature_maps[i][0]
#             )
#             self.gradient_maps.append(gradient_map)

#         self.remove_handlers()
#         return self.gradient_maps[-1]

# # 定义输入图像预处理函数
# def preprocess_image(img_path):
#     img = cv2.imread(img_path)
#     img = cv2.resize(img, (224, 224))
#     img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
#     img_tensor = transforms.ToTensor()(img)
#     img_tensor = transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])(img_tensor)
#     img_tensor = img_tensor.unsqueeze(0)
#     return img_tensor

# # 加载模型
# model = get_model()
# # 加载图像
# img_tensor = preprocess_image('newDataset_binary/train/BacterialPneumonia/101.jpeg')
# # 运行Grad-CAM可视化
# torch.autograd.set_detect_anomaly(True)
# cam = GradCam(model, ['layer4'])
# grad_cam = cam(img_tensor)
# # 将可视化结果转换为热力图
# grad_cam = np.mean(grad_cam, axis=(1, 2), keepdims=True)
# grad_cam = np.maximum(grad_cam, 0)
# grad_cam = grad_cam / grad_cam.max()
# # 将热力图叠加到原始图像上
# img = cv2.imread(dataloaders['train'].dataset.root+'BacterialPneumonia/101.jpeg')
# grad_cam = cv2.resize(grad_cam[0], (img.shape[1], img.shape[0]))
# grad_cam = cv2.applyColorMap(np.uint8(255 * grad_cam), cv2.COLORMAP_JET)
# output_image = cv2.addWeighted(img, 0.8, grad_cam, 0.4, 0)
# # 显示结果
# plt.imshow(output_image[...,::-1])
# plt.axis('off')
# plt

# %%
def plot_confusion(cm):
    plt.figure()
    plot_confusion_matrix(cm, figsize=(12, 8), cmap=plt.cm.Blues) # 参数设置
    plt.xticks(range(2), ['bacCovid', 'normalViral'], fontsize=14)
    plt.yticks(range(2), ['bacCovid', 'normalViral'], fontsize=14)
    plt.xlabel('Predicted Label', fontsize=16)
    plt.ylabel('True Label', fontsize=16)
    plt.show()

# %%
# def accuracy(outputs, labels):
#     # 计算正确率
#     _, preds = torch.max(outputs, dim=1)
#     correct = torch.tensor(torch.sum(preds == labels).item() / len(preds))
#     return correct

# %%
# def metrics(outputs, labels):
#     _, preds = torch.max(outputs, dim=1)
#     # precision, recall, F1
#     # 混淆矩阵
#     cm = confusion_matrix(labels.cpu().numpy(), preds.cpu().numpy())
#     # 绘制混淆矩阵
#     plot_confusion(cm) 
#     # 获取tn, fp, fn, tp
# #     tn, fp, fn, tp = cm.ravel()
#     fp = cm.sum(axis=0) - np.diag(cm)
#     fn = cm.sum(axis=1) - np.diag(cm)
#     tp = np.diag(cm)
#     tn = cm.sum() - (fp + fn + tp)
#     print(tn)
#     print(fp)
#     # 精准率
#     precision = tp / (tp + fp)
#     # 召回率
#     recall = tp / (tp + fn)
#     # f1 score
#     f1 = 2 * ((precision * recall) / (precision + recall))
#     return precision, recall, f1

# %%
all_preds = []
all_labels = []

with torch.no_grad():
    model.eval()
    for datas, labels in dataloaders['test']:
        datas, labels = datas.to(device), labels.to(device)
        # 预测输出 前向传播
        outputs = model(datas)
        _, preds = torch.max(outputs, dim=1)
#     将预测结果和真实标签添加到列表中
        all_preds.extend(preds.cpu().numpy())
        all_labels.extend(labels.cpu().numpy())
        # precision, recall, F1
        # 混淆矩阵
    cm = confusion_matrix(all_labels, all_preds)
    # 绘制混淆矩阵
    plot_confusion(cm) 
#     fp = cm.sum(axis=0) - np.diag(cm)
#     fn = cm.sum(axis=1) - np.diag(cm)
#     tp = np.diag(cm)
#     tn = cm.sum() - (fp + fn + tp)
    tn, fp, fn, tp = cm.ravel()
    # 精准率
    precision = tp / (tp + fp)
    # 召回率
    recall = tp / (tp + fn)
    # f1 score
    f1 = 2 * ((precision * recall) / (precision + recall))
    num_correct = 0
    num_total = len(all_labels)
    for pred, label in zip(all_preds, all_labels):
        if pred == label:
            num_correct += 1
            acc = num_correct / num_total
#     acc = torch.tensor(torch.sum(all_preds == all_labels.data).item() / len(all_preds))
    print(precision)
    print(recall)
    print(f1)
    print(acc)

# with torch.no_grad():
#     model.eval()
#     for datas, labels in dataloaders['val']:
#         datas, labels = datas.to(device), labels.to(device)
#         # 预测输出
#         outputs = model(datas)
#         # 计算metrics
#         precision, recall, f1 = metrics(outputs, labels)
#         acc = accuracy(outputs, labels)
#         # 保存结果
#         precisions.append(precision)
#         recalls.append(recall)
#         f1s.append(f1)
#         accuracies.append(acc.item())
#         print(precisions)
#         print(recalls)
# Out:
# 0.8369565217391305
# 0.806282722513089
# 0.8213333333333334
# 0.8416075650118203

# %%
# ['{:.2f}%'.format(pre*100) for pre in precisions]# 精准率 precision

# %%
# ['{:.2f}%'.format(r*100) for r in recalls]# 召回率 recall

# %%
# ['{:.2f}%'.format(f*100) for f in f1s]# f1

# %%
# ['{:.2f}%'.format(a*100) for a in accuracies]# 准确率 accuracy
