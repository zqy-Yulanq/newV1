# %%
# 导入必要的库
import torch
import torch.nn as nn
import numpy as np
import torch.optim as optim
from torchvision import transforms, datasets, models, utils
from torchsummary import summary # 可视化训练过程
from torch.utils.data import DataLoader
import time
import matplotlib.pyplot as plt
import os
import seaborn as sns
import pandas as pd
from mlxtend.plotting import plot_confusion_matrix
from sklearn.metrics import confusion_matrix
from PIL import Image

# %%
# 分为为train, val, test定义transform
image_transforms = {
    'train' : transforms.Compose([
        transforms.RandomResizedCrop(size=300, scale=(0.8, 1.1)), #功能：随机长宽比裁剪原始图片, 表示随机crop出来的图片会在的0.08倍至1.1倍之间
        transforms.RandomRotation(degrees=10), #功能：根据degrees随机旋转一定角度, 则表示在（-10，+10）度之间随机旋转
        transforms.ColorJitter(0.4, 0.4, 0.4), #功能：修改亮度、对比度和饱和度
        transforms.RandomHorizontalFlip(), #功能：水平翻转
        transforms.CenterCrop(size=256), #功能：根据给定的size从中心裁剪，size - 若为sequence,则为(h,w)，若为int，则(size,size)
        transforms.ToTensor(), #numpy --> tensor
        # 功能：对数据按通道进行标准化（RGB），即先减均值，再除以标准差
        transforms.Normalize([0.485, 0.456, 0.406],# mean
                             [0.229, 0.224, 0.225])# std 
    ]),
    
    'val' : transforms.Compose([
        transforms.Resize(300),
        transforms.CenterCrop(256),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406],# mean
                             [0.229, 0.224, 0.225])# std 
    ]),
    
    'test' : transforms.Compose([
        transforms.Resize(300),
        transforms.CenterCrop(256),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406],# mean
                             [0.229, 0.224, 0.225])# std 
    ])
}

# %%
# 加载数据集

# 数据集所在目录路径
data_dir = 'normalViral/'
# train路径
train_dir = data_dir + 'train/'
# val路径
val_dir = data_dir + 'val/'
# test路径
test_dir = data_dir + 'test/'

# 从文件中读取数据
datasets = {
    'train' : datasets.ImageFolder(train_dir, transform=image_transforms['train']), # 读取train中的数据集，并transform
    'val' : datasets.ImageFolder(val_dir, transform=image_transforms['val']),  # 读取val中的数据集，并transform
    'test' : datasets.ImageFolder(test_dir, transform=image_transforms['test']) #  读取test中的数据集，并transform
}

# 定义BATCH_SIZE
BATCH_SIZE = 128 # 每批读取128张图片

# DataLoader : 创建iterator, 按批读取数据
dataloaders = {
    'train' : DataLoader(datasets['train'], batch_size=BATCH_SIZE, shuffle=True), # 训练集
    'val' : DataLoader(datasets['val'], batch_size=BATCH_SIZE, shuffle=True), # 验证集
    'test' : DataLoader(datasets['test'], batch_size=BATCH_SIZE, shuffle=True) # 测试集
}

# 创建label的键值对
LABEL = dict((v, k) for k, v in datasets['train'].class_to_idx.items())

LABEL
# Out:
# {0: 'Normal', 1: 'Viral'}

# %%
# train 简介
dataloaders['train'].dataset
# Out:
# Dataset ImageFolder
#     Number of datapoints: 5000
#     Root location: normalViral/train/
#     StandardTransform
# Transform: Compose(
#                RandomResizedCrop(size=(300, 300), scale=(0.8, 1.1), ratio=(0.75, 1.3333), interpolation=bilinear)
#                RandomRotation(degrees=[-10.0, 10.0], interpolation=nearest, expand=False, fill=0)
#                ColorJitter(brightness=[0.6, 1.4], contrast=[0.6, 1.4], saturation=[0.6, 1.4], hue=None)
#                RandomHorizontalFlip(p=0.5)
#                CenterCrop(size=(256, 256))
#                ToTensor()
#                Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
#            )

# %%
dataloaders['train'].dataset.classes # train下的类别
# Out:
# ['Normal', 'Viral']

# %%
dataloaders['train'].dataset.root # train的路径
# Out:
# 'normalViral/train/'

# %%
# 肺部细菌感染的图片
files_normal_pneumonia = os.listdir(os.path.join(str(dataloaders['train'].dataset.root), 'Normal'))
files_normal_pneumonia
# Out:
# ['Normal (1).jpeg',
#  'Normal (1).png',
#  'Normal (10).jpeg',
#  'Normal (10).png',
#  'Normal (100).jpeg',
#  'Normal (100).png',
#  'Normal (1000).jpeg',
#  'Normal (1000).png',
#  'Normal (1001).jpeg',
#  'Normal (1001).png',
#  'Normal (1002).jpeg',
#  'Normal (1002).png',
#  'Normal (1003).jpeg',
#  'Normal (1003).png',
#  'Normal (1004).jpeg',
#  'Normal (1004).png',
#  'Normal (1005).jpeg',
#  'Normal (1005).png',
#  'Normal (1006).jpeg',
#  'Normal (1006).png',
#  'Normal (1007).jpeg',
#  'Normal (1007).png',
#  'Normal (1008).jpeg',
#  'Normal (1008).png',
#  'Normal (1009).jpeg',
#  'Normal (1009).png',
#  'Normal (101).jpeg',
#  'Normal (101).png',
#  'Normal (1010).jpeg',
#  'Normal (1010).png',
#  'Normal (1011).jpeg',
#  'Normal (1011).png',
#  'Normal (1012).jpeg',
#  'Normal (1012).png',
#  'Normal (1013).jpeg',
#  'Normal (1013).png',
#  'Normal (1014).jpeg',
#  'Normal (1014).png',
#  'Normal (1015).jpeg',
#  'Normal (1015).png',
#  'Normal (1016).jpeg',
#  'Normal (1016).png',
#  'Normal (1017).jpeg',
#  'Normal (1017).png',
#  'Normal (1018).jpeg',
#  'Normal (1018).png',
#  'Normal (1019).jpeg',
#  'Normal (1019).png',
#  'Normal (102).jpeg',
#  'Normal (102).png',
#  'Normal (1020).jpeg',
#  'Normal (1020).png',
#  'Normal (1021).jpeg',
#  'Normal (1021).png',
#  'Normal (1022).jpeg',
#  'Normal (1022).png',
#  'Normal (1023).jpeg',
#  'Normal (1023).png',
#  'Normal (1024).jpeg',
#  'Normal (1024).png',
#  'Normal (1025).jpeg',
#  'Normal (1025).png',
#  'Normal (1026).jpeg',
#  'Normal (1026).png',
#  'Normal (1027).jpeg',
#  'Normal (1027).png',
#  'Normal (1028).jpeg',
#  'Normal (1028).png',
#  'Normal (1029).jpeg',
#  'Normal (1029).png',
#  'Normal (103).jpeg',
#  'Normal (103).png',
#  'Normal (1030).jpeg',
#  'Normal (1030).png',
#  'Normal (1031).jpeg',
#  'Normal (1031).png',
#  'Normal (1032).jpeg',
#  'Normal (1032).png',
#  'Normal (1033).jpeg',
#  'Normal (1033).png',
#  'Normal (1034).jpeg',
#  'Normal (1034).png',
#  'Normal (1035).jpeg',
#  'Normal (1035).png',
#  'Normal (1036).jpeg',
#  'Normal (1036).png',
#  'Normal (1037).jpeg',
#  'Normal (1037).png',
#  'Normal (1038).jpeg',
#  'Normal (1038).png',
#  'Normal (1039).jpeg',
#  'Normal (1039).png',
#  'Normal (104).jpeg',
#  'Normal (104).png',
#  'Normal (1040).jpeg',
#  'Normal (1040).png',
#  'Normal (1041).jpeg',
#  'Normal (1041).png',
#  'Normal (1042).jpeg',
#  'Normal (1042).png',
#  'Normal (1043).jpeg',
#  'Normal (1043).png',
#  'Normal (1044).jpeg',
#  'Normal (1044).png',
#  'Normal (1045).jpeg',
#  'Normal (1045).png',
#  'Normal (1046).jpeg',
#  'Normal (1046).png',
#  'Normal (1047).jpeg',
#  'Normal (1047).png',
#  'Normal (1048).jpeg',
#  'Normal (1048).png',
#  'Normal (1049).jpeg',
#  'Normal (1049).png',
#  'Normal (105).jpeg',
#  'Normal (105).png',
#  'Normal (1050).jpeg',
#  'Normal (1050).png',
#  'Normal (1051).jpeg',
#  'Normal (1051).png',
#  'Normal (1052).jpeg',
#  'Normal (1052).png',
#  'Normal (1053).jpeg',
#  'Normal (1053).png',
#  'Normal (1054).jpeg',
#  'Normal (1054).png',
#  'Normal (1055).jpeg',
#  'Normal (1055).png',
#  'Normal (1056).jpeg',
#  'Normal (1056).png',
#  'Normal (1057).jpeg',
#  'Normal (1057).png',
#  'Normal (1058).jpeg',
#  'Normal (1058).png',
#  'Normal (1059).jpeg',
#  'Normal (1059).png',
#  'Normal (106).jpeg',
#  'Normal (106).png',
#  'Normal (1060).jpeg',
#  'Normal (1060).png',
#  'Normal (1061).jpeg',
#  'Normal (1061).png',
#  'Normal (1062).jpeg',
#  'Normal (1062).png',
#  'Normal (1063).jpeg',
#  'Normal (1063).png',
#  'Normal (1064).jpeg',
#  'Normal (1064).png',
#  'Normal (1065).jpeg',
#  'Normal (1065).png',
#  'Normal (1066).jpeg',
#  'Normal (1066).png',
#  'Normal (1067).jpeg',
#  'Normal (1067).png',
#  'Normal (1068).jpeg',
#  'Normal (1068).png',
#  'Normal (1069).jpeg',
#  'Normal (1069).png',
#  'Normal (107).jpeg',
#  'Normal (107).png',
#  'Normal (1070).jpeg',
#  'Normal (1070).png',
#  'Normal (1071).jpeg',
#  'Normal (1071).png',
#  'Normal (1072).jpeg',
#  'Normal (1072).png',
#  'Normal (1073).jpeg',
#  'Normal (1073).png',
#  'Normal (1074).jpeg',
#  'Normal (1074).png',
#  'Normal (1075).jpeg',
#  'Normal (1075).png',
#  'Normal (1076).jpeg',
#  'Normal (1076).png',
#  'Normal (1077).jpeg',
#  'Normal (1077).png',
#  'Normal (1078).jpeg',
#  'Normal (1078).png',
#  'Normal (1079).jpeg',
#  'Normal (1079).png',
#  'Normal (108).jpeg',
#  'Normal (108).png',
#  'Normal (1080).jpeg',
#  'Normal (1080).png',
#  'Normal (1081).jpeg',
#  'Normal (1081).png',
#  'Normal (1082).jpeg',
#  'Normal (1082).png',
#  'Normal (1083).jpeg',
#  'Normal (1083).png',
#  'Normal (1084).jpeg',
#  'Normal (1084).png',
#  'Normal (1085).jpeg',
#  'Normal (1085).png',
#  'Normal (1086).jpeg',
#  'Normal (1086).png',
#  'Normal (1087).jpeg',
#  'Normal (1087).png',
#  'Normal (1088).jpeg',
#  'Normal (1088).png',
#  'Normal (1089).jpeg',
#  'Normal (1089).png',
#  'Normal (109).jpeg',
#  'Normal (109).png',
#  'Normal (1090).jpeg',
#  'Normal (1090).png',
#  'Normal (1091).jpeg',
#  'Normal (1091).png',
#  'Normal (1092).jpeg',
#  'Normal (1092).png',
#  'Normal (1093).jpeg',
#  'Normal (1093).png',
#  'Normal (1094).jpeg',
#  'Normal (1094).png',
#  'Normal (1095).jpeg',
#  'Normal (1095).png',
#  'Normal (1096).jpeg',
#  'Normal (1096).png',
#  'Normal (1097).jpeg',
#  'Normal (1097).png',
#  'Normal (1098).jpeg',
#  'Normal (1098).png',
#  'Normal (1099).jpeg',
#  'Normal (1099).png',
#  'Normal (11).jpeg',
#  'Normal (11).png',
#  'Normal (110).jpeg',
#  'Normal (110).png',
#  'Normal (1100).jpeg',
#  'Normal (1100).png',
#  'Normal (1101).jpeg',
#  'Normal (1101).png',
#  'Normal (1102).jpeg',
#  'Normal (1102).png',
#  'Normal (1103).jpeg',
#  'Normal (1103).png',
#  'Normal (1104).jpeg',
#  'Normal (1104).png',
#  'Normal (1105).jpeg',
#  'Normal (1105).png',
#  'Normal (1106).jpeg',
#  'Normal (1106).png',
#  'Normal (1107).jpeg',
#  'Normal (1107).png',
#  'Normal (1108).jpeg',
#  'Normal (1108).png',
#  'Normal (1109).jpeg',
#  'Normal (1109).png',
#  'Normal (111).jpeg',
#  'Normal (111).png',
#  'Normal (1110).jpeg',
#  'Normal (1110).png',
#  'Normal (1111).jpeg',
#  'Normal (1111).png',
#  'Normal (1112).jpeg',
#  'Normal (1112).png',
#  'Normal (1113).jpeg',
#  'Normal (1113).png',
#  'Normal (1114).jpeg',
#  'Normal (1114).png',
#  'Normal (1115).jpeg',
#  'Normal (1115).png',
#  'Normal (1116).jpeg',
#  'Normal (1116).png',
#  'Normal (1117).jpeg',
#  'Normal (1117).png',
#  'Normal (1118).jpeg',
#  'Normal (1118).png',
#  'Normal (1119).jpeg',
#  'Normal (1119).png',
#  'Normal (112).jpeg',
#  'Normal (112).png',
#  'Normal (1120).jpeg',
#  'Normal (1120).png',
#  'Normal (1121).jpeg',
#  'Normal (1121).png',
#  'Normal (1122).jpeg',
#  'Normal (1122).png',
#  'Normal (1123).jpeg',
#  'Normal (1123).png',
#  'Normal (1124).jpeg',
#  'Normal (1124).png',
#  'Normal (1125).jpeg',
#  'Normal (1125).png',
#  'Normal (1126).jpeg',
#  'Normal (1126).png',
#  'Normal (1127).jpeg',
#  'Normal (1127).png',
#  'Normal (1128).jpeg',
#  'Normal (1128).png',
#  'Normal (1129).jpeg',
#  'Normal (1129).png',
#  'Normal (113).jpeg',
#  'Normal (113).png',
#  'Normal (1130).jpeg',
#  'Normal (1130).png',
#  'Normal (1131).jpeg',
#  'Normal (1131).png',
#  'Normal (1132).jpeg',
#  'Normal (1132).png',
#  'Normal (1133).jpeg',
#  'Normal (1133).png',
#  'Normal (1134).jpeg',
#  'Normal (1134).png',
#  'Normal (1135).jpeg',
#  'Normal (1135).png',
#  'Normal (1136).jpeg',
#  'Normal (1136).png',
#  'Normal (1137).jpeg',
#  'Normal (1137).png',
#  'Normal (1138).jpeg',
#  'Normal (1138).png',
#  'Normal (1139).jpeg',
#  'Normal (1139).png',
#  'Normal (114).jpeg',
#  'Normal (114).png',
#  'Normal (1140).jpeg',
#  'Normal (1140).png',
#  'Normal (1141).jpeg',
#  'Normal (1141).png',
#  'Normal (1142).jpeg',
#  'Normal (1142).png',
#  'Normal (1143).jpeg',
#  'Normal (1143).png',
#  'Normal (1144).jpeg',
#  'Normal (1144).png',
#  'Normal (1145).jpeg',
#  'Normal (1145).png',
#  'Normal (1146).jpeg',
#  'Normal (1146).png',
#  'Normal (1147).jpeg',
#  'Normal (1147).png',
#  'Normal (1148).jpeg',
#  'Normal (1148).png',
#  'Normal (1149).jpeg',
#  'Normal (1149).png',
#  'Normal (115).jpeg',
#  'Normal (115).png',
#  'Normal (1150).jpeg',
#  'Normal (1150).png',
#  'Normal (1151).jpeg',
#  'Normal (1151).png',
#  'Normal (1152).jpeg',
#  'Normal (1152).png',
#  'Normal (1153).jpeg',
#  'Normal (1153).png',
#  'Normal (1154).jpeg',
#  'Normal (1154).png',
#  'Normal (1155).jpeg',
#  'Normal (1155).png',
#  'Normal (1156).jpeg',
#  'Normal (1156).png',
#  'Normal (1157).jpeg',
#  'Normal (1157).png',
#  'Normal (1158).jpeg',
#  'Normal (1158).png',
#  'Normal (1159).jpeg',
#  'Normal (1159).png',
#  'Normal (116).jpeg',
#  'Normal (116).png',
#  'Normal (1160).jpeg',
#  'Normal (1160).png',
#  'Normal (1161).jpeg',
#  'Normal (1161).png',
#  'Normal (1162).jpeg',
#  'Normal (1162).png',
#  'Normal (1163).jpeg',
#  'Normal (1163).png',
#  'Normal (1164).jpeg',
#  'Normal (1164).png',
#  'Normal (1165).jpeg',
#  'Normal (1165).png',
#  'Normal (1166).jpeg',
#  'Normal (1166).png',
#  'Normal (1167).jpeg',
#  'Normal (1167).png',
#  'Normal (1168).jpeg',
#  'Normal (1168).png',
#  'Normal (1169).jpeg',
#  'Normal (1169).png',
#  'Normal (117).jpeg',
#  'Normal (117).png',
#  'Normal (1170).jpeg',
#  'Normal (1170).png',
#  'Normal (1171).jpeg',
#  'Normal (1171).png',
#  'Normal (1172).jpeg',
#  'Normal (1172).png',
#  'Normal (1173).jpeg',
#  'Normal (1173).png',
#  'Normal (1174).jpeg',
#  'Normal (1174).png',
#  'Normal (1175).jpeg',
#  'Normal (1175).png',
#  'Normal (1176).jpeg',
#  'Normal (1176).png',
#  'Normal (1177).jpeg',
#  'Normal (1177).png',
#  'Normal (1178).jpeg',
#  'Normal (1178).png',
#  'Normal (1179).jpeg',
#  'Normal (1179).png',
#  'Normal (118).jpeg',
#  'Normal (118).png',
#  'Normal (1180).jpeg',
#  'Normal (1180).png',
#  'Normal (1181).jpeg',
#  'Normal (1181).png',
#  'Normal (1182).jpeg',
#  'Normal (1182).png',
#  'Normal (1183).jpeg',
#  'Normal (1183).png',
#  'Normal (1184).jpeg',
#  'Normal (1184).png',
#  'Normal (1185).jpeg',
#  'Normal (1185).png',
#  'Normal (1186).jpeg',
#  'Normal (1186).png',
#  'Normal (1187).jpeg',
#  'Normal (1187).png',
#  'Normal (1188).jpeg',
#  'Normal (1188).png',
#  'Normal (1189).jpeg',
#  'Normal (1189).png',
#  'Normal (119).jpeg',
#  'Normal (119).png',
#  'Normal (1190).jpeg',
#  'Normal (1190).png',
#  'Normal (1191).jpeg',
#  'Normal (1191).png',
#  'Normal (1192).jpeg',
#  'Normal (1192).png',
#  'Normal (1193).jpeg',
#  'Normal (1193).png',
#  'Normal (1194).jpeg',
#  'Normal (1194).png',
#  'Normal (1195).jpeg',
#  'Normal (1195).png',
#  'Normal (1196).jpeg',
#  'Normal (1196).png',
#  'Normal (1197).jpeg',
#  'Normal (1197).png',
#  'Normal (1198).jpeg',
#  'Normal (1198).png',
#  'Normal (1199).jpeg',
#  'Normal (1199).png',
#  'Normal (12).jpeg',
#  'Normal (12).png',
#  'Normal (120).jpeg',
#  'Normal (120).png',
#  'Normal (1200).jpeg',
#  'Normal (1200).png',
#  'Normal (1201).jpeg',
#  'Normal (1201).png',
#  'Normal (1202).jpeg',
#  'Normal (1202).png',
#  'Normal (1203).jpeg',
#  'Normal (1203).png',
#  'Normal (1204).jpeg',
#  'Normal (1204).png',
#  'Normal (1205).jpeg',
#  'Normal (1205).png',
#  'Normal (1206).jpeg',
#  'Normal (1206).png',
#  'Normal (1207).jpeg',
#  'Normal (1207).png',
#  'Normal (1208).jpeg',
#  'Normal (1208).png',
#  'Normal (1209).jpeg',
#  'Normal (1209).png',
#  'Normal (121).jpeg',
#  'Normal (121).png',
#  'Normal (1210).jpeg',
#  'Normal (1210).png',
#  'Normal (1211).jpeg',
#  'Normal (1211).png',
#  'Normal (1212).jpeg',
#  'Normal (1212).png',
#  'Normal (1213).jpeg',
#  'Normal (1213).png',
#  'Normal (1214).jpeg',
#  'Normal (1214).png',
#  'Normal (1215).jpeg',
#  'Normal (1215).png',
#  'Normal (1216).jpeg',
#  'Normal (1216).png',
#  'Normal (1217).jpeg',
#  'Normal (1217).png',
#  'Normal (1218).jpeg',
#  'Normal (1218).png',
#  'Normal (1219).jpeg',
#  'Normal (1219).png',
#  'Normal (122).jpeg',
#  'Normal (122).png',
#  'Normal (1220).jpeg',
#  'Normal (1220).png',
#  'Normal (1221).jpeg',
#  'Normal (1221).png',
#  'Normal (1222).jpeg',
#  'Normal (1222).png',
#  'Normal (1223).jpeg',
#  'Normal (1223).png',
#  'Normal (1224).jpeg',
#  'Normal (1224).png',
#  'Normal (1225).jpeg',
#  'Normal (1225).png',
#  'Normal (1226).jpeg',
#  'Normal (1226).png',
#  'Normal (1227).jpeg',
#  'Normal (1227).png',
#  'Normal (1228).jpeg',
#  'Normal (1228).png',
#  'Normal (1229).jpeg',
#  'Normal (1229).png',
#  'Normal (123).jpeg',
#  'Normal (123).png',
#  'Normal (1230).jpeg',
#  'Normal (1230).png',
#  'Normal (1231).jpeg',
#  'Normal (1231).png',
#  'Normal (1232).jpeg',
#  'Normal (1232).png',
#  'Normal (1233).jpeg',
#  'Normal (1233).png',
#  'Normal (1234).jpeg',
#  'Normal (1234).png',
#  'Normal (1235).jpeg',
#  'Normal (1235).png',
#  'Normal (1236).jpeg',
#  'Normal (1236).png',
#  'Normal (1237).jpeg',
#  'Normal (1237).png',
#  'Normal (1238).jpeg',
#  'Normal (1238).png',
#  'Normal (1239).jpeg',
#  'Normal (1239).png',
#  'Normal (124).jpeg',
#  'Normal (124).png',
#  'Normal (1240).jpeg',
#  'Normal (1240).png',
#  'Normal (1241).jpeg',
#  'Normal (1241).png',
#  'Normal (1242).jpeg',
#  'Normal (1242).png',
#  'Normal (1243).jpeg',
#  'Normal (1243).png',
#  'Normal (1244).jpeg',
#  'Normal (1244).png',
#  'Normal (1245).jpeg',
#  'Normal (1245).png',
#  'Normal (1246).jpeg',
#  'Normal (1246).png',
#  'Normal (1247).jpeg',
#  'Normal (1247).png',
#  'Normal (1248).jpeg',
#  'Normal (1248).png',
#  'Normal (1249).jpeg',
#  'Normal (1249).png',
#  'Normal (125).jpeg',
#  'Normal (125).png',
#  'Normal (1250).jpeg',
#  'Normal (1250).png',
#  'Normal (126).jpeg',
#  'Normal (126).png',
#  'Normal (127).jpeg',
#  'Normal (127).png',
#  'Normal (128).jpeg',
#  'Normal (128).png',
#  'Normal (129).jpeg',
#  'Normal (129).png',
#  'Normal (13).jpeg',
#  'Normal (13).png',
#  'Normal (130).jpeg',
#  'Normal (130).png',
#  'Normal (131).jpeg',
#  'Normal (131).png',
#  'Normal (132).jpeg',
#  'Normal (132).png',
#  'Normal (133).jpeg',
#  'Normal (133).png',
#  'Normal (134).jpeg',
#  'Normal (134).png',
#  'Normal (135).jpeg',
#  'Normal (135).png',
#  'Normal (136).jpeg',
#  'Normal (136).png',
#  'Normal (137).jpeg',
#  'Normal (137).png',
#  'Normal (138).jpeg',
#  'Normal (138).png',
#  'Normal (139).jpeg',
#  'Normal (139).png',
#  'Normal (14).jpeg',
#  'Normal (14).png',
#  'Normal (140).jpeg',
#  'Normal (140).png',
#  'Normal (141).jpeg',
#  'Normal (141).png',
#  'Normal (142).jpeg',
#  'Normal (142).png',
#  'Normal (143).jpeg',
#  'Normal (143).png',
#  'Normal (144).jpeg',
#  'Normal (144).png',
#  'Normal (145).jpeg',
#  'Normal (145).png',
#  'Normal (146).jpeg',
#  'Normal (146).png',
#  'Normal (147).jpeg',
#  'Normal (147).png',
#  'Normal (148).jpeg',
#  'Normal (148).png',
#  'Normal (149).jpeg',
#  'Normal (149).png',
#  'Normal (15).jpeg',
#  'Normal (15).png',
#  'Normal (150).jpeg',
#  'Normal (150).png',
#  'Normal (151).jpeg',
#  'Normal (151).png',
#  'Normal (152).jpeg',
#  'Normal (152).png',
#  'Normal (153).jpeg',
#  'Normal (153).png',
#  'Normal (154).jpeg',
#  'Normal (154).png',
#  'Normal (155).jpeg',
#  'Normal (155).png',
#  'Normal (156).jpeg',
#  'Normal (156).png',
#  'Normal (157).jpeg',
#  'Normal (157).png',
#  'Normal (158).jpeg',
#  'Normal (158).png',
#  'Normal (159).jpeg',
#  'Normal (159).png',
#  'Normal (16).jpeg',
#  'Normal (16).png',
#  'Normal (160).jpeg',
#  'Normal (160).png',
#  'Normal (161).jpeg',
#  'Normal (161).png',
#  'Normal (162).jpeg',
#  'Normal (162).png',
#  'Normal (163).jpeg',
#  'Normal (163).png',
#  'Normal (164).jpeg',
#  'Normal (164).png',
#  'Normal (165).jpeg',
#  'Normal (165).png',
#  'Normal (166).jpeg',
#  'Normal (166).png',
#  'Normal (167).jpeg',
#  'Normal (167).png',
#  'Normal (168).jpeg',
#  'Normal (168).png',
#  'Normal (169).jpeg',
#  'Normal (169).png',
#  'Normal (17).jpeg',
#  'Normal (17).png',
#  'Normal (170).jpeg',
#  'Normal (170).png',
#  'Normal (171).jpeg',
#  'Normal (171).png',
#  'Normal (172).jpeg',
#  'Normal (172).png',
#  'Normal (173).jpeg',
#  'Normal (173).png',
#  'Normal (174).jpeg',
#  'Normal (174).png',
#  'Normal (175).jpeg',
#  'Normal (175).png',
#  'Normal (176).jpeg',
#  'Normal (176).png',
#  'Normal (177).jpeg',
#  'Normal (177).png',
#  'Normal (178).jpeg',
#  'Normal (178).png',
#  'Normal (179).jpeg',
#  'Normal (179).png',
#  'Normal (18).jpeg',
#  'Normal (18).png',
#  'Normal (180).jpeg',
#  'Normal (180).png',
#  'Normal (181).jpeg',
#  'Normal (181).png',
#  'Normal (182).jpeg',
#  'Normal (182).png',
#  'Normal (183).jpeg',
#  'Normal (183).png',
#  'Normal (184).jpeg',
#  'Normal (184).png',
#  'Normal (185).jpeg',
#  'Normal (185).png',
#  'Normal (186).jpeg',
#  'Normal (186).png',
#  'Normal (187).jpeg',
#  'Normal (187).png',
#  'Normal (188).jpeg',
#  'Normal (188).png',
#  'Normal (189).jpeg',
#  'Normal (189).png',
#  'Normal (19).jpeg',
#  'Normal (19).png',
#  'Normal (190).jpeg',
#  'Normal (190).png',
#  'Normal (191).jpeg',
#  'Normal (191).png',
#  'Normal (192).jpeg',
#  'Normal (192).png',
#  'Normal (193).jpeg',
#  'Normal (193).png',
#  'Normal (194).jpeg',
#  'Normal (194).png',
#  'Normal (195).jpeg',
#  'Normal (195).png',
#  'Normal (196).jpeg',
#  'Normal (196).png',
#  'Normal (197).jpeg',
#  'Normal (197).png',
#  'Normal (198).jpeg',
#  'Normal (198).png',
#  'Normal (199).jpeg',
#  'Normal (199).png',
#  'Normal (2).jpeg',
#  'Normal (2).png',
#  'Normal (20).jpeg',
#  'Normal (20).png',
#  'Normal (200).jpeg',
#  'Normal (200).png',
#  'Normal (201).jpeg',
#  'Normal (201).png',
#  'Normal (202).jpeg',
#  'Normal (202).png',
#  'Normal (203).jpeg',
#  'Normal (203).png',
#  'Normal (204).jpeg',
#  'Normal (204).png',
#  'Normal (205).jpeg',
#  'Normal (205).png',
#  'Normal (206).jpeg',
#  'Normal (206).png',
#  'Normal (207).jpeg',
#  'Normal (207).png',
#  'Normal (208).jpeg',
#  'Normal (208).png',
#  'Normal (209).jpeg',
#  'Normal (209).png',
#  'Normal (21).jpeg',
#  'Normal (21).png',
#  'Normal (210).jpeg',
#  'Normal (210).png',
#  'Normal (211).jpeg',
#  'Normal (211).png',
#  'Normal (212).jpeg',
#  'Normal (212).png',
#  'Normal (213).jpeg',
#  'Normal (213).png',
#  'Normal (214).jpeg',
#  'Normal (214).png',
#  'Normal (215).jpeg',
#  'Normal (215).png',
#  'Normal (216).jpeg',
#  'Normal (216).png',
#  'Normal (217).jpeg',
#  'Normal (217).png',
#  'Normal (218).jpeg',
#  'Normal (218).png',
#  'Normal (219).jpeg',
#  'Normal (219).png',
#  'Normal (22).jpeg',
#  'Normal (22).png',
#  'Normal (220).jpeg',
#  'Normal (220).png',
#  'Normal (221).jpeg',
#  'Normal (221).png',
#  'Normal (222).jpeg',
#  'Normal (222).png',
#  'Normal (223).jpeg',
#  'Normal (223).png',
#  'Normal (224).jpeg',
#  'Normal (224).png',
#  'Normal (225).jpeg',
#  'Normal (225).png',
#  'Normal (226).jpeg',
#  'Normal (226).png',
#  'Normal (227).jpeg',
#  'Normal (227).png',
#  'Normal (228).jpeg',
#  'Normal (228).png',
#  'Normal (229).jpeg',
#  'Normal (229).png',
#  'Normal (23).jpeg',
#  'Normal (23).png',
#  'Normal (230).jpeg',
#  'Normal (230).png',
#  'Normal (231).jpeg',
#  'Normal (231).png',
#  'Normal (232).jpeg',
#  'Normal (232).png',
#  'Normal (233).jpeg',
#  'Normal (233).png',
#  'Normal (234).jpeg',
#  'Normal (234).png',
#  'Normal (235).jpeg',
#  'Normal (235).png',
#  'Normal (236).jpeg',
#  'Normal (236).png',
#  'Normal (237).jpeg',
#  'Normal (237).png',
#  'Normal (238).jpeg',
#  'Normal (238).png',
#  'Normal (239).jpeg',
#  'Normal (239).png',
#  'Normal (24).jpeg',
#  'Normal (24).png',
#  'Normal (240).jpeg',
#  'Normal (240).png',
#  'Normal (241).jpeg',
#  'Normal (241).png',
#  'Normal (242).jpeg',
#  'Normal (242).png',
#  'Normal (243).jpeg',
#  'Normal (243).png',
#  'Normal (244).jpeg',
#  'Normal (244).png',
#  'Normal (245).jpeg',
#  'Normal (245).png',
#  'Normal (246).jpeg',
#  'Normal (246).png',
#  'Normal (247).jpeg',
#  'Normal (247).png',
#  'Normal (248).jpeg',
#  'Normal (248).png',
#  'Normal (249).jpeg',
#  'Normal (249).png',
#  'Normal (25).jpeg',
#  'Normal (25).png',
#  'Normal (250).jpeg',
#  'Normal (250).png',
#  'Normal (251).jpeg',
#  'Normal (251).png',
#  'Normal (252).jpeg',
#  'Normal (252).png',
#  'Normal (253).jpeg',
#  'Normal (253).png',
#  'Normal (254).jpeg',
#  'Normal (254).png',
#  'Normal (255).jpeg',
#  'Normal (255).png',
#  'Normal (256).jpeg',
#  'Normal (256).png',
#  'Normal (257).jpeg',
#  'Normal (257).png',
#  'Normal (258).jpeg',
#  'Normal (258).png',
#  'Normal (259).jpeg',
#  'Normal (259).png',
#  'Normal (26).jpeg',
#  'Normal (26).png',
#  'Normal (260).jpeg',
#  'Normal (260).png',
#  'Normal (261).jpeg',
#  'Normal (261).png',
#  'Normal (262).jpeg',
#  'Normal (262).png',
#  'Normal (263).jpeg',
#  'Normal (263).png',
#  'Normal (264).jpeg',
#  'Normal (264).png',
#  'Normal (265).jpeg',
#  'Normal (265).png',
#  'Normal (266).jpeg',
#  'Normal (266).png',
#  'Normal (267).jpeg',
#  'Normal (267).png',
#  'Normal (268).jpeg',
#  'Normal (268).png',
#  'Normal (269).jpeg',
#  'Normal (269).png',
#  'Normal (27).jpeg',
#  'Normal (27).png',
#  'Normal (270).jpeg',
#  'Normal (270).png',
#  'Normal (271).jpeg',
#  'Normal (271).png',
#  'Normal (272).jpeg',
#  'Normal (272).png',
#  'Normal (273).jpeg',
#  'Normal (273).png',
#  'Normal (274).jpeg',
#  'Normal (274).png',
#  'Normal (275).jpeg',
#  'Normal (275).png',
#  'Normal (276).jpeg',
#  'Normal (276).png',
#  'Normal (277).jpeg',
#  'Normal (277).png',
#  'Normal (278).jpeg',
#  'Normal (278).png',
#  'Normal (279).jpeg',
#  'Normal (279).png',
#  'Normal (28).jpeg',
#  'Normal (28).png',
#  'Normal (280).jpeg',
#  'Normal (280).png',
#  'Normal (281).jpeg',
#  'Normal (281).png',
#  'Normal (282).jpeg',
#  'Normal (282).png',
#  'Normal (283).jpeg',
#  'Normal (283).png',
#  'Normal (284).jpeg',
#  'Normal (284).png',
#  'Normal (285).jpeg',
#  'Normal (285).png',
#  'Normal (286).jpeg',
#  'Normal (286).png',
#  'Normal (287).jpeg',
#  'Normal (287).png',
#  'Normal (288).jpeg',
#  'Normal (288).png',
#  'Normal (289).jpeg',
#  'Normal (289).png',
#  'Normal (29).jpeg',
#  'Normal (29).png',
#  'Normal (290).jpeg',
#  'Normal (290).png',
#  'Normal (291).jpeg',
#  'Normal (291).png',
#  'Normal (292).jpeg',
#  'Normal (292).png',
#  'Normal (293).jpeg',
#  'Normal (293).png',
#  'Normal (294).jpeg',
#  'Normal (294).png',
#  'Normal (295).jpeg',
#  'Normal (295).png',
#  'Normal (296).jpeg',
#  'Normal (296).png',
#  'Normal (297).jpeg',
#  'Normal (297).png',
#  'Normal (298).jpeg',
#  'Normal (298).png',
#  'Normal (299).jpeg',
#  'Normal (299).png',
#  'Normal (3).jpeg',
#  'Normal (3).png',
#  'Normal (30).jpeg',
#  'Normal (30).png',
#  'Normal (300).jpeg',
#  'Normal (300).png',
#  'Normal (301).jpeg',
#  'Normal (301).png',
#  'Normal (302).jpeg',
#  'Normal (302).png',
#  'Normal (303).jpeg',
#  'Normal (303).png',
#  'Normal (304).jpeg',
#  'Normal (304).png',
#  'Normal (305).jpeg',
#  'Normal (305).png',
#  'Normal (306).jpeg',
#  'Normal (306).png',
#  'Normal (307).jpeg',
#  'Normal (307).png',
#  'Normal (308).jpeg',
#  'Normal (308).png',
#  'Normal (309).jpeg',
#  'Normal (309).png',
#  'Normal (31).jpeg',
#  'Normal (31).png',
#  'Normal (310).jpeg',
#  'Normal (310).png',
#  'Normal (311).jpeg',
#  'Normal (311).png',
#  'Normal (312).jpeg',
#  'Normal (312).png',
#  'Normal (313).jpeg',
#  'Normal (313).png',
#  'Normal (314).jpeg',
#  'Normal (314).png',
#  'Normal (315).jpeg',
#  'Normal (315).png',
#  'Normal (316).jpeg',
#  'Normal (316).png',
#  'Normal (317).jpeg',
#  'Normal (317).png',
#  'Normal (318).jpeg',
#  'Normal (318).png',
#  'Normal (319).jpeg',
#  'Normal (319).png',
#  'Normal (32).jpeg',
#  'Normal (32).png',
#  'Normal (320).jpeg',
#  'Normal (320).png',
#  'Normal (321).jpeg',
#  'Normal (321).png',
#  'Normal (322).jpeg',
#  'Normal (322).png',
#  ...]

# %%
# 肺部感染的图片
files_viral_pneumonia = os.listdir(os.path.join(str(dataloaders['train'].dataset.root), 'Viral'))
files_viral_pneumonia
# Out:
# ['Viral (1).jpeg',
#  'Viral (1).png',
#  'Viral (10).jpeg',
#  'Viral (10).png',
#  'Viral (100).jpeg',
#  'Viral (100).png',
#  'Viral (1000).jpeg',
#  'Viral (1001).jpeg',
#  'Viral (1002).jpeg',
#  'Viral (1003).jpeg',
#  'Viral (1004).jpeg',
#  'Viral (1005).jpeg',
#  'Viral (1006).jpeg',
#  'Viral (1007).jpeg',
#  'Viral (1008).jpeg',
#  'Viral (1009).jpeg',
#  'Viral (101).jpeg',
#  'Viral (101).png',
#  'Viral (1010).jpeg',
#  'Viral (1011).jpeg',
#  'Viral (1012).jpeg',
#  'Viral (1013).jpeg',
#  'Viral (1014).jpeg',
#  'Viral (1015).jpeg',
#  'Viral (1016).jpeg',
#  'Viral (1017).jpeg',
#  'Viral (1018).jpeg',
#  'Viral (1019).jpeg',
#  'Viral (102).jpeg',
#  'Viral (102).png',
#  'Viral (1020).jpeg',
#  'Viral (1021).jpeg',
#  'Viral (1022).jpeg',
#  'Viral (1023).jpeg',
#  'Viral (1024).jpeg',
#  'Viral (1025).jpeg',
#  'Viral (1026).jpeg',
#  'Viral (1027).jpeg',
#  'Viral (1028).jpeg',
#  'Viral (1029).jpeg',
#  'Viral (103).jpeg',
#  'Viral (103).png',
#  'Viral (1030).jpeg',
#  'Viral (1031).jpeg',
#  'Viral (1032).jpeg',
#  'Viral (1033).jpeg',
#  'Viral (1034).jpeg',
#  'Viral (1035).jpeg',
#  'Viral (1036).jpeg',
#  'Viral (1037).jpeg',
#  'Viral (1038).jpeg',
#  'Viral (1039).jpeg',
#  'Viral (104).jpeg',
#  'Viral (104).png',
#  'Viral (1040).jpeg',
#  'Viral (1041).jpeg',
#  'Viral (1042).jpeg',
#  'Viral (1043).jpeg',
#  'Viral (1044).jpeg',
#  'Viral (1045).jpeg',
#  'Viral (1046).jpeg',
#  'Viral (1047).jpeg',
#  'Viral (1048).jpeg',
#  'Viral (1049).jpeg',
#  'Viral (105).jpeg',
#  'Viral (105).png',
#  'Viral (1050).jpeg',
#  'Viral (1051).jpeg',
#  'Viral (1052).jpeg',
#  'Viral (1053).jpeg',
#  'Viral (1054).jpeg',
#  'Viral (1055).jpeg',
#  'Viral (1056).jpeg',
#  'Viral (1057).jpeg',
#  'Viral (1058).jpeg',
#  'Viral (1059).jpeg',
#  'Viral (106).jpeg',
#  'Viral (106).png',
#  'Viral (1060).jpeg',
#  'Viral (1061).jpeg',
#  'Viral (1062).jpeg',
#  'Viral (1063).jpeg',
#  'Viral (1064).jpeg',
#  'Viral (1065).jpeg',
#  'Viral (1066).jpeg',
#  'Viral (1067).jpeg',
#  'Viral (1068).jpeg',
#  'Viral (1069).jpeg',
#  'Viral (107).jpeg',
#  'Viral (107).png',
#  'Viral (1070).jpeg',
#  'Viral (1071).jpeg',
#  'Viral (1072).jpeg',
#  'Viral (1073).jpeg',
#  'Viral (1074).jpeg',
#  'Viral (1075).jpeg',
#  'Viral (1076).jpeg',
#  'Viral (1077).jpeg',
#  'Viral (1078).jpeg',
#  'Viral (1079).jpeg',
#  'Viral (108).jpeg',
#  'Viral (108).png',
#  'Viral (1080).jpeg',
#  'Viral (1081).jpeg',
#  'Viral (1082).jpeg',
#  'Viral (1083).jpeg',
#  'Viral (1084).jpeg',
#  'Viral (1085).jpeg',
#  'Viral (1086).jpeg',
#  'Viral (1087).jpeg',
#  'Viral (1088).jpeg',
#  'Viral (1089).jpeg',
#  'Viral (109).jpeg',
#  'Viral (109).png',
#  'Viral (1090).jpeg',
#  'Viral (1091).jpeg',
#  'Viral (1092).jpeg',
#  'Viral (1093).jpeg',
#  'Viral (1094).jpeg',
#  'Viral (1095).jpeg',
#  'Viral (1096).jpeg',
#  'Viral (1097).jpeg',
#  'Viral (1098).jpeg',
#  'Viral (1099).jpeg',
#  'Viral (11).jpeg',
#  'Viral (11).png',
#  'Viral (110).jpeg',
#  'Viral (110).png',
#  'Viral (1100).jpeg',
#  'Viral (1101).jpeg',
#  'Viral (1102).jpeg',
#  'Viral (1103).jpeg',
#  'Viral (1104).jpeg',
#  'Viral (1105).jpeg',
#  'Viral (1106).jpeg',
#  'Viral (1107).jpeg',
#  'Viral (1108).jpeg',
#  'Viral (1109).jpeg',
#  'Viral (111).jpeg',
#  'Viral (111).png',
#  'Viral (1110).jpeg',
#  'Viral (1111).jpeg',
#  'Viral (1112).jpeg',
#  'Viral (1113).jpeg',
#  'Viral (1114).jpeg',
#  'Viral (1115).jpeg',
#  'Viral (1116).jpeg',
#  'Viral (1117).jpeg',
#  'Viral (1118).jpeg',
#  'Viral (1119).jpeg',
#  'Viral (112).jpeg',
#  'Viral (112).png',
#  'Viral (1120).jpeg',
#  'Viral (1121).jpeg',
#  'Viral (1122).jpeg',
#  'Viral (1123).jpeg',
#  'Viral (1124).jpeg',
#  'Viral (1125).jpeg',
#  'Viral (1126).jpeg',
#  'Viral (1127).jpeg',
#  'Viral (1128).jpeg',
#  'Viral (1129).jpeg',
#  'Viral (113).jpeg',
#  'Viral (113).png',
#  'Viral (1130).jpeg',
#  'Viral (1131).jpeg',
#  'Viral (1132).jpeg',
#  'Viral (1133).jpeg',
#  'Viral (1134).jpeg',
#  'Viral (1135).jpeg',
#  'Viral (1136).jpeg',
#  'Viral (1137).jpeg',
#  'Viral (1138).jpeg',
#  'Viral (1139).jpeg',
#  'Viral (114).jpeg',
#  'Viral (114).png',
#  'Viral (1140).jpeg',
#  'Viral (1141).jpeg',
#  'Viral (1142).jpeg',
#  'Viral (1143).jpeg',
#  'Viral (1144).jpeg',
#  'Viral (1145).jpeg',
#  'Viral (1146).jpeg',
#  'Viral (1147).jpeg',
#  'Viral (1148).jpeg',
#  'Viral (1149).jpeg',
#  'Viral (115).jpeg',
#  'Viral (115).png',
#  'Viral (1150).jpeg',
#  'Viral (1151).jpeg',
#  'Viral (1152).jpeg',
#  'Viral (1153).jpeg',
#  'Viral (1154).jpeg',
#  'Viral (1155).jpeg',
#  'Viral (1156).jpeg',
#  'Viral (1157).jpeg',
#  'Viral (1158).jpeg',
#  'Viral (1159).jpeg',
#  'Viral (116).jpeg',
#  'Viral (116).png',
#  'Viral (1160).jpeg',
#  'Viral (1161).jpeg',
#  'Viral (1162).jpeg',
#  'Viral (1163).jpeg',
#  'Viral (1164).jpeg',
#  'Viral (1165).jpeg',
#  'Viral (1166).jpeg',
#  'Viral (1167).jpeg',
#  'Viral (1168).jpeg',
#  'Viral (1169).jpeg',
#  'Viral (117).jpeg',
#  'Viral (117).png',
#  'Viral (1170).jpeg',
#  'Viral (1171).jpeg',
#  'Viral (1172).jpeg',
#  'Viral (1173).jpeg',
#  'Viral (1174).jpeg',
#  'Viral (1175).jpeg',
#  'Viral (1176).jpeg',
#  'Viral (1177).jpeg',
#  'Viral (1178).jpeg',
#  'Viral (1179).jpeg',
#  'Viral (118).jpeg',
#  'Viral (118).png',
#  'Viral (1180).jpeg',
#  'Viral (1181).jpeg',
#  'Viral (1182).jpeg',
#  'Viral (1183).jpeg',
#  'Viral (1184).jpeg',
#  'Viral (1185).jpeg',
#  'Viral (1186).jpeg',
#  'Viral (1187).jpeg',
#  'Viral (1188).jpeg',
#  'Viral (1189).jpeg',
#  'Viral (119).jpeg',
#  'Viral (119).png',
#  'Viral (1190).jpeg',
#  'Viral (1191).jpeg',
#  'Viral (1192).jpeg',
#  'Viral (1193).jpeg',
#  'Viral (1194).jpeg',
#  'Viral (1195).jpeg',
#  'Viral (1196).jpeg',
#  'Viral (1197).jpeg',
#  'Viral (1198).jpeg',
#  'Viral (1199).jpeg',
#  'Viral (12).jpeg',
#  'Viral (12).png',
#  'Viral (120).jpeg',
#  'Viral (120).png',
#  'Viral (1200).jpeg',
#  'Viral (1201).jpeg',
#  'Viral (1202).jpeg',
#  'Viral (1203).jpeg',
#  'Viral (1204).jpeg',
#  'Viral (1205).jpeg',
#  'Viral (1206).jpeg',
#  'Viral (1207).jpeg',
#  'Viral (1208).jpeg',
#  'Viral (1209).jpeg',
#  'Viral (121).jpeg',
#  'Viral (121).png',
#  'Viral (1210).jpeg',
#  'Viral (1211).jpeg',
#  'Viral (1212).jpeg',
#  'Viral (1213).jpeg',
#  'Viral (1214).jpeg',
#  'Viral (1215).jpeg',
#  'Viral (1216).jpeg',
#  'Viral (1217).jpeg',
#  'Viral (1218).jpeg',
#  'Viral (1219).jpeg',
#  'Viral (122).jpeg',
#  'Viral (122).png',
#  'Viral (1220).jpeg',
#  'Viral (1221).jpeg',
#  'Viral (1222).jpeg',
#  'Viral (1223).jpeg',
#  'Viral (1224).jpeg',
#  'Viral (1225).jpeg',
#  'Viral (1226).jpeg',
#  'Viral (1227).jpeg',
#  'Viral (1228).jpeg',
#  'Viral (1229).jpeg',
#  'Viral (123).jpeg',
#  'Viral (123).png',
#  'Viral (1230).jpeg',
#  'Viral (1231).jpeg',
#  'Viral (1232).jpeg',
#  'Viral (1233).jpeg',
#  'Viral (1234).jpeg',
#  'Viral (1235).jpeg',
#  'Viral (1236).jpeg',
#  'Viral (1237).jpeg',
#  'Viral (1238).jpeg',
#  'Viral (1239).jpeg',
#  'Viral (124).jpeg',
#  'Viral (124).png',
#  'Viral (1240).jpeg',
#  'Viral (1241).jpeg',
#  'Viral (1242).jpeg',
#  'Viral (1243).jpeg',
#  'Viral (1244).jpeg',
#  'Viral (1245).jpeg',
#  'Viral (1246).jpeg',
#  'Viral (1247).jpeg',
#  'Viral (1248).jpeg',
#  'Viral (1249).jpeg',
#  'Viral (125).jpeg',
#  'Viral (125).png',
#  'Viral (1250).jpeg',
#  'Viral (1251).jpeg',
#  'Viral (1252).jpeg',
#  'Viral (1253).jpeg',
#  'Viral (1254).jpeg',
#  'Viral (1255).jpeg',
#  'Viral (1256).jpeg',
#  'Viral (1257).jpeg',
#  'Viral (1258).jpeg',
#  'Viral (1259).jpeg',
#  'Viral (126).jpeg',
#  'Viral (126).png',
#  'Viral (1260).jpeg',
#  'Viral (1261).jpeg',
#  'Viral (1262).jpeg',
#  'Viral (1263).jpeg',
#  'Viral (1264).jpeg',
#  'Viral (1265).jpeg',
#  'Viral (1266).jpeg',
#  'Viral (1267).jpeg',
#  'Viral (1268).jpeg',
#  'Viral (1269).jpeg',
#  'Viral (127).jpeg',
#  'Viral (127).png',
#  'Viral (1270).jpeg',
#  'Viral (1271).jpeg',
#  'Viral (1272).jpeg',
#  'Viral (1273).jpeg',
#  'Viral (1274).jpeg',
#  'Viral (1275).jpeg',
#  'Viral (1276).jpeg',
#  'Viral (1277).jpeg',
#  'Viral (1278).jpeg',
#  'Viral (1279).jpeg',
#  'Viral (128).jpeg',
#  'Viral (128).png',
#  'Viral (1280).jpeg',
#  'Viral (1281).jpeg',
#  'Viral (1282).jpeg',
#  'Viral (1283).jpeg',
#  'Viral (1284).jpeg',
#  'Viral (1285).jpeg',
#  'Viral (1286).jpeg',
#  'Viral (1287).jpeg',
#  'Viral (1288).jpeg',
#  'Viral (1289).jpeg',
#  'Viral (129).jpeg',
#  'Viral (129).png',
#  'Viral (1290).jpeg',
#  'Viral (1291).jpeg',
#  'Viral (1292).jpeg',
#  'Viral (1293).jpeg',
#  'Viral (1294).jpeg',
#  'Viral (1295).jpeg',
#  'Viral (1296).jpeg',
#  'Viral (1297).jpeg',
#  'Viral (1298).jpeg',
#  'Viral (1299).jpeg',
#  'Viral (13).jpeg',
#  'Viral (13).png',
#  'Viral (130).jpeg',
#  'Viral (130).png',
#  'Viral (1300).jpeg',
#  'Viral (1301).jpeg',
#  'Viral (1302).jpeg',
#  'Viral (1303).jpeg',
#  'Viral (1304).jpeg',
#  'Viral (1305).jpeg',
#  'Viral (1306).jpeg',
#  'Viral (1307).jpeg',
#  'Viral (1308).jpeg',
#  'Viral (1309).jpeg',
#  'Viral (131).jpeg',
#  'Viral (131).png',
#  'Viral (1310).jpeg',
#  'Viral (1311).jpeg',
#  'Viral (1312).jpeg',
#  'Viral (1313).jpeg',
#  'Viral (1314).jpeg',
#  'Viral (1315).jpeg',
#  'Viral (1316).jpeg',
#  'Viral (1317).jpeg',
#  'Viral (1318).jpeg',
#  'Viral (1319).jpeg',
#  'Viral (132).jpeg',
#  'Viral (132).png',
#  'Viral (1320).jpeg',
#  'Viral (1321).jpeg',
#  'Viral (1322).jpeg',
#  'Viral (1323).jpeg',
#  'Viral (1324).jpeg',
#  'Viral (1325).jpeg',
#  'Viral (1326).jpeg',
#  'Viral (1327).jpeg',
#  'Viral (1328).jpeg',
#  'Viral (1329).jpeg',
#  'Viral (133).jpeg',
#  'Viral (133).png',
#  'Viral (1330).jpeg',
#  'Viral (1331).jpeg',
#  'Viral (1332).jpeg',
#  'Viral (1333).jpeg',
#  'Viral (1334).jpeg',
#  'Viral (1335).jpeg',
#  'Viral (1336).jpeg',
#  'Viral (1337).jpeg',
#  'Viral (1338).jpeg',
#  'Viral (1339).jpeg',
#  'Viral (134).jpeg',
#  'Viral (134).png',
#  'Viral (1340).jpeg',
#  'Viral (1341).jpeg',
#  'Viral (1342).jpeg',
#  'Viral (1343).jpeg',
#  'Viral (1344).jpeg',
#  'Viral (1345).jpeg',
#  'Viral (1346).jpeg',
#  'Viral (1347).jpeg',
#  'Viral (1348).jpeg',
#  'Viral (1349).jpeg',
#  'Viral (135).jpeg',
#  'Viral (135).png',
#  'Viral (1350).jpeg',
#  'Viral (1351).jpeg',
#  'Viral (1352).jpeg',
#  'Viral (1353).jpeg',
#  'Viral (1354).jpeg',
#  'Viral (1355).jpeg',
#  'Viral (1356).jpeg',
#  'Viral (1357).jpeg',
#  'Viral (1358).jpeg',
#  'Viral (1359).jpeg',
#  'Viral (136).jpeg',
#  'Viral (136).png',
#  'Viral (1360).jpeg',
#  'Viral (1361).jpeg',
#  'Viral (1362).jpeg',
#  'Viral (1363).jpeg',
#  'Viral (1364).jpeg',
#  'Viral (1365).jpeg',
#  'Viral (1366).jpeg',
#  'Viral (1367).jpeg',
#  'Viral (1368).jpeg',
#  'Viral (1369).jpeg',
#  'Viral (137).jpeg',
#  'Viral (137).png',
#  'Viral (1370).jpeg',
#  'Viral (1371).jpeg',
#  'Viral (1372).jpeg',
#  'Viral (1373).jpeg',
#  'Viral (1374).jpeg',
#  'Viral (1375).jpeg',
#  'Viral (1376).jpeg',
#  'Viral (1377).jpeg',
#  'Viral (1378).jpeg',
#  'Viral (1379).jpeg',
#  'Viral (138).jpeg',
#  'Viral (138).png',
#  'Viral (1380).jpeg',
#  'Viral (1381).jpeg',
#  'Viral (1382).jpeg',
#  'Viral (1383).jpeg',
#  'Viral (1384).jpeg',
#  'Viral (1385).jpeg',
#  'Viral (1386).jpeg',
#  'Viral (1387).jpeg',
#  'Viral (1388).jpeg',
#  'Viral (1389).jpeg',
#  'Viral (139).jpeg',
#  'Viral (139).png',
#  'Viral (1390).jpeg',
#  'Viral (1391).jpeg',
#  'Viral (1392).jpeg',
#  'Viral (1393).jpeg',
#  'Viral (1394).jpeg',
#  'Viral (1395).jpeg',
#  'Viral (1396).jpeg',
#  'Viral (1397).jpeg',
#  'Viral (1398).jpeg',
#  'Viral (1399).jpeg',
#  'Viral (14).jpeg',
#  'Viral (14).png',
#  'Viral (140).jpeg',
#  'Viral (140).png',
#  'Viral (1400).jpeg',
#  'Viral (1401).jpeg',
#  'Viral (1402).jpeg',
#  'Viral (1403).jpeg',
#  'Viral (1404).jpeg',
#  'Viral (1405).jpeg',
#  'Viral (1406).jpeg',
#  'Viral (1407).jpeg',
#  'Viral (1408).jpeg',
#  'Viral (1409).jpeg',
#  'Viral (141).jpeg',
#  'Viral (141).png',
#  'Viral (1410).jpeg',
#  'Viral (1411).jpeg',
#  'Viral (1412).jpeg',
#  'Viral (1413).jpeg',
#  'Viral (1414).jpeg',
#  'Viral (1415).jpeg',
#  'Viral (1416).jpeg',
#  'Viral (1417).jpeg',
#  'Viral (1418).jpeg',
#  'Viral (1419).jpeg',
#  'Viral (142).jpeg',
#  'Viral (142).png',
#  'Viral (1420).jpeg',
#  'Viral (1421).jpeg',
#  'Viral (1422).jpeg',
#  'Viral (1423).jpeg',
#  'Viral (1424).jpeg',
#  'Viral (1425).jpeg',
#  'Viral (1426).jpeg',
#  'Viral (1427).jpeg',
#  'Viral (1428).jpeg',
#  'Viral (1429).jpeg',
#  'Viral (143).jpeg',
#  'Viral (143).png',
#  'Viral (1430).jpeg',
#  'Viral (1431).jpeg',
#  'Viral (1432).jpeg',
#  'Viral (1433).jpeg',
#  'Viral (1434).jpeg',
#  'Viral (1435).jpeg',
#  'Viral (1436).jpeg',
#  'Viral (1437).jpeg',
#  'Viral (1438).jpeg',
#  'Viral (1439).jpeg',
#  'Viral (144).jpeg',
#  'Viral (144).png',
#  'Viral (1440).jpeg',
#  'Viral (1441).jpeg',
#  'Viral (1442).jpeg',
#  'Viral (1443).jpeg',
#  'Viral (1444).jpeg',
#  'Viral (1445).jpeg',
#  'Viral (1446).jpeg',
#  'Viral (1447).jpeg',
#  'Viral (1448).jpeg',
#  'Viral (1449).jpeg',
#  'Viral (145).jpeg',
#  'Viral (145).png',
#  'Viral (1450).jpeg',
#  'Viral (1451).jpeg',
#  'Viral (1452).jpeg',
#  'Viral (1453).jpeg',
#  'Viral (1454).jpeg',
#  'Viral (1455).jpeg',
#  'Viral (1456).jpeg',
#  'Viral (1457).jpeg',
#  'Viral (1458).jpeg',
#  'Viral (1459).jpeg',
#  'Viral (146).jpeg',
#  'Viral (146).png',
#  'Viral (1460).jpeg',
#  'Viral (1461).jpeg',
#  'Viral (1462).jpeg',
#  'Viral (1463).jpeg',
#  'Viral (1464).jpeg',
#  'Viral (1465).jpeg',
#  'Viral (1466).jpeg',
#  'Viral (1467).jpeg',
#  'Viral (1468).jpeg',
#  'Viral (1469).jpeg',
#  'Viral (147).jpeg',
#  'Viral (147).png',
#  'Viral (1470).jpeg',
#  'Viral (1471).jpeg',
#  'Viral (1472).jpeg',
#  'Viral (1473).jpeg',
#  'Viral (1474).jpeg',
#  'Viral (1475).jpeg',
#  'Viral (1476).jpeg',
#  'Viral (1477).jpeg',
#  'Viral (1478).jpeg',
#  'Viral (1479).jpeg',
#  'Viral (148).jpeg',
#  'Viral (148).png',
#  'Viral (1480).jpeg',
#  'Viral (1481).jpeg',
#  'Viral (1482).jpeg',
#  'Viral (1483).jpeg',
#  'Viral (1484).jpeg',
#  'Viral (1485).jpeg',
#  'Viral (1486).jpeg',
#  'Viral (1487).jpeg',
#  'Viral (1488).jpeg',
#  'Viral (1489).jpeg',
#  'Viral (149).jpeg',
#  'Viral (149).png',
#  'Viral (1490).jpeg',
#  'Viral (1491).jpeg',
#  'Viral (1492).jpeg',
#  'Viral (1493).jpeg',
#  'Viral (1494).jpeg',
#  'Viral (1495).jpeg',
#  'Viral (1496).jpeg',
#  'Viral (1497).jpeg',
#  'Viral (1498).jpeg',
#  'Viral (1499).jpeg',
#  'Viral (15).jpeg',
#  'Viral (15).png',
#  'Viral (150).jpeg',
#  'Viral (150).png',
#  'Viral (1500).jpeg',
#  'Viral (1501).jpeg',
#  'Viral (1502).jpeg',
#  'Viral (1503).jpeg',
#  'Viral (1504).jpeg',
#  'Viral (1505).jpeg',
#  'Viral (1506).jpeg',
#  'Viral (1507).jpeg',
#  'Viral (1508).jpeg',
#  'Viral (1509).jpeg',
#  'Viral (151).jpeg',
#  'Viral (151).png',
#  'Viral (1510).jpeg',
#  'Viral (1511).jpeg',
#  'Viral (1512).jpeg',
#  'Viral (1513).jpeg',
#  'Viral (1514).jpeg',
#  'Viral (1515).jpeg',
#  'Viral (1516).jpeg',
#  'Viral (1517).jpeg',
#  'Viral (1518).jpeg',
#  'Viral (1519).jpeg',
#  'Viral (152).jpeg',
#  'Viral (152).png',
#  'Viral (1520).jpeg',
#  'Viral (1521).jpeg',
#  'Viral (1522).jpeg',
#  'Viral (1523).jpeg',
#  'Viral (1524).jpeg',
#  'Viral (1525).jpeg',
#  'Viral (1526).jpeg',
#  'Viral (1527).jpeg',
#  'Viral (1528).jpeg',
#  'Viral (1529).jpeg',
#  'Viral (153).jpeg',
#  'Viral (153).png',
#  'Viral (1530).jpeg',
#  'Viral (1531).jpeg',
#  'Viral (1532).jpeg',
#  'Viral (1533).jpeg',
#  'Viral (1534).jpeg',
#  'Viral (1535).jpeg',
#  'Viral (1536).jpeg',
#  'Viral (1537).jpeg',
#  'Viral (1538).jpeg',
#  'Viral (1539).jpeg',
#  'Viral (154).jpeg',
#  'Viral (154).png',
#  'Viral (1540).jpeg',
#  'Viral (1541).jpeg',
#  'Viral (1542).jpeg',
#  'Viral (1543).jpeg',
#  'Viral (1544).jpeg',
#  'Viral (1545).jpeg',
#  'Viral (1546).jpeg',
#  'Viral (1547).jpeg',
#  'Viral (1548).jpeg',
#  'Viral (1549).jpeg',
#  'Viral (155).jpeg',
#  'Viral (155).png',
#  'Viral (1550).jpeg',
#  'Viral (1551).jpeg',
#  'Viral (1552).jpeg',
#  'Viral (1553).jpeg',
#  'Viral (1554).jpeg',
#  'Viral (1555).jpeg',
#  'Viral (1556).jpeg',
#  'Viral (1557).jpeg',
#  'Viral (1558).jpeg',
#  'Viral (1559).jpeg',
#  'Viral (156).jpeg',
#  'Viral (156).png',
#  'Viral (1560).jpeg',
#  'Viral (1561).jpeg',
#  'Viral (1562).jpeg',
#  'Viral (1563).jpeg',
#  'Viral (1564).jpeg',
#  'Viral (1565).jpeg',
#  'Viral (1566).jpeg',
#  'Viral (1567).jpeg',
#  'Viral (1568).jpeg',
#  'Viral (1569).jpeg',
#  'Viral (157).jpeg',
#  'Viral (157).png',
#  'Viral (1570).jpeg',
#  'Viral (1571).jpeg',
#  'Viral (1572).jpeg',
#  'Viral (1573).jpeg',
#  'Viral (1574).jpeg',
#  'Viral (1575).jpeg',
#  'Viral (1576).jpeg',
#  'Viral (1577).jpeg',
#  'Viral (1578).jpeg',
#  'Viral (1579).jpeg',
#  'Viral (158).jpeg',
#  'Viral (158).png',
#  'Viral (1580).jpeg',
#  'Viral (1581).jpeg',
#  'Viral (1582).jpeg',
#  'Viral (1583).jpeg',
#  'Viral (1584).jpeg',
#  'Viral (1585).jpeg',
#  'Viral (1586).jpeg',
#  'Viral (1587).jpeg',
#  'Viral (1588).jpeg',
#  'Viral (1589).jpeg',
#  'Viral (159).jpeg',
#  'Viral (159).png',
#  'Viral (1590).jpeg',
#  'Viral (1591).jpeg',
#  'Viral (1592).jpeg',
#  'Viral (1593).jpeg',
#  'Viral (1594).jpeg',
#  'Viral (1595).jpeg',
#  'Viral (1596).jpeg',
#  'Viral (1597).jpeg',
#  'Viral (1598).jpeg',
#  'Viral (1599).jpeg',
#  'Viral (16).jpeg',
#  'Viral (16).png',
#  'Viral (160).jpeg',
#  'Viral (160).png',
#  'Viral (1600).jpeg',
#  'Viral (1601).jpeg',
#  'Viral (1602).jpeg',
#  'Viral (1603).jpeg',
#  'Viral (1604).jpeg',
#  'Viral (1605).jpeg',
#  'Viral (1606).jpeg',
#  'Viral (1607).jpeg',
#  'Viral (1608).jpeg',
#  'Viral (1609).jpeg',
#  'Viral (161).jpeg',
#  'Viral (161).png',
#  'Viral (1610).jpeg',
#  'Viral (1611).jpeg',
#  'Viral (1612).jpeg',
#  'Viral (1613).jpeg',
#  'Viral (1614).jpeg',
#  'Viral (1615).jpeg',
#  'Viral (1616).jpeg',
#  'Viral (1617).jpeg',
#  'Viral (1618).jpeg',
#  'Viral (1619).jpeg',
#  'Viral (162).jpeg',
#  'Viral (162).png',
#  'Viral (1620).jpeg',
#  'Viral (1621).jpeg',
#  'Viral (1622).jpeg',
#  'Viral (1623).jpeg',
#  'Viral (1624).jpeg',
#  'Viral (1625).jpeg',
#  'Viral (1626).jpeg',
#  'Viral (1627).jpeg',
#  'Viral (1628).jpeg',
#  'Viral (1629).jpeg',
#  'Viral (163).jpeg',
#  'Viral (163).png',
#  'Viral (1630).jpeg',
#  'Viral (1631).jpeg',
#  'Viral (1632).jpeg',
#  'Viral (1633).jpeg',
#  'Viral (1634).jpeg',
#  'Viral (1635).jpeg',
#  'Viral (1636).jpeg',
#  'Viral (1637).jpeg',
#  'Viral (1638).jpeg',
#  'Viral (1639).jpeg',
#  'Viral (164).jpeg',
#  'Viral (164).png',
#  'Viral (1640).jpeg',
#  'Viral (1641).jpeg',
#  'Viral (1642).jpeg',
#  'Viral (1643).jpeg',
#  'Viral (1644).jpeg',
#  'Viral (1645).jpeg',
#  'Viral (1646).jpeg',
#  'Viral (1647).jpeg',
#  'Viral (1648).jpeg',
#  'Viral (1649).jpeg',
#  'Viral (165).jpeg',
#  'Viral (165).png',
#  'Viral (1650).jpeg',
#  'Viral (1651).jpeg',
#  'Viral (1652).jpeg',
#  'Viral (1653).jpeg',
#  'Viral (1654).jpeg',
#  'Viral (1655).jpeg',
#  'Viral (1656).jpeg',
#  'Viral (1657).jpeg',
#  'Viral (1658).jpeg',
#  'Viral (1659).jpeg',
#  'Viral (166).jpeg',
#  'Viral (166).png',
#  'Viral (1660).jpeg',
#  'Viral (1661).jpeg',
#  'Viral (1662).jpeg',
#  'Viral (1663).jpeg',
#  'Viral (1664).jpeg',
#  'Viral (1665).jpeg',
#  'Viral (1666).jpeg',
#  'Viral (1667).jpeg',
#  'Viral (1668).jpeg',
#  'Viral (1669).jpeg',
#  'Viral (167).jpeg',
#  'Viral (167).png',
#  'Viral (1670).jpeg',
#  'Viral (1671).jpeg',
#  'Viral (1672).jpeg',
#  'Viral (1673).jpeg',
#  'Viral (1674).jpeg',
#  'Viral (1675).jpeg',
#  'Viral (1676).jpeg',
#  'Viral (1677).jpeg',
#  'Viral (1678).jpeg',
#  'Viral (1679).jpeg',
#  'Viral (168).jpeg',
#  'Viral (168).png',
#  'Viral (1680).jpeg',
#  'Viral (1681).jpeg',
#  'Viral (1682).jpeg',
#  'Viral (1683).jpeg',
#  'Viral (1684).jpeg',
#  'Viral (1685).jpeg',
#  'Viral (1686).jpeg',
#  'Viral (1687).jpeg',
#  'Viral (1688).jpeg',
#  'Viral (1689).jpeg',
#  'Viral (169).jpeg',
#  'Viral (169).png',
#  'Viral (1690).jpeg',
#  'Viral (1691).jpeg',
#  'Viral (1692).jpeg',
#  'Viral (1693).jpeg',
#  'Viral (1694).jpeg',
#  'Viral (1695).jpeg',
#  'Viral (1696).jpeg',
#  'Viral (1697).jpeg',
#  'Viral (1698).jpeg',
#  'Viral (1699).jpeg',
#  'Viral (17).jpeg',
#  'Viral (17).png',
#  'Viral (170).jpeg',
#  'Viral (170).png',
#  'Viral (1700).jpeg',
#  'Viral (1701).jpeg',
#  'Viral (1702).jpeg',
#  'Viral (1703).jpeg',
#  'Viral (1704).jpeg',
#  'Viral (1705).jpeg',
#  'Viral (1706).jpeg',
#  'Viral (1707).jpeg',
#  'Viral (1708).jpeg',
#  'Viral (1709).jpeg',
#  'Viral (171).jpeg',
#  'Viral (171).png',
#  'Viral (1710).jpeg',
#  'Viral (1711).jpeg',
#  'Viral (1712).jpeg',
#  'Viral (1713).jpeg',
#  'Viral (1714).jpeg',
#  'Viral (1715).jpeg',
#  'Viral (1716).jpeg',
#  'Viral (1717).jpeg',
#  'Viral (1718).jpeg',
#  'Viral (1719).jpeg',
#  'Viral (172).jpeg',
#  'Viral (172).png',
#  'Viral (1720).jpeg',
#  'Viral (1721).jpeg',
#  'Viral (1722).jpeg',
#  'Viral (1723).jpeg',
#  'Viral (1724).jpeg',
#  'Viral (1725).jpeg',
#  'Viral (1726).jpeg',
#  'Viral (1727).jpeg',
#  'Viral (1728).jpeg',
#  'Viral (1729).jpeg',
#  'Viral (173).jpeg',
#  'Viral (173).png',
#  'Viral (1730).jpeg',
#  'Viral (1731).jpeg',
#  'Viral (1732).jpeg',
#  'Viral (1733).jpeg',
#  'Viral (1734).jpeg',
#  'Viral (1735).jpeg',
#  'Viral (1736).jpeg',
#  'Viral (1737).jpeg',
#  'Viral (1738).jpeg',
#  'Viral (1739).jpeg',
#  'Viral (174).jpeg',
#  'Viral (174).png',
#  'Viral (1740).jpeg',
#  'Viral (1741).jpeg',
#  'Viral (1742).jpeg',
#  'Viral (1743).jpeg',
#  'Viral (1744).jpeg',
#  'Viral (1745).jpeg',
#  'Viral (1746).jpeg',
#  'Viral (1747).jpeg',
#  'Viral (1748).jpeg',
#  'Viral (1749).jpeg',
#  'Viral (175).jpeg',
#  'Viral (175).png',
#  'Viral (1750).jpeg',
#  'Viral (1751).jpeg',
#  'Viral (1752).jpeg',
#  'Viral (1753).jpeg',
#  'Viral (1754).jpeg',
#  'Viral (1755).jpeg',
#  'Viral (1756).jpeg',
#  'Viral (1757).jpeg',
#  'Viral (1758).jpeg',
#  'Viral (1759).jpeg',
#  'Viral (176).jpeg',
#  'Viral (176).png',
#  'Viral (1760).jpeg',
#  'Viral (1761).jpeg',
#  'Viral (1762).jpeg',
#  'Viral (1763).jpeg',
#  'Viral (1764).jpeg',
#  'Viral (1765).jpeg',
#  'Viral (1766).jpeg',
#  'Viral (1767).jpeg',
#  'Viral (1768).jpeg',
#  'Viral (1769).jpeg',
#  'Viral (177).jpeg',
#  'Viral (177).png',
#  'Viral (1770).jpeg',
#  'Viral (1771).jpeg',
#  'Viral (1772).jpeg',
#  'Viral (1773).jpeg',
#  'Viral (1774).jpeg',
#  'Viral (1775).jpeg',
#  'Viral (1776).jpeg',
#  'Viral (1777).jpeg',
#  'Viral (1778).jpeg',
#  'Viral (1779).jpeg',
#  'Viral (178).jpeg',
#  'Viral (178).png',
#  'Viral (1780).jpeg',
#  'Viral (1781).jpeg',
#  'Viral (1782).jpeg',
#  'Viral (1783).jpeg',
#  'Viral (1784).jpeg',
#  'Viral (1785).jpeg',
#  'Viral (1786).jpeg',
#  'Viral (1787).jpeg',
#  'Viral (1788).jpeg',
#  'Viral (1789).jpeg',
#  'Viral (179).jpeg',
#  'Viral (179).png',
#  'Viral (1790).jpeg',
#  'Viral (1791).jpeg',
#  'Viral (1792).jpeg',
#  'Viral (1793).jpeg',
#  'Viral (1794).jpeg',
#  'Viral (1795).jpeg',
#  'Viral (1796).jpeg',
#  'Viral (1797).jpeg',
#  'Viral (1798).jpeg',
#  'Viral (1799).jpeg',
#  'Viral (18).jpeg',
#  'Viral (18).png',
#  'Viral (180).jpeg',
#  'Viral (180).png',
#  'Viral (1800).jpeg',
#  'Viral (1801).jpeg',
#  'Viral (1802).jpeg',
#  'Viral (1803).jpeg',
#  'Viral (1804).jpeg',
#  'Viral (1805).jpeg',
#  'Viral (1806).jpeg',
#  'Viral (1807).jpeg',
#  'Viral (1808).jpeg',
#  'Viral (1809).jpeg',
#  'Viral (181).jpeg',
#  'Viral (181).png',
#  'Viral (1810).jpeg',
#  'Viral (1811).jpeg',
#  'Viral (1812).jpeg',
#  'Viral (1813).jpeg',
#  'Viral (1814).jpeg',
#  'Viral (1815).jpeg',
#  ...]

# %%
# val 简介
dataloaders['val'].dataset
# Out:
# Dataset ImageFolder
#     Number of datapoints: 700
#     Root location: normalViral/val/
#     StandardTransform
# Transform: Compose(
#                Resize(size=300, interpolation=bilinear, max_size=None, antialias=None)
#                CenterCrop(size=(256, 256))
#                ToTensor()
#                Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
#            )

# %%
# test 简介
dataloaders['test'].dataset
# Out:
# Dataset ImageFolder
#     Number of datapoints: 1400
#     Root location: normalViral/test/
#     StandardTransform
# Transform: Compose(
#                Resize(size=300, interpolation=bilinear, max_size=None, antialias=None)
#                CenterCrop(size=(256, 256))
#                ToTensor()
#                Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
#            )

# %% [markdown]
# ### 提示：需要安装库：tb-nightly
# ### pip3 install tb-nightly

# %%
# 导入SummaryWriter
from torch.utils.tensorboard import SummaryWriter
# SummaryWriter() 向事件文件写入事件和概要

# 定义日志路径
log_path = 'logdir2/'

# 定义函数：获取tensorboard writer
def tb_writer():
    timestr = time.strftime("%Y%m%d_%H%M%S") # 时间格式
    writer = SummaryWriter(log_path+timestr) # 写入日志
    return writer


writer = tb_writer()

# 第1种方法：显示部分图片集
images, labels = next(iter(dataloaders['train'])) # 获取到一批数据

# 定义图片显示方法
def imshow(img):
    img = img / 2 + 0.5 # 逆正则化
    np_img = img.numpy() # tensor --> numpy
    plt.imshow(np.transpose(np_img, (1, 2, 0))) # 改变通道顺序
    plt.show()
    
grid = utils.make_grid(images) # make_grid的作用是将若干幅图像拼成一幅图像
imshow(grid) # 展示图片

# 在summary中添加图片数据
writer.add_image('X-Ray grid', grid, 0) # add_image(tag, img_tensor, global_step=None, walltime=None, dataformats='CHW')

writer.flush() # 把事件文件写入到磁盘
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
# 获取一张图片tensor
dataloaders['train'].dataset[4] # 返回：tensor, label
# Out:
# (tensor([[[-0.3541, -0.3198, -0.3027,  ...,  0.0912,  0.0912,  0.1426],
#           [-0.3541, -0.3198, -0.3198,  ...,  0.1254,  0.0912,  0.1597],
#           [-0.3712, -0.3198, -0.3027,  ...,  0.1426,  0.1426,  0.1426],
#           ...,
#           [ 0.7248,  0.5193,  0.4166,  ..., -1.9638, -1.9638, -1.9638],
#           [ 0.8104,  0.4508,  0.4337,  ..., -1.9638, -1.9638, -1.9638],
#           [ 0.8961,  0.4337,  0.5707,  ..., -1.9638, -1.9638, -1.9638]],
#
#          [[-0.2325, -0.1975, -0.1800,  ...,  0.2227,  0.2227,  0.2752],
#           [-0.2325, -0.1975, -0.1975,  ...,  0.2577,  0.2227,  0.2927],
#           [-0.2500, -0.1975, -0.1800,  ...,  0.2752,  0.2752,  0.2752],
#           ...,
#           [ 0.8704,  0.6604,  0.5553,  ..., -1.8782, -1.8782, -1.8782],
#           [ 0.9580,  0.5903,  0.5728,  ..., -1.8782, -1.8782, -1.8782],
#           [ 1.0455,  0.5728,  0.7129,  ..., -1.8782, -1.8782, -1.8782]],
#
#          [[-0.0092,  0.0256,  0.0431,  ...,  0.4439,  0.4439,  0.4962],
#           [-0.0092,  0.0256,  0.0256,  ...,  0.4788,  0.4439,  0.5136],
#           [-0.0267,  0.0256,  0.0431,  ...,  0.4962,  0.4962,  0.4962],
#           ...,
#           [ 1.0888,  0.8797,  0.7751,  ..., -1.6476, -1.6476, -1.6476],
#           [ 1.1759,  0.8099,  0.7925,  ..., -1.6476, -1.6476, -1.6476],
#           [ 1.2631,  0.7925,  0.9319,  ..., -1.6476, -1.6476, -1.6476]]]),
#  0)

# %%
# 第2种方法：显示一张图片
def show_sample(img, label):
    print("Label : ", dataloaders['train'].dataset.classes[label]) # 输出标签
    img = img.numpy().transpose((1, 2, 0)) # 改变shape顺序
    mean = np.array([0.485, 0.456, 0.406]) # 均值
    std = np.array([0.229, 0.224, 0.225]) # 标准差
    img = img * std + mean # 逆向复原
    img = np.clip(img, 0, 1) # np.clip() 将inp中的元素值限制在(0,1)之间，最小值为0，最大值为1。小于min的等于min，大于max等于max
    plt.imshow(img)
    plt.axis('off') # 关闭坐标轴

show_sample(*dataloaders['train'].dataset[4]) # 显示第5张图片
# Out:
# Label :  Normal

# %%
# 第3种方法：显示一张图片
def show_image(img):
    plt.figure(figsize=(8,8)) # 显示大小
    plt.imshow(img) # 显示图片
    plt.axis('off') # 关闭坐标轴
    plt.show()
    
# 读取图片
one_img = Image.open(dataloaders['train'].dataset.root+'Normal/Normal (100).jpeg')

# 调用函数
show_image(one_img)

# %%
# 记录错误分类的图片
def misclassified_images(pred, writer, target, images, output, epoch, count=10):
    misclassified = (pred != target.data) # 判断是否一致
    for index, image_tensor in enumerate(images[misclassified][:count]):
        img_name = 'Epoch:{}-->Predict:{}-->Actual:{}'.format(epoch, LABEL[pred[misclassified].tolist()[index]],
                                                              LABEL[target.data[misclassified].tolist()[index]])
        writer.add_image(img_name, image_tensor, epoch)

# %%
# 自定义池化层

class AdaptiveConcatPool2d(nn.Module):
    def __init__(self, size=None):
        super(AdaptiveConcatPool2d,self).__init__()
        size = size or (1, 1) # kernel大小
        # 自适应算法能够自动帮助我们计算核的大小和每次移动的步长。
        self.avgPooling = nn.AdaptiveAvgPool2d(size) # 自适应平均池化
        self.maxPooling = nn.AdaptiveMaxPool2d(size) # 最大池化
    def forward(self, x):
        # 拼接avg和max
        return torch.cat([self.maxPooling(x), self.avgPooling(x)], dim=1)

# %%
# 迁移学习：获取预训练模型，并替换池化层和全连接层
# def get_model():
#     # 获取欲训练模型 restnet50
#     model = models.resnet50(pretrained=True) 
#     # 冻结模型参数
#     for param in model.parameters():
#         param.requires_grad = False 
#     # 替换最后2层：池化层和全连接层
#     # 池化层
#     model.avgpool = AdaptiveConcatPool2d()
#     # 全连接层
#     model.fc = nn.Sequential(
#         nn.Flatten(), # 拉平
#         nn.BatchNorm1d(4096), # 加速神经网络的收敛过程，提高训练过程中的稳定性
#         nn.Dropout(0.5), # 丢掉部分神经元
#         nn.Linear(4096, 512), # 全连接层
#         nn.ReLU(), # 激活函数
#         nn.BatchNorm1d(512), 
#         nn.Dropout(0.5),
#         nn.Linear(512, 2), # 2个输出
#         nn.LogSoftmax(dim=1) # 损失函数：将input转换成概率分布的形式，输出2个概率
#     )
#     return model
# def get_model():
#     # 使用VGG-16预训练模型
#     model = models.vgg16(pretrained=True)
#     # 冻结模型参数
#     for param in model.parameters():
#         param.requires_grad = False
#     # 替换最后两层
#     model.avgpool = AdaptiveConcatPool2d()
#     model.classifier = nn.Sequential(
#         nn.Dropout(),
#         nn.Linear(2 * 512, 256),
#         nn.ReLU(inplace=True),
#         nn.Dropout(),
#         nn.Linear(256, 4),
#         nn.LogSoftmax(dim=1)
#     )
#     return model

def get_model():
    # 获取欲训练模型 restnet50
    model = models.resnet101(pretrained=True) 
    # 冻结模型参数
    for param in model.parameters():
        param.requires_grad = False 
    # 替换最后2层：池化层和全连接层
    # 池化层
    model.avgpool = AdaptiveConcatPool2d()
    # 全连接层
    model.fc = nn.Sequential(
        nn.Flatten(), # 拉平
        nn.BatchNorm1d(4096), # 加速神经网络的收敛过程，提高训练过程中的稳定性
        nn.Dropout(0.5), # 丢掉部分神经元
        nn.Linear(4096, 512), # 全连接层
        nn.ReLU(), # 激活函数
        nn.BatchNorm1d(512), 
        nn.Dropout(0.5),
        nn.Linear(512, 2), # 2个输出
        nn.LogSoftmax(dim=1) # 损失函数：将input转换成概率分布的形式，输出2个概率
    )
    return model

# %%
# 定义训练函数
def train_val(model, device, train_loader, val_loader, optimizer, criterion, epoch, writer):
    model.train()
    total_loss = 0.0
    val_loss = 0.0
    val_acc = 0
    for batch_id, (images, labels) in enumerate(train_loader):
        # 部署到device上
        images, labels = images.to(device), labels.to(device)
        # 梯度置0
        optimizer.zero_grad()
        # 模型输出
        outputs = model(images)
        # 计算损失
        loss = criterion(outputs, labels)
        # 反向传播
        loss.backward()
        # 更新参数
        optimizer.step()
        # 累计损失
        total_loss += loss.item() * images.size(0)
    # 平均训练损失
    train_loss = total_loss / len(train_loader.dataset)
    #写入到writer中
    writer.add_scalar('Training Loss', train_loss, epoch)
    # 写入到磁盘
    writer.flush()
    
    model.eval() 
    with torch.no_grad():
        for images, labels in val_loader:
            images, labels = images.to(device), labels.to(device)
            outputs = model(images) # 前向传播输出
            loss = criterion(outputs, labels) # 损失
            val_loss += loss.item() * images.size(0) # 累计损失
            _, pred = torch.max(outputs, dim=1) # 获取最大概率的索引
            correct = pred.eq(labels.view_as(pred)) # 返回：tensor([ True,False,True,...,False])
            accuracy = torch.mean(correct.type(torch.FloatTensor)) # 准确率
            val_acc += accuracy.item() * images.size(0) # 累计准确率
        # 平均验证损失
        val_loss = val_loss / len(val_loader.dataset)
        # 平均准确率
        val_acc = val_acc / len(val_loader.dataset)
        
    return train_loss, val_loss, val_acc

# %%
# 定义测试函数
def test(model, device, test_loader, criterion, epoch, writer):
    model.eval()
    total_loss = 0.0
    correct = 0.0 # 正确数
    with torch.no_grad():
        for batch_id, (images, labels) in enumerate(test_loader):
            images, labels = images.to(device), labels.to(device)
            # 输出
            outputs = model(images)
            # 损失
            loss = criterion(outputs, labels)
            # 累计损失
            total_loss += loss.item()
            # 获取预测概率最大值的索引
            _, predicted = torch.max(outputs, dim=1)
            # 累计正确预测的数
            correct += predicted.eq(labels.view_as(predicted)).sum().item()
            # 错误分类的图片
            misclassified_images(predicted, writer, labels, images, outputs, epoch)
        # 平均损失
        avg_loss = total_loss / len(test_loader.dataset)
        # 计算正确率
        accuracy = 100 * correct / len(test_loader.dataset)
        # 将test的结果写入write
        writer.add_scalar("Test Loss", total_loss, epoch)
        writer.add_scalar("Accuracy", accuracy, epoch)
        writer.flush()
        return total_loss, accuracy

# %%
# 定义训练流程

# 是否有GPU
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

print(device.type)

# 模型部署到device
model = get_model().to(device)

# 损失函数
criterion = nn.NLLLoss()

# 优化器
optimizer = optim.SGD(model.parameters(), lr=0.001)

# 定义训练流程函数
def train_epochs(model, device, dataloaders, criterion, optimizer, epochs, writer):
    # 输出信息
    print("{0:>15} | {1:>15} | {2:>15} | {3:>15} | {4:>15} | {5:>15}".format('Epoch', 'Train Loss', 'val_loss', 'val_acc', 'Test Loss', 'Test_acc'))
    # 初始最小的损失
    best_loss = np.inf
    # 开始训练、测试
    for epoch in range(epochs):
        # 训练，return: loss
        train_loss, val_loss, val_acc = train_val(model, device, dataloaders['train'], dataloaders['val'], optimizer, criterion, epoch, writer)
        # 测试，return: loss + accuracy
        test_loss, test_acc = test(model, device, dataloaders['test'], criterion, epoch, writer)
        # 判断损失是否最小
        if test_loss < best_loss:
            best_loss = test_loss # 保存最小损失
            # 保存模型
            torch.save(model.state_dict(), 'model3.pth')
        # 输出结果
        print("{0:>15} | {1:>15} | {2:>15} | {3:>15} | {4:>15} | {5:>15}".format(epoch, train_loss, val_loss, val_acc, test_loss, test_acc))
        writer.flush()
# Out:
# cuda
# E:\ProgramData\Anaconda3\envs\my_en3.7\lib\site-packages\torchvision\models\_utils.py:209: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and will be removed in 0.15, please use 'weights' instead.
#   f"The parameter '{pretrained_param}' is deprecated since 0.13 and will be removed in 0.15, "
# E:\ProgramData\Anaconda3\envs\my_en3.7\lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and will be removed in 0.15. The current behavior is equivalent to passing `weights=ResNet101_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet101_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)

# %%
# 调用函数
epochs=40
train_epochs(model, device, dataloaders, criterion, optimizer, epochs, writer)
writer.close()
# Out:
#           Epoch |      Train Loss |        val_loss |         val_acc |       Test Loss |        Test_acc
#               0 | 0.6587803784370423 | 0.3787615406513214 | 0.8885714268684387 | 4.507279872894287 | 85.07142857142857
#               1 | 0.49571600971221924 | 0.2751206363098962 | 0.9242857146263123 | 3.322146475315094 | 90.78571428571429
#               2 | 0.42111639637947085 | 0.2519848442077637 | 0.9228571435383388 | 2.9102980941534042 | 91.57142857142857
#               3 | 0.3865403036117554 | 0.23042807408741542 | 0.9385714275496346 | 2.649502918124199 | 92.85714285714286
#               4 | 0.36502979249954226 | 0.21488057255744933 | 0.9357142846924918 | 2.439230114221573 | 92.64285714285714
#               5 | 0.34107436120510104 | 0.213023048383849 | 0.9414285690443857 | 2.3297402411699295 | 93.57142857142857
#               6 | 0.3301137840270996 | 0.21275091750281197 | 0.9328571445601327 | 2.3174550980329514 |            93.0
#               7 | 0.33442560960054396 | 0.20494693909372602 | 0.9414285690443857 | 2.2026086300611496 | 93.57142857142857
#               8 | 0.3076073441028595 | 0.2065783831051418 | 0.9385714302744185 | 2.1795156002044678 | 93.28571428571429
#               9 | 0.30930229115486146 | 0.1915049605710166 | 0.9428571445601327 | 2.041449189186096 |            93.5
#              10 | 0.30056552538871767 | 0.190819967176233 | 0.9399999976158142 | 2.017422303557396 |            94.0
#              11 | 0.29448813700675963 | 0.19990146781717028 | 0.9357142860548837 | 2.0405751317739487 | 93.85714285714286
#              12 | 0.2934093302249908 | 0.20155221138681684 | 0.9357142860548837 | 2.0781928300857544 | 93.35714285714286
#              13 | 0.2853375781536102 | 0.19007456294127872 | 0.9428571404729571 | 1.9682993665337563 | 94.07142857142857
#              14 | 0.28745523433685305 | 0.19003861461366925 | 0.9400000006811959 | 1.9663903415203094 | 93.85714285714286
#              15 | 0.2860895119190216 | 0.18534346010003772 | 0.9428571404729571 | 1.9094376116991043 |            94.0
#              16 | 0.28182691609859467 | 0.19682946911879948 | 0.9399999989782061 | 1.9575766324996948 | 93.71428571428571
#              17 | 0.2722463938713074 | 0.18875928457294192 | 0.9400000013623919 | 1.9426453709602356 | 93.85714285714286
#              18 | 0.2781604249477386 | 0.19107704784188953 | 0.9357142836706979 | 1.9107019007205963 | 93.92857142857143
#              19 | 0.2726216107845306 | 0.18804870243583408 | 0.9400000003405979 | 1.9025475457310677 | 93.92857142857143
#              20 | 0.27179842249155045 | 0.1850986249106271 | 0.9400000003405979 | 1.8930824548006058 | 93.85714285714286
#              21 | 0.25977641587257383 | 0.17833759656974246 | 0.9400000003405979 | 1.8272235095500946 | 94.07142857142857
#              22 | 0.25865331296920774 | 0.18583949651036943 | 0.9414285717691694 | 1.8232467025518417 | 94.42857142857143
#              23 | 0.26650448904037477 | 0.18718208632298877 | 0.9342857142857143 | 1.8221169710159302 | 94.42857142857143
#              24 | 0.267727645111084 | 0.18382465754236493 | 0.9414285693849836 | 1.8048706650733948 | 94.28571428571429
#              25 | 0.25426737513542175 | 0.17984376089913504 | 0.9414285690443857 | 1.7691160142421722 |            94.5
#              26 | 0.25787157928347587 | 0.18126984766551427 | 0.9328571449007307 | 1.768426962196827 | 94.78571428571429
#              27 | 0.2721345487356186 | 0.17627260778631482 | 0.9414285693849836 | 1.7337249368429184 | 94.14285714285714
#              28 | 0.2668628768920898 | 0.17411070568220957 | 0.9442857142857143 | 1.7055754885077477 | 94.42857142857143
#              29 | 0.26036708960533145 | 0.18911035733563558 | 0.9385714275496346 | 1.814685732126236 | 94.21428571428571
#              30 | 0.2555415404319763 | 0.18256785333156586 | 0.9414285704067775 | 1.7672018632292747 | 94.21428571428571
#              31 | 0.24862927817702293 | 0.17844514736107417 | 0.9399999993188041 | 1.7316985726356506 | 94.57142857142857
#              32 | 0.24559608256816864 | 0.18239878824778966 | 0.9371428550992693 | 1.7287135496735573 | 94.64285714285714
#              33 | 0.2562836235046387 | 0.19037735436643874 | 0.9328571445601327 | 1.774664729833603 |            94.5
#              34 | 0.2562412588596344 | 0.18940413611275808 | 0.9371428574834552 | 1.7700286582112312 |            94.5
#              35 | 0.24429093146324157 | 0.19551526512418474 | 0.9257142836706979 | 1.8588494658470154 |            94.0
#              36 | 0.24937585525512695 | 0.1891116740022387 | 0.9285714265278407 | 1.789970025420189 | 94.14285714285714
#              37 | 0.23989284648895265 | 0.19278173412595476 | 0.9328571445601327 | 1.7898580729961395 | 94.35714285714286
#              38 | 0.24405490398406982 | 0.1791664399419512 | 0.9400000017029898 | 1.7169761210680008 |            94.5
#              39 | 0.2436193413734436 | 0.17146334618330003 | 0.9442857132639204 | 1.6838315427303314 | 94.28571428571429

# %%
# import cv2


# # 定义 Grad-CAM 类
# class GradCAM:
#     def __init__(self, model, target_layer):
#         self.model = model
#         self.target_layer = target_layer
#         self.feature_maps = None
#         self.gradient = None

#     def save_gradient(self, gradient):
#         self.gradient = gradient
        
#     def __call__(self, input):
#         # 调整维度
#         input = input.squeeze(0)
#         input = torch.transpose(input, 0, 1)

#         # 前向传播，记录目标层的特征图
#         for name, module in self.model.named_modules():
#             input = module(input)
#             if name == self.target_layer:
#                 input.register_hook(self.save_gradient)
#                 self.feature_maps = input.detach()
#         output = input

#         # 反向传播，计算梯度
#         output.backward(torch.ones_like(output))
#         # 计算梯度加权特征图
#         gradients = self.gradient.detach().cpu().numpy()[0]
#         weights = np.mean(gradients, axis=(1, 2), keepdims=True)
#         cam = np.sum(weights * self.feature_maps.cpu().numpy()[0], axis=0)
#         cam = np.maximum(cam, 0)  # ReLU
#         cam = cv2.resize(cam, input.shape[1:])  # 调整特征图尺寸
#         cam = cam - np.min(cam)  # 线性规范化
#         cam = cam / np.max(cam)

#         return cam


#     def __call__(self, x):
#         # 前向传播，记录目标层的特征图
#         for name, module in self.model.named_modules():
#             x = module(x)
#             if name == self.target_layer:
#                 x.register_hook(self.save_gradient)
#                 self.feature_maps = x.detach()
#         output = x
#         # 反向传播，计算梯度
#         output.backward(torch.ones_like(output))
#         # 计算梯度加权特征图
#         gradients = self.gradient.detach().cpu().numpy()[0]
#         weights = np.mean(gradients, axis=(1, 2), keepdims=True)
#         cam = np.sum(weights * self.feature_maps.cpu().numpy()[0], axis=0)
#         cam = np.maximum(cam, 0)  # ReLU
#         cam = cv2.resize(cam, x.shape[2:])  # 调整特征图尺寸
#         cam = cam - np.min(cam)  # 线性规范化
#         cam = cam / np.max(cam)
#         return cam

# 获取模型
# model = get_model()
# # 加载预训练权重
# model.load_state_dict(torch.load('model2.pth', map_location=torch.device('cpu')))
# # 设置为评估模式
# model.eval()
# # 定义 Grad-CAM 对象
# grad_cam = GradCAM(model, 'layer4') # 这里选择 ResNet50 的 layer4 层作为目标层

# # 加载目标图像并预处理
# image = cv2.imread('newDataset_binary/train/BacterialPneumonia/101.jpeg')
# image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
# image = cv2.resize(image, (224, 224))
# image = image / 255.
# image = (image - [0.485, 0.456, 0.406]) / [0.229, 0.224, 0.225]
# image = np.transpose(image, (2, 0, 1))
# image = np.expand_dims(image, axis=0)
# image = torch.from_numpy(image).float()

# # 使用 Grad-CAM 进行可视化
# with torch.set_grad_enabled(True):
#     output = model(image)
#     _, pred = output.max(dim=1)
#     cam = grad_cam(image)
#     cam = cv2.resize(cam, (224, 224))
#     heatmap = cv2.applyColorMap(np.uint8(255*cam), cv2.COLORMAP_JET)
#     heatmap = np.float32(heatmap) / 255
#     cam_on_image = heatmap + np.float32(cv2.cvtColor(np.uint8(255*image[0].permute(1,2,0).cpu().numpy()), cv2.COLOR_BGR2RGB))
#     cam_on_image = cam_on_image / np.max(cam_on_image)

# # 显示结果
# import matplotlib.pyplot as plt
# plt.imshow(cam_on_image)
# plt.axis('off')
# plt.show()

# %%
# import cv2
# import numpy as np
# import torch
# from torchvision import models, transforms
# from torch.nn import functional as F
# from matplotlib import pyplot as plt

# # 定义Grad-CAM可视化函数
# class GradCam:
#     def __init__(self, model, target_layer_names):
#         self.model = model
#         self.target_layer_names = target_layer_names
#         self.feature_maps = []
#         self.gradient_maps = []
#         self.model.eval()
#         self.handlers = []
#         for name in self.target_layer_names:
#             self.handlers.append(
#                 self.register_hook(self.model._modules.get(name))
#             )

#     def register_hook(self, module):
#         def hook(module, input, output):
#             self.feature_maps.append(output.cpu().data.numpy())

#         return module.register_forward_hook(hook)

#     def remove_handlers(self):
#         for handle in self.handlers:
#             handle.remove()

#     def __call__(self, x):
#         self.feature_maps = []
#         self.gradient_maps = []
#         self.handlers = []
#         for name in self.target_layer_names:
#             self.handlers.append(
#                 self.register_hook(self.model._modules.get(name))
#             )

#         outputs = self.model(x)
#         one_hot = outputs.detach().zero_()
#         one_hot[0][torch.argmax(outputs)] = 1
#         one_hot.requires_grad = True
#         one_hot = torch.sum(one_hot * outputs)

#         self.model.zero_grad()
#         one_hot.backward(retain_graph=True)

#         self.gradient_maps = []
#         for i, name in enumerate(self.target_layer_names):
#             gradient_map = (
#                 self.feature_maps[i][0] * self.gradient_maps[-1]
#                 if len(self.gradient_maps) > 0
#                 else self.feature_maps[i][0]
#             )
#             self.gradient_maps.append(gradient_map)

#         self.remove_handlers()
#         return self.gradient_maps[-1]

# # 定义输入图像预处理函数
# def preprocess_image(img_path):
#     img = cv2.imread(img_path)
#     img = cv2.resize(img, (224, 224))
#     img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
#     img_tensor = transforms.ToTensor()(img)
#     img_tensor = transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])(img_tensor)
#     img_tensor = img_tensor.unsqueeze(0)
#     return img_tensor

# # 加载模型
# model = get_model()
# # 加载图像
# img_tensor = preprocess_image('newDataset_binary/train/BacterialPneumonia/101.jpeg')
# # 运行Grad-CAM可视化
# torch.autograd.set_detect_anomaly(True)
# cam = GradCam(model, ['layer4'])
# grad_cam = cam(img_tensor)
# # 将可视化结果转换为热力图
# grad_cam = np.mean(grad_cam, axis=(1, 2), keepdims=True)
# grad_cam = np.maximum(grad_cam, 0)
# grad_cam = grad_cam / grad_cam.max()
# # 将热力图叠加到原始图像上
# img = cv2.imread(dataloaders['train'].dataset.root+'BacterialPneumonia/101.jpeg')
# grad_cam = cv2.resize(grad_cam[0], (img.shape[1], img.shape[0]))
# grad_cam = cv2.applyColorMap(np.uint8(255 * grad_cam), cv2.COLORMAP_JET)
# output_image = cv2.addWeighted(img, 0.8, grad_cam, 0.4, 0)
# # 显示结果
# plt.imshow(output_image[...,::-1])
# plt.axis('off')
# plt

# %%
def plot_confusion(cm):
    plt.figure()
    plot_confusion_matrix(cm, figsize=(12, 8), cmap=plt.cm.Blues) # 参数设置
    plt.xticks(range(2), ['Normal', 'Viral'], fontsize=14)
    plt.yticks(range(2), ['Normal', 'Viral'], fontsize=14)
    plt.xlabel('Predicted Label', fontsize=16)
    plt.ylabel('True Label', fontsize=16)
    plt.show()

# %%
# def accuracy(outputs, labels):
#     # 计算正确率
#     _, preds = torch.max(outputs, dim=1)
#     correct = torch.tensor(torch.sum(preds == labels).item() / len(preds))
#     return correct

# %%
# def metrics(outputs, labels):
#     _, preds = torch.max(outputs, dim=1)
#     # precision, recall, F1
#     # 混淆矩阵
#     cm = confusion_matrix(labels.cpu().numpy(), preds.cpu().numpy())
#     # 绘制混淆矩阵
#     plot_confusion(cm) 
#     # 获取tn, fp, fn, tp
# #     tn, fp, fn, tp = cm.ravel()
#     fp = cm.sum(axis=0) - np.diag(cm)
#     fn = cm.sum(axis=1) - np.diag(cm)
#     tp = np.diag(cm)
#     tn = cm.sum() - (fp + fn + tp)
#     print(tn)
#     print(fp)
#     # 精准率
#     precision = tp / (tp + fp)
#     # 召回率
#     recall = tp / (tp + fn)
#     # f1 score
#     f1 = 2 * ((precision * recall) / (precision + recall))
#     return precision, recall, f1

# %%
all_preds = []
all_labels = []

with torch.no_grad():
    model.eval()
    for datas, labels in dataloaders['test']:
        datas, labels = datas.to(device), labels.to(device)
        # 预测输出 前向传播
        outputs = model(datas)
        _, preds = torch.max(outputs, dim=1)
#     将预测结果和真实标签添加到列表中
        all_preds.extend(preds.cpu().numpy())
        all_labels.extend(labels.cpu().numpy())
        # precision, recall, F1
        # 混淆矩阵
    cm = confusion_matrix(all_labels, all_preds)
    # 绘制混淆矩阵
    plot_confusion(cm) 
#     fp = cm.sum(axis=0) - np.diag(cm)
#     fn = cm.sum(axis=1) - np.diag(cm)
#     tp = np.diag(cm)
#     tn = cm.sum() - (fp + fn + tp)
    tn, fp, fn, tp = cm.ravel()
    # 精准率
    precision = tp / (tp + fp)
    # 召回率
    recall = tp / (tp + fn)
    # f1 score
    f1 = 2 * ((precision * recall) / (precision + recall))
    num_correct = 0
    num_total = len(all_labels)
    for pred, label in zip(all_preds, all_labels):
        if pred == label:
            num_correct += 1
            acc = num_correct / num_total
#     acc = torch.tensor(torch.sum(all_preds == all_labels.data).item() / len(all_preds))
    print(precision)
    print(recall)
    print(f1)
    print(acc)

# with torch.no_grad():
#     model.eval()
#     for datas, labels in dataloaders['val']:
#         datas, labels = datas.to(device), labels.to(device)
#         # 预测输出
#         outputs = model(datas)
#         # 计算metrics
#         precision, recall, f1 = metrics(outputs, labels)
#         acc = accuracy(outputs, labels)
#         # 保存结果
#         precisions.append(precision)
#         recalls.append(recall)
#         f1s.append(f1)
#         accuracies.append(acc.item())
#         print(precisions)
#         print(recalls)
# Out:
# 0.9378531073446328
# 0.9485714285714286
# 0.9431818181818182
# 0.9428571428571428

# %%
# ['{:.2f}%'.format(pre*100) for pre in precisions]# 精准率 precision

# %%
# ['{:.2f}%'.format(r*100) for r in recalls]# 召回率 recall

# %%
# ['{:.2f}%'.format(f*100) for f in f1s]# f1

# %%
# ['{:.2f}%'.format(a*100) for a in accuracies]# 准确率 accuracy
