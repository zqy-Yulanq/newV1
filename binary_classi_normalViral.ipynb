# %%
# 导入必要的库
import torch
import torch.nn as nn
import numpy as np
import torch.optim as optim
from torchvision import transforms, datasets, models, utils
from torchsummary import summary # 可视化训练过程
from torch.utils.data import DataLoader
import time
import matplotlib.pyplot as plt
import os
import seaborn as sns
import pandas as pd
from mlxtend.plotting import plot_confusion_matrix
from sklearn.metrics import confusion_matrix
from PIL import Image

# %%
# 分为为train, val, test定义transform
image_transforms = {
    'train' : transforms.Compose([
        transforms.RandomResizedCrop(size=300, scale=(0.8, 1.1)), #功能：随机长宽比裁剪原始图片, 表示随机crop出来的图片会在的0.08倍至1.1倍之间
        transforms.RandomRotation(degrees=10), #功能：根据degrees随机旋转一定角度, 则表示在（-10，+10）度之间随机旋转
        transforms.ColorJitter(0.4, 0.4, 0.4), #功能：修改亮度、对比度和饱和度
        transforms.RandomHorizontalFlip(), #功能：水平翻转
        transforms.CenterCrop(size=256), #功能：根据给定的size从中心裁剪，size - 若为sequence,则为(h,w)，若为int，则(size,size)
        transforms.ToTensor(), #numpy --> tensor
        # 功能：对数据按通道进行标准化（RGB），即先减均值，再除以标准差
        transforms.Normalize([0.485, 0.456, 0.406],# mean
                             [0.229, 0.224, 0.225])# std 
    ]),
    
    'val' : transforms.Compose([
        transforms.Resize(300),
        transforms.CenterCrop(256),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406],# mean
                             [0.229, 0.224, 0.225])# std 
    ]),
    
    'test' : transforms.Compose([
        transforms.Resize(300),
        transforms.CenterCrop(256),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406],# mean
                             [0.229, 0.224, 0.225])# std 
    ])
}

# %%
# 加载数据集

# 数据集所在目录路径
data_dir = 'normalViral/'
# train路径
train_dir = data_dir + 'train/'
# val路径
val_dir = data_dir + 'val/'
# test路径
test_dir = data_dir + 'test/'

# 从文件中读取数据
datasets = {
    'train' : datasets.ImageFolder(train_dir, transform=image_transforms['train']), # 读取train中的数据集，并transform
    'val' : datasets.ImageFolder(val_dir, transform=image_transforms['val']),  # 读取val中的数据集，并transform
    'test' : datasets.ImageFolder(test_dir, transform=image_transforms['test']) #  读取test中的数据集，并transform
}

# 定义BATCH_SIZE
BATCH_SIZE = 128 # 每批读取128张图片

# DataLoader : 创建iterator, 按批读取数据
dataloaders = {
    'train' : DataLoader(datasets['train'], batch_size=BATCH_SIZE, shuffle=True), # 训练集
    'val' : DataLoader(datasets['val'], batch_size=BATCH_SIZE, shuffle=True), # 验证集
    'test' : DataLoader(datasets['test'], batch_size=BATCH_SIZE, shuffle=True) # 测试集
}

# 创建label的键值对
LABEL = dict((v, k) for k, v in datasets['train'].class_to_idx.items())

LABEL
# Out:
# {0: 'Normal', 1: 'Viral'}

# %%
# train 简介
dataloaders['train'].dataset
# Out:
# Dataset ImageFolder
#     Number of datapoints: 6235
#     Root location: normalViral/train/
#     StandardTransform
# Transform: Compose(
#                RandomResizedCrop(size=(300, 300), scale=(0.8, 1.1), ratio=(0.75, 1.3333), interpolation=bilinear)
#                RandomRotation(degrees=[-10.0, 10.0], interpolation=nearest, expand=False, fill=0)
#                ColorJitter(brightness=[0.6, 1.4], contrast=[0.6, 1.4], saturation=[0.6, 1.4], hue=None)
#                RandomHorizontalFlip(p=0.5)
#                CenterCrop(size=(256, 256))
#                ToTensor()
#                Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
#            )

# %%
dataloaders['train'].dataset.classes # train下的类别
# Out:
# ['Normal', 'Viral']

# %%
dataloaders['train'].dataset.root # train的路径
# Out:
# 'normalViral/train/'

# %%
# 肺部细菌感染的图片
files_normal_pneumonia = os.listdir(os.path.join(str(dataloaders['train'].dataset.root), 'Normal'))
files_normal_pneumonia
# Out:
# ['Normal (881).png',
#  'Normal (599).png',
#  'Normal (635).png',
#  'Normal (18).jpeg',
#  'Normal (751).png',
#  'Normal (1592).png',
#  'Normal (238).jpeg',
#  'Normal (1066).jpeg',
#  'Normal (1675).png',
#  'Normal (1711).png',
#  'Normal (1085).png',
#  'Normal (173).jpeg',
#  'Normal (470).jpeg',
#  'Normal (1329).png',
#  'Normal (1009).jpeg',
#  'Normal (246).png',
#  'Normal (322).png',
#  'Normal (754).jpeg',
#  'Normal (1206).png',
#  'Normal (1362).png',
#  'Normal (257).jpeg',
#  'Normal (369).png',
#  'Normal (851).jpeg',
#  'Normal (77).jpeg',
#  'Normal (380).png',
#  'Normal (148).png',
#  'Normal (1143).png',
#  'Normal (1027).png',
#  'Normal (573).jpeg',
#  'Normal (103).png',
#  'Normal (952).jpeg',
#  'Normal (1108).png',
#  'Normal (657).jpeg',
#  'Normal (354).jpeg',
#  'Normal (638).jpeg',
#  'Normal (1530).png',
#  'Normal (1454).png',
#  'Normal (697).png',
#  'Normal (947).png',
#  'Normal (1241).jpeg',
#  'Normal (823).png',
#  'Normal (46).png',
#  'Normal (570).png',
#  'Normal (414).png',
#  'Normal (1165).jpeg',
#  'Normal (868).png',
#  'Normal (1198).jpeg',
#  'Normal (1028).jpeg',
#  'Normal (132).png',
#  'Normal (1295).png',
#  'Normal (152).jpeg',
#  'Normal (451).jpeg',
#  'Normal (1139).png',
#  'Normal (870).jpeg',
#  'Normal (179).png',
#  'Normal (56).jpeg',
#  'Normal (1016).png',
#  'Normal (775).jpeg',
#  'Normal (1172).png',
#  'Normal (788).jpeg',
#  'Normal (276).jpeg',
#  'Normal (77).png',
#  'Normal (1782).png',
#  'Normal (219).jpeg',
#  'Normal (789).png',
#  'Normal (425).png',
#  'Normal (859).png',
#  'Normal (39).jpeg',
#  'Normal (541).png',
#  'Normal (1465).png',
#  'Normal (1501).png',
#  'Normal (812).png',
#  'Normal (1047).jpeg',
#  'Normal (976).png',
#  'Normal (487).png',
#  'Normal (1260).jpeg',
#  'Normal (619).jpeg',
#  'Normal (1720).png',
#  'Normal (1644).png',
#  'Normal (760).png',
#  'Normal (1144).jpeg',
#  'Normal (604).png',
#  'Normal (1353).png',
#  'Normal (552).jpeg',
#  'Normal (1237).png',
#  'Normal (190).png',
#  'Normal (358).png',
#  'Normal (1318).png',
#  'Normal (676).jpeg',
#  'Normal (388).jpeg',
#  'Normal (375).jpeg',
#  'Normal (313).png',
#  'Normal (973).jpeg',
#  'Normal (277).png',
#  'Normal (447).png',
#  'Normal (1291).jpeg',
#  'Normal (910).jpeg',
#  'Normal (523).png',
#  'Normal (615).jpeg',
#  'Normal (1528).png',
#  'Normal (1684).png',
#  'Normal (316).jpeg',
#  'Normal (15).png',
#  'Normal (1148).jpeg',
#  'Normal (870).png',
#  'Normal (914).png',
#  'Normal (568).png',
#  'Normal (1407).png',
#  'Normal (531).jpeg',
#  'Normal (1563).png',
#  'Normal (1393).png',
#  'Normal (1127).jpeg',
#  'Normal (150).png',
#  'Normal (398).png',
#  'Normal (384).jpeg',
#  'Normal (1074).png',
#  'Normal (687).jpeg',
#  'Normal (379).jpeg',
#  'Normal (1110).png',
#  'Normal (1203).jpeg',
#  'Normal (982).jpeg',
#  'Normal (1024).jpeg',
#  'Normal (1).png',
#  'Normal (1331).png',
#  'Normal (1255).png',
#  'Normal (371).png',
#  'Normal (881).jpeg',
#  'Normal (1300).jpeg',
#  'Normal (215).png',
#  'Normal (779).jpeg',
#  'Normal (287).jpeg',
#  'Normal (784).jpeg',
#  'Normal (1742).png',
#  'Normal (716).jpeg',
#  'Normal (1626).png',
#  'Normal (215).jpeg',
#  'Normal (749).png',
#  'Normal (813).jpeg',
#  'Normal (581).png',
#  'Normal (35).jpeg',
#  'Normal (899).png',
#  'Normal (131).jpeg',
#  'Normal (1709).png',
#  'Normal (432).jpeg',
#  'Normal (702).png',
#  'Normal (666).png',
#  'Normal (1106).jpeg',
#  'Normal (224).png',
#  'Normal (340).png',
#  'Normal (188).png',
#  'Normal (582).jpeg',
#  'Normal (1183).png',
#  'Normal (1222).jpeg',
#  'Normal (1264).png',
#  'Normal (1300).png',
#  'Normal (358).jpeg',
#  'Normal (634).jpeg',
#  'Normal (1738).png',
#  'Normal (1494).png',
#  'Normal (337).jpeg',
#  'Normal (657).png',
#  'Normal (931).jpeg',
#  'Normal (733).png',
#  'Normal (987).png',
#  'Normal (510).jpeg',
#  'Normal (1617).png',
#  'Normal (86).png',
#  'Normal (1773).png',
#  'Normal (1169).jpeg',
#  'Normal (778).png',
#  'Normal (1194).jpeg',
#  'Normal (925).png',
#  'Normal (832).jpeg',
#  'Normal (559).png',
#  'Normal (841).png',
#  'Normal (791).png',
#  'Normal (14).jpeg',
#  'Normal (1552).png',
#  'Normal (1436).png',
#  'Normal (737).jpeg',
#  'Normal (234).jpeg',
#  'Normal (512).png',
#  'Normal (1097).jpeg',
#  'Normal (476).png',
#  'Normal (24).png',
#  'Normal (110).jpeg',
#  'Normal (1519).png',
#  'Normal (413).jpeg',
#  'Normal (1121).png',
#  'Normal (481).jpeg',
#  'Normal (1045).png',
#  'Normal (182).jpeg',
#  'Normal (1005).jpeg',
#  'Normal (286).png',
#  'Normal (758).jpeg',
#  'Normal (86).jpeg',
#  'Normal (161).png',
#  'Normal (1321).jpeg',
#  'Normal (1012).png',
#  'Normal (763).jpeg',
#  'Normal (1176).png',
#  'Normal (260).jpeg',
#  'Normal (866).jpeg',
#  'Normal (40).jpeg',
#  'Normal (1291).png',
#  'Normal (144).jpeg',
#  'Normal (1059).png',
#  'Normal (447).jpeg',
#  'Normal (136).png',
#  'Normal (816).png',
#  'Normal (1051).jpeg',
#  'Normal (972).png',
#  'Normal (1461).png',
#  'Normal (1505).png',
#  'Normal (428).jpeg',
#  'Normal (38).png',
#  'Normal (809).jpeg',
#  'Normal (421).png',
#  'Normal (939).png',
#  'Normal (545).png',
#  'Normal (73).png',
#  'Normal (1786).png',
#  'Normal (764).png',
#  'Normal (1152).jpeg',
#  'Normal (600).png',
#  'Normal (1488).png',
#  'Normal (1724).png',
#  'Normal (1640).png',
#  'Normal (483).png',
#  'Normal (1276).jpeg',
#  'Normal (317).png',
#  'Normal (965).jpeg',
#  'Normal (273).png',
#  'Normal (1219).jpeg',
#  'Normal (998).jpeg',
#  'Normal (660).jpeg',
#  'Normal (1278).png',
#  'Normal (363).jpeg',
#  'Normal (194).png',
#  'Normal (238).png',
#  'Normal (1357).png',
#  'Normal (544).jpeg',
#  'Normal (1233).png',
#  'Normal (1671).png',
#  'Normal (1715).png',
#  'Normal (409).jpeg',
#  'Normal (1070).jpeg',
#  'Normal (1596).png',
#  'Normal (885).png',
#  'Normal (828).jpeg',
#  'Normal (631).png',
#  'Normal (755).png',
#  'Normal (209).png',
#  'Normal (847).jpeg',
#  'Normal (61).jpeg',
#  'Normal (1202).png',
#  'Normal (1366).png',
#  'Normal (742).jpeg',
#  'Normal (241).jpeg',
#  'Normal (242).png',
#  'Normal (326).png',
#  'Normal (1081).png',
#  'Normal (165).jpeg',
#  'Normal (1249).png',
#  'Normal (198).jpeg',
#  'Normal (466).jpeg',
#  'Normal (641).jpeg',
#  'Normal (1068).png',
#  'Normal (342).jpeg',
#  'Normal (107).png',
#  'Normal (944).jpeg',
#  'Normal (1238).jpeg',
#  'Normal (598).jpeg',
#  'Normal (565).jpeg',
#  'Normal (1147).png',
#  'Normal (1023).png',
#  'Normal (384).png',
#  'Normal (1173).jpeg',
#  'Normal (908).png',
#  'Normal (574).png',
#  'Normal (410).png',
#  'Normal (42).png',
#  'Normal (693).png',
#  'Normal (943).png',
#  'Normal (1257).jpeg',
#  'Normal (827).png',
#  'Normal (1698).png',
#  'Normal (1534).png',
#  'Normal (1450).png',
#  'Normal (1260).png',
#  'Normal (1304).png',
#  'Normal (948).jpeg',
#  'Normal (1234).jpeg',
#  'Normal (594).jpeg',
#  'Normal (1187).png',
#  'Normal (569).jpeg',
#  'Normal (220).png',
#  'Normal (344).png',
#  'Normal (1110).jpeg',
#  'Normal (618).png',
#  'Normal (1182).jpeg',
#  'Normal (1613).png',
#  'Normal (82).png',
#  'Normal (1777).png',
#  'Normal (506).jpeg',
#  'Normal (653).png',
#  'Normal (927).jpeg',
#  'Normal (737).png',
#  'Normal (983).png',
#  'Normal (1658).png',
#  'Normal (622).jpeg',
#  'Normal (321).jpeg',
#  'Normal (1490).png',
#  'Normal (20).png',
#  'Normal (106).jpeg',
#  'Normal (405).jpeg',
#  'Normal (1479).png',
#  'Normal (516).png',
#  'Normal (1081).jpeg',
#  'Normal (472).png',
#  'Normal (721).jpeg',
#  'Normal (1556).png',
#  'Normal (1432).png',
#  'Normal (222).jpeg',
#  'Normal (921).png',
#  'Normal (824).jpeg',
#  'Normal (439).png',
#  'Normal (845).png',
#  'Normal (795).png',
#  'Normal (90).jpeg',
#  'Normal (165).png',
#  'Normal (1337).jpeg',
#  'Normal (1013).jpeg',
#  'Normal (282).png',
#  'Normal (1125).png',
#  'Normal (169).jpeg',
#  'Normal (497).jpeg',
#  'Normal (1041).png',
#  'Normal (194).jpeg',
#  'Normal (1289).png',
#  'Normal (1403).png',
#  'Normal (527).jpeg',
#  'Normal (1567).png',
#  'Normal (408).png',
#  'Normal (874).png',
#  'Normal (910).png',
#  'Normal (1448).png',
#  'Normal (603).jpeg',
#  'Normal (1680).png',
#  'Normal (300).jpeg',
#  'Normal (11).png',
#  'Normal (443).png',
#  'Normal (906).jpeg',
#  'Normal (1287).jpeg',
#  'Normal (527).png',
#  'Normal (969).jpeg',
#  'Normal (994).jpeg',
#  'Normal (1215).jpeg',
#  'Normal (392).jpeg',
#  'Normal (1070).png',
#  'Normal (691).jpeg',
#  'Normal (3).jpeg',
#  'Normal (1114).png',
#  'Normal (1131).jpeg',
#  'Normal (154).png',
#  'Normal (548).jpeg',
#  'Normal (1397).png',
#  'Normal (291).jpeg',
#  'Normal (792).jpeg',
#  'Normal (1316).jpeg',
#  'Normal (375).png',
#  'Normal (897).jpeg',
#  'Normal (211).png',
#  'Normal (1335).png',
#  'Normal (148).jpeg',
#  'Normal (1251).png',
#  'Normal (1099).png',
#  'Normal (1032).jpeg',
#  'Normal (5).png',
#  'Normal (706).png',
#  'Normal (662).png',
#  'Normal (127).jpeg',
#  'Normal (424).jpeg',
#  'Normal (1669).png',
#  'Normal (629).png',
#  'Normal (805).jpeg',
#  'Normal (585).png',
#  'Normal (23).jpeg',
#  'Normal (1746).png',
#  'Normal (700).jpeg',
#  'Normal (1622).png',
#  'Normal (203).jpeg',
#  'Normal (355).jpeg',
#  'Normal (1118).png',
#  'Normal (656).jpeg',
#  'Normal (953).jpeg',
#  'Normal (113).png',
#  'Normal (1153).png',
#  'Normal (572).jpeg',
#  'Normal (1037).png',
#  'Normal (158).png',
#  'Normal (390).png',
#  'Normal (1199).jpeg',
#  'Normal (560).png',
#  'Normal (878).png',
#  'Normal (1164).jpeg',
#  'Normal (404).png',
#  'Normal (56).png',
#  'Normal (957).png',
#  'Normal (833).png',
#  'Normal (1240).jpeg',
#  'Normal (687).png',
#  'Normal (1520).png',
#  'Normal (1444).png',
#  'Normal (639).jpeg',
#  'Normal (1665).png',
#  'Normal (1701).png',
#  'Normal (1067).jpeg',
#  'Normal (239).jpeg',
#  'Normal (1582).png',
#  'Normal (625).png',
#  'Normal (741).png',
#  'Normal (19).jpeg',
#  'Normal (891).png',
#  'Normal (589).png',
#  'Normal (76).jpeg',
#  'Normal (850).jpeg',
#  'Normal (379).png',
#  'Normal (256).jpeg',
#  'Normal (755).jpeg',
#  'Normal (1216).png',
#  'Normal (1372).png',
#  'Normal (9).png',
#  'Normal (256).png',
#  'Normal (332).png',
#  'Normal (1008).jpeg',
#  'Normal (471).jpeg',
#  'Normal (1339).png',
#  'Normal (1095).png',
#  'Normal (172).jpeg',
#  'Normal (770).png',
#  'Normal (614).png',
#  'Normal (1145).jpeg',
#  'Normal (1730).png',
#  'Normal (1654).png',
#  'Normal (618).jpeg',
#  'Normal (1261).jpeg',
#  'Normal (497).png',
#  'Normal (972).jpeg',
#  'Normal (303).png',
#  'Normal (267).png',
#  'Normal (374).jpeg',
#  'Normal (1308).png',
#  'Normal (389).jpeg',
#  'Normal (677).jpeg',
#  'Normal (348).png',
#  'Normal (180).png',
#  'Normal (1343).png',
#  'Normal (1227).png',
#  'Normal (553).jpeg',
#  'Normal (277).jpeg',
#  'Normal (789).jpeg',
#  'Normal (1006).png',
#  'Normal (774).jpeg',
#  'Normal (1162).png',
#  'Normal (57).jpeg',
#  'Normal (169).png',
#  'Normal (871).jpeg',
#  'Normal (450).jpeg',
#  'Normal (1129).png',
#  'Normal (1285).png',
#  'Normal (153).jpeg',
#  'Normal (122).png',
#  'Normal (1029).jpeg',
#  'Normal (1046).jpeg',
#  'Normal (802).png',
#  'Normal (966).png',
#  'Normal (1475).png',
#  'Normal (1511).png',
#  'Normal (849).png',
#  'Normal (435).png',
#  'Normal (551).png',
#  'Normal (38).jpeg',
#  'Normal (799).png',
#  'Normal (218).jpeg',
#  'Normal (1792).png',
#  'Normal (67).png',
#  'Normal (785).jpeg',
#  'Normal (286).jpeg',
#  'Normal (778).jpeg',
#  'Normal (361).png',
#  'Normal (205).png',
#  'Normal (1301).jpeg',
#  'Normal (880).jpeg',
#  'Normal (1321).png',
#  'Normal (1245).png',
#  'Normal (1025).jpeg',
#  'Normal (712).png',
#  'Normal (676).png',
#  'Normal (1719).png',
#  'Normal (433).jpeg',
#  'Normal (130).jpeg',
#  'Normal (34).jpeg',
#  'Normal (591).png',
#  'Normal (889).png',
#  'Normal (812).jpeg',
#  'Normal (759).png',
#  'Normal (214).jpeg',
#  'Normal (1752).png',
#  'Normal (717).jpeg',
#  'Normal (1636).png',
#  'Normal (530).jpeg',
#  'Normal (1417).png',
#  'Normal (1573).png',
#  'Normal (860).png',
#  'Normal (578).png',
#  'Normal (904).png',
#  'Normal (1149).jpeg',
#  'Normal (1694).png',
#  'Normal (317).jpeg',
#  'Normal (614).jpeg',
#  'Normal (1538).png',
#  'Normal (457).png',
#  'Normal (533).png',
#  'Normal (911).jpeg',
#  'Normal (1290).jpeg',
#  'Normal (983).jpeg',
#  'Normal (1202).jpeg',
#  'Normal (1064).png',
#  'Normal (1100).png',
#  'Normal (378).jpeg',
#  'Normal (686).jpeg',
#  'Normal (385).jpeg',
#  'Normal (388).png',
#  'Normal (1126).jpeg',
#  'Normal (140).png',
#  'Normal (1383).png',
#  'Normal (1509).png',
#  'Normal (412).jpeg',
#  'Normal (111).jpeg',
#  'Normal (34).png',
#  'Normal (1096).jpeg',
#  'Normal (502).png',
#  'Normal (466).png',
#  'Normal (235).jpeg',
#  'Normal (1542).png',
#  'Normal (1426).png',
#  'Normal (736).jpeg',
#  'Normal (15).jpeg',
#  'Normal (781).png',
#  'Normal (549).png',
#  'Normal (833).jpeg',
#  'Normal (935).png',
#  'Normal (851).png',
#  'Normal (171).png',
#  'Normal (1320).jpeg',
#  'Normal (87).jpeg',
#  'Normal (759).jpeg',
#  'Normal (296).png',
#  'Normal (1004).jpeg',
#  'Normal (183).jpeg',
#  'Normal (480).jpeg',
#  'Normal (1131).png',
#  'Normal (1055).png',
#  'Normal (1274).png',
#  'Normal (359).jpeg',
#  'Normal (1310).png',
#  'Normal (1223).jpeg',
#  'Normal (1193).png',
#  'Normal (583).jpeg',
#  'Normal (198).png',
#  'Normal (234).png',
#  'Normal (1107).jpeg',
#  'Normal (350).png',
#  'Normal (1195).jpeg',
#  'Normal (768).png',
#  'Normal (1168).jpeg',
#  'Normal (1607).png',
#  'Normal (511).jpeg',
#  'Normal (1763).png',
#  'Normal (96).png',
#  'Normal (997).png',
#  'Normal (647).png',
#  'Normal (723).png',
#  'Normal (930).jpeg',
#  'Normal (1484).png',
#  'Normal (336).jpeg',
#  'Normal (635).jpeg',
#  'Normal (1728).png',
#  'Normal (1277).jpeg',
#  'Normal (493).png',
#  'Normal (1734).png',
#  'Normal (1650).png',
#  'Normal (1498).png',
#  'Normal (1153).jpeg',
#  'Normal (774).png',
#  'Normal (610).png',
#  'Normal (545).jpeg',
#  'Normal (1347).png',
#  'Normal (1223).png',
#  'Normal (228).png',
#  'Normal (184).png',
#  'Normal (362).jpeg',
#  'Normal (661).jpeg',
#  'Normal (1268).png',
#  'Normal (999).jpeg',
#  'Normal (1218).jpeg',
#  'Normal (307).png',
#  'Normal (263).png',
#  'Normal (964).jpeg',
#  'Normal (126).png',
#  'Normal (1049).png',
#  'Normal (446).jpeg',
#  'Normal (145).jpeg',
#  'Normal (1281).png',
#  'Normal (41).jpeg',
#  'Normal (867).jpeg',
#  'Normal (261).jpeg',
#  'Normal (1002).png',
#  'Normal (762).jpeg',
#  'Normal (1166).png',
#  'Normal (1796).png',
#  'Normal (63).png',
#  'Normal (431).png',
#  'Normal (555).png',
#  'Normal (929).png',
#  'Normal (808).jpeg',
#  'Normal (28).png',
#  'Normal (429).jpeg',
#  'Normal (1471).png',
#  'Normal (1515).png',
#  'Normal (806).png',
#  'Normal (962).png',
#  'Normal (1050).jpeg',
#  'Normal (394).png',
#  'Normal (1157).png',
#  'Normal (564).jpeg',
#  'Normal (1033).png',
#  'Normal (599).jpeg',
#  'Normal (1239).jpeg',
#  'Normal (117).png',
#  'Normal (945).jpeg',
#  'Normal (343).jpeg',
#  'Normal (640).jpeg',
#  'Normal (1078).png',
#  'Normal (1524).png',
#  'Normal (1440).png',
#  'Normal (19).png',
#  'Normal (1688).png',
#  'Normal (1256).jpeg',
#  'Normal (953).png',
#  'Normal (837).png',
#  'Normal (683).png',
#  'Normal (52).png',
#  'Normal (564).png',
#  'Normal (918).png',
#  'Normal (1172).jpeg',
#  'Normal (400).png',
#  'Normal (621).png',
#  'Normal (745).png',
#  'Normal (829).jpeg',
#  'Normal (895).png',
#  'Normal (1586).png',
#  'Normal (1071).jpeg',
#  'Normal (408).jpeg',
#  'Normal (1661).png',
#  'Normal (1705).png',
#  'Normal (1259).png',
#  'Normal (467).jpeg',
#  'Normal (199).jpeg',
#  'Normal (164).jpeg',
#  'Normal (1091).png',
#  'Normal (252).png',
#  'Normal (336).png',
#  'Normal (240).jpeg',
#  'Normal (1212).png',
#  'Normal (1376).png',
#  'Normal (743).jpeg',
#  'Normal (60).jpeg',
#  'Normal (846).jpeg',
#  'Normal (219).png',
#  'Normal (785).png',
#  'Normal (931).png',
#  'Normal (855).png',
#  'Normal (429).png',
#  'Normal (825).jpeg',
#  'Normal (223).jpeg',
#  'Normal (720).jpeg',
#  'Normal (1546).png',
#  'Normal (1422).png',
#  'Normal (506).png',
#  'Normal (462).png',
#  'Normal (1080).jpeg',
#  'Normal (404).jpeg',
#  'Normal (1469).png',
#  'Normal (30).png',
#  'Normal (107).jpeg',
#  'Normal (195).jpeg',
#  'Normal (1299).png',
#  'Normal (1135).png',
#  'Normal (1051).png',
#  'Normal (496).jpeg',
#  'Normal (168).jpeg',
#  'Normal (292).png',
#  'Normal (1012).jpeg',
#  'Normal (1336).jpeg',
#  'Normal (175).png',
#  'Normal (91).jpeg',
#  'Normal (230).png',
#  'Normal (1111).jpeg',
#  'Normal (354).png',
#  'Normal (568).jpeg',
#  'Normal (1197).png',
#  'Normal (595).jpeg',
#  'Normal (1235).jpeg',
#  'Normal (949).jpeg',
#  'Normal (1270).png',
#  'Normal (1314).png',
#  'Normal (1480).png',
#  'Normal (320).jpeg',
#  'Normal (1648).png',
#  'Normal (623).jpeg',
#  'Normal (993).png',
#  'Normal (926).jpeg',
#  'Normal (643).png',
#  'Normal (727).png',
#  'Normal (1603).png',
#  'Normal (507).jpeg',
#  'Normal (1767).png',
#  'Normal (92).png',
#  'Normal (1183).jpeg',
#  'Normal (608).png',
#  'Normal (1033).jpeg',
#  'Normal (1089).png',
#  'Normal (1325).png',
#  'Normal (1241).png',
#  'Normal (149).jpeg',
#  'Normal (896).jpeg',
#  'Normal (365).png',
#  'Normal (1317).jpeg',
#  'Normal (201).png',
#  'Normal (793).jpeg',
#  'Normal (290).jpeg',
#  'Normal (202).jpeg',
#  'Normal (1756).png',
#  'Normal (701).jpeg',
#  'Normal (1632).png',
#  'Normal (595).png',
#  'Normal (22).jpeg',
#  'Normal (804).jpeg',
#  'Normal (639).png',
#  'Normal (425).jpeg',
#  'Normal (1679).png',
#  'Normal (126).jpeg',
#  'Normal (716).png',
#  'Normal (672).png',
#  'Normal (1286).jpeg',
#  'Normal (907).jpeg',
#  'Normal (453).png',
#  'Normal (537).png',
#  'Normal (301).jpeg',
#  'Normal (1690).png',
#  'Normal (1458).png',
#  'Normal (602).jpeg',
#  'Normal (864).png',
#  'Normal (418).png',
#  'Normal (900).png',
#  'Normal (1413).png',
#  'Normal (1577).png',
#  'Normal (526).jpeg',
#  'Normal (1387).png',
#  'Normal (549).jpeg',
#  'Normal (144).png',
#  'Normal (1130).jpeg',
#  'Normal (690).jpeg',
#  'Normal (1060).png',
#  'Normal (1104).png',
#  'Normal (2).jpeg',
#  'Normal (393).jpeg',
#  'Normal (1214).jpeg',
#  'Normal (995).jpeg',
#  'Normal (968).jpeg',
#  'Normal (956).png',
#  'Normal (1045).jpeg',
#  'Normal (832).png',
#  'Normal (686).png',
#  'Normal (1521).png',
#  'Normal (1445).png',
#  'Normal (561).png',
#  'Normal (879).png',
#  'Normal (405).png',
#  'Normal (57).png',
#  'Normal (718).jpeg',
#  'Normal (1152).png',
#  'Normal (289).jpeg',
#  'Normal (1036).png',
#  'Normal (777).jpeg',
#  'Normal (274).jpeg',
#  'Normal (159).png',
#  'Normal (872).jpeg',
#  'Normal (391).png',
#  'Normal (54).jpeg',
#  'Normal (150).jpeg',
#  'Normal (1119).png',
#  'Normal (453).jpeg',
#  'Normal (112).png',
#  'Normal (8).png',
#  'Normal (257).png',
#  'Normal (971).jpeg',
#  'Normal (333).png',
#  'Normal (674).jpeg',
#  'Normal (1338).png',
#  'Normal (1094).png',
#  'Normal (377).jpeg',
#  'Normal (689).jpeg',
#  'Normal (1129).jpeg',
#  'Normal (378).png',
#  'Normal (1217).png',
#  'Normal (550).jpeg',
#  'Normal (1373).png',
#  'Normal (1583).png',
#  'Normal (624).png',
#  'Normal (1146).jpeg',
#  'Normal (740).png',
#  'Normal (890).png',
#  'Normal (588).png',
#  'Normal (1664).png',
#  'Normal (318).jpeg',
#  'Normal (1700).png',
#  'Normal (1262).jpeg',
#  'Normal (853).jpeg',
#  'Normal (349).png',
#  'Normal (88).jpeg',
#  'Normal (181).png',
#  'Normal (75).jpeg',
#  'Normal (1342).png',
#  'Normal (756).jpeg',
#  'Normal (1226).png',
#  'Normal (255).jpeg',
#  'Normal (302).png',
#  'Normal (266).png',
#  'Normal (171).jpeg',
#  'Normal (1309).png',
#  'Normal (472).jpeg',
#  'Normal (1731).png',
#  'Normal (1655).png',
#  'Normal (1064).jpeg',
#  'Normal (1099).jpeg',
#  'Normal (496).png',
#  'Normal (739).jpeg',
#  'Normal (771).png',
#  'Normal (615).png',
#  'Normal (1340).jpeg',
#  'Normal (1167).jpeg',
#  'Normal (848).png',
#  'Normal (434).png',
#  'Normal (550).png',
#  'Normal (798).png',
#  'Normal (66).png',
#  'Normal (1793).png',
#  'Normal (803).png',
#  'Normal (1243).jpeg',
#  'Normal (967).png',
#  'Normal (1474).png',
#  'Normal (1510).png',
#  'Normal (339).jpeg',
#  'Normal (655).jpeg',
#  'Normal (1128).png',
#  'Normal (1284).png',
#  'Normal (356).jpeg',
#  'Normal (950).jpeg',
#  'Normal (123).png',
#  'Normal (571).jpeg',
#  'Normal (1007).png',
#  'Normal (1163).png',
#  'Normal (1108).jpeg',
#  'Normal (168).png',
#  'Normal (590).png',
#  'Normal (888).png',
#  'Normal (758).png',
#  'Normal (1196).jpeg',
#  'Normal (1753).png',
#  'Normal (1637).png',
#  'Normal (512).jpeg',
#  'Normal (713).png',
#  'Normal (933).jpeg',
#  'Normal (677).png',
#  'Normal (1718).png',
#  'Normal (636).jpeg',
#  'Normal (335).jpeg',
#  'Normal (659).jpeg',
#  'Normal (1320).png',
#  'Normal (1244).png',
#  'Normal (1220).jpeg',
#  'Normal (580).jpeg',
#  'Normal (360).png',
#  'Normal (204).png',
#  'Normal (1104).jpeg',
#  'Normal (84).jpeg',
#  'Normal (389).png',
#  'Normal (1323).jpeg',
#  'Normal (79).jpeg',
#  'Normal (141).png',
#  'Normal (1382).png',
#  'Normal (259).jpeg',
#  'Normal (1007).jpeg',
#  'Normal (1065).png',
#  'Normal (483).jpeg',
#  'Normal (1101).png',
#  'Normal (180).jpeg',
#  'Normal (1695).png',
#  'Normal (112).jpeg',
#  'Normal (411).jpeg',
#  'Normal (1539).png',
#  'Normal (1068).jpeg',
#  'Normal (456).png',
#  'Normal (1095).jpeg',
#  'Normal (532).png',
#  'Normal (1416).png',
#  'Normal (735).jpeg',
#  'Normal (1572).png',
#  'Normal (236).jpeg',
#  'Normal (861).png',
#  'Normal (579).png',
#  'Normal (830).jpeg',
#  'Normal (905).png',
#  'Normal (16).jpeg',
#  'Normal (297).png',
#  'Normal (980).jpeg',
#  'Normal (1201).jpeg',
#  'Normal (386).jpeg',
#  'Normal (678).jpeg',
#  'Normal (1130).png',
#  'Normal (685).jpeg',
#  'Normal (1054).png',
#  'Normal (170).png',
#  'Normal (1125).jpeg',
#  'Normal (1543).png',
#  'Normal (533).jpeg',
#  'Normal (1427).png',
#  'Normal (780).png',
#  'Normal (548).png',
#  'Normal (934).png',
#  'Normal (850).png',
#  'Normal (1508).png',
#  'Normal (617).jpeg',
#  'Normal (35).png',
#  'Normal (314).jpeg',
#  'Normal (503).png',
#  'Normal (912).jpeg',
#  'Normal (1293).jpeg',
#  'Normal (467).png',
#  'Normal (1049).jpeg',
#  'Normal (996).png',
#  'Normal (646).png',
#  'Normal (722).png',
#  'Normal (1485).png',
#  'Normal (133).jpeg',
#  'Normal (430).jpeg',
#  'Normal (1729).png',
#  'Normal (811).jpeg',
#  'Normal (769).png',
#  'Normal (37).jpeg',
#  'Normal (714).jpeg',
#  'Normal (1606).png',
#  'Normal (97).png',
#  'Normal (1762).png',
#  'Normal (217).jpeg',
#  'Normal (285).jpeg',
#  'Normal (1192).png',
#  'Normal (278).jpeg',
#  'Normal (786).jpeg',
#  'Normal (199).png',
#  'Normal (235).png',
#  'Normal (1302).jpeg',
#  'Normal (883).jpeg',
#  'Normal (58).jpeg',
#  'Normal (351).png',
#  'Normal (1275).png',
#  'Normal (1311).png',
#  'Normal (1026).jpeg',
#  'Normal (499).jpeg',
#  'Normal (167).jpeg',
#  'Normal (464).jpeg',
#  'Normal (1269).png',
#  'Normal (306).png',
#  'Normal (262).png',
#  'Normal (1346).png',
#  'Normal (740).jpeg',
#  'Normal (1222).png',
#  'Normal (243).jpeg',
#  'Normal (845).jpeg',
#  'Normal (229).png',
#  'Normal (1339).jpeg',
#  'Normal (185).png',
#  'Normal (63).jpeg',
#  'Normal (775).png',
#  'Normal (611).png',
#  'Normal (1072).jpeg',
#  'Normal (492).png',
#  ...]

# %%
# 肺部感染的图片
files_viral_pneumonia = os.listdir(os.path.join(str(dataloaders['train'].dataset.root), 'Viral'))
files_viral_pneumonia
# Out:
# ['Viral (1286).png',
#  'Viral (184).png',
#  'Viral (228).png',
#  'Viral (1400).jpeg',
#  'Viral (859).jpeg',
#  'Viral (1103).jpeg',
#  'Viral (307).png',
#  'Viral (1005).png',
#  'Viral (263).png',
#  'Viral (485).jpeg',
#  'Viral (1161).png',
#  'Viral (478).jpeg',
#  'Viral (186).jpeg',
#  'Viral (1227).jpeg',
#  'Viral (1724).jpeg',
#  'Viral (1248).jpeg',
#  'Viral (82).png',
#  'Viral (493).png',
#  'Viral (114).jpeg',
#  'Viral (417).jpeg',
#  'Viral (1191).jpeg',
#  'Viral (836).jpeg',
#  'Viral (1492).jpeg',
#  'Viral (733).jpeg',
#  'Viral (774).png',
#  'Viral (610).png',
#  'Viral (230).jpeg',
#  'Viral (431).png',
#  'Viral (20).png',
#  'Viral (514).jpeg',
#  'Viral (555).png',
#  'Viral (929).png',
#  'Viral (1648).jpeg',
#  'Viral (806).png',
#  'Viral (630).jpeg',
#  'Viral (962).png',
#  'Viral (333).jpeg',
#  'Viral (935).jpeg',
#  'Viral (1092).jpeg',
#  'Viral (1591).jpeg',
#  'Viral (1503).jpeg',
#  'Viral (1000).jpeg',
#  'Viral (1188).png',
#  'Viral (1340).png',
#  'Viral (1224).png',
#  'Viral (126).png',
#  'Viral (1324).jpeg',
#  'Viral (1627).jpeg',
#  'Viral (586).jpeg',
#  'Viral (41).jpeg',
#  'Viral (135).jpeg',
#  'Viral (683).png',
#  'Viral (436).jpeg',
#  'Viral (953).png',
#  'Viral (837).png',
#  'Viral (1269).jpeg',
#  'Viral (1294).jpeg',
#  'Viral (564).png',
#  'Viral (712).jpeg',
#  'Viral (918).png',
#  'Viral (11).png',
#  'Viral (400).png',
#  'Viral (211).jpeg',
#  'Viral (817).jpeg',
#  'Viral (878).jpeg',
#  'Viral (1421).jpeg',
#  'Viral (885).jpeg',
#  'Viral (1122).jpeg',
#  'Viral (394).png',
#  'Viral (283).jpeg',
#  'Viral (1096).png',
#  'Viral (3).jpeg',
#  'Viral (780).jpeg',
#  'Viral (1206).jpeg',
#  'Viral (1705).jpeg',
#  'Viral (1215).png',
#  'Viral (117).png',
#  'Viral (459).jpeg',
#  'Viral (380).jpeg',
#  'Viral (683).jpeg',
#  'Viral (252).png',
#  'Viral (1150).png',
#  'Viral (336).png',
#  'Viral (1034).png',
#  'Viral (1522).jpeg',
#  'Viral (1021).jpeg',
#  'Viral (986).jpeg',
#  'Viral (219).png',
#  'Viral (60).jpeg',
#  'Viral (1305).jpeg',
#  'Viral (1606).jpeg',
#  'Viral (1694).jpeg',
#  'Viral (1397).jpeg',
#  'Viral (1669).jpeg',
#  'Viral (895).png',
#  'Viral (621).png',
#  'Viral (535).jpeg',
#  'Viral (745).png',
#  'Viral (914).jpeg',
#  'Viral (611).jpeg',
#  'Viral (312).jpeg',
#  'Viral (672).jpeg',
#  'Viral (1190).png',
#  'Viral (371).jpeg',
#  'Viral (292).png',
#  'Viral (977).jpeg',
#  'Viral (91).jpeg',
#  'Viral (175).png',
#  'Viral (556).jpeg',
#  'Viral (1277).png',
#  'Viral (1313).png',
#  'Viral (1309).jpeg',
#  'Viral (1366).jpeg',
#  'Viral (1698).jpeg',
#  'Viral (1665).jpeg',
#  'Viral (931).png',
#  'Viral (855).png',
#  'Viral (429).png',
#  'Viral (38).png',
#  'Viral (785).png',
#  'Viral (539).jpeg',
#  'Viral (918).jpeg',
#  'Viral (1541).jpeg',
#  'Viral (1042).jpeg',
#  'Viral (506).png',
#  'Viral (73).png',
#  'Viral (462).png',
#  'Viral (643).png',
#  'Viral (139).jpeg',
#  'Viral (727).png',
#  'Viral (993).png',
#  'Viral (1265).jpeg',
#  'Viral (1298).jpeg',
#  'Viral (608).png',
#  'Viral (1442).jpeg',
#  'Viral (1141).jpeg',
#  'Viral (874).jpeg',
#  'Viral (889).jpeg',
#  'Viral (1132).png',
#  'Viral (230).png',
#  'Viral (771).jpeg',
#  'Viral (1056).png',
#  'Viral (354).png',
#  'Viral (272).jpeg',
#  'Viral (1709).jpeg',
#  'Viral (156).jpeg',
#  'Viral (1179).png',
#  'Viral (455).jpeg',
#  'Viral (639).png',
#  'Viral (595).png',
#  'Viral (518).jpeg',
#  'Viral (22).jpeg',
#  'Viral (1347).jpeg',
#  'Viral (1644).jpeg',
#  'Viral (716).png',
#  'Viral (672).png',
#  'Viral (1560).jpeg',
#  'Viral (939).jpeg',
#  'Viral (1063).jpeg',
#  'Viral (956).jpeg',
#  'Viral (653).jpeg',
#  'Viral (1148).png',
#  'Viral (350).jpeg',
#  'Viral (1328).jpeg',
#  'Viral (1067).png',
#  'Viral (365).png',
#  'Viral (577).jpeg',
#  'Viral (1103).png',
#  'Viral (201).png',
#  'Viral (1322).png',
#  'Viral (144).png',
#  'Viral (1246).png',
#  'Viral (750).jpeg',
#  'Viral (253).jpeg',
#  'Viral (855).jpeg',
#  'Viral (489).jpeg',
#  'Viral (177).jpeg',
#  'Viral (474).jpeg',
#  'Viral (1728).jpeg',
#  'Viral (1244).jpeg',
#  'Viral (1747).jpeg',
#  'Viral (118).jpeg',
#  'Viral (453).png',
#  'Viral (42).png',
#  'Viral (537).png',
#  'Viral (1463).jpeg',
#  'Viral (1160).jpeg',
#  'Viral (864).png',
#  'Viral (418).png',
#  'Viral (900).png',
#  'Viral (1458).jpeg',
#  'Viral (801).jpeg',
#  'Viral (560).png',
#  'Viral (878).png',
#  'Viral (704).jpeg',
#  'Viral (15).png',
#  'Viral (404).png',
#  'Viral (207).jpeg',
#  'Viral (1282).jpeg',
#  'Viral (123).jpeg',
#  'Viral (687).png',
#  'Viral (957).png',
#  'Viral (833).png',
#  'Viral (420).jpeg',
#  'Viral (113).png',
#  'Viral (1211).png',
#  'Viral (1210).jpeg',
#  'Viral (1713).jpeg',
#  'Viral (1092).png',
#  'Viral (390).png',
#  'Viral (295).jpeg',
#  'Viral (268).jpeg',
#  'Viral (796).jpeg',
#  'Viral (158).png',
#  'Viral (1437).jpeg',
#  'Viral (1134).jpeg',
#  'Viral (893).jpeg',
#  'Viral (1313).jpeg',
#  'Viral (1610).jpeg',
#  'Viral (379).png',
#  'Viral (76).jpeg',
#  'Viral (1534).jpeg',
#  'Viral (990).jpeg',
#  'Viral (1037).jpeg',
#  'Viral (396).jpeg',
#  'Viral (668).jpeg',
#  'Viral (1154).png',
#  'Viral (256).png',
#  'Viral (1030).png',
#  'Viral (695).jpeg',
#  'Viral (332).png',
#  'Viral (607).jpeg',
#  'Viral (304).jpeg',
#  'Viral (902).jpeg',
#  'Viral (1058).jpeg',
#  'Viral (891).png',
#  'Viral (589).png',
#  'Viral (625).png',
#  'Viral (523).jpeg',
#  'Viral (19).jpeg',
#  'Viral (741).png',
#  'Viral (1682).jpeg',
#  'Viral (1381).jpeg',
#  'Viral (1231).jpeg',
#  'Viral (1732).jpeg',
#  'Viral (1001).png',
#  'Viral (493).jpeg',
#  'Viral (303).png',
#  'Viral (1165).png',
#  'Viral (267).png',
#  'Viral (190).jpeg',
#  'Viral (1416).jpeg',
#  'Viral (1115).jpeg',
#  'Viral (180).png',
#  'Viral (1282).png',
#  'Viral (249).jpeg',
#  'Viral (348).png',
#  'Viral (770).png',
#  'Viral (614).png',
#  'Viral (725).jpeg',
#  'Viral (226).jpeg',
#  'Viral (820).jpeg',
#  'Viral (1479).jpeg',
#  'Viral (1187).jpeg',
#  'Viral (1484).jpeg',
#  'Viral (102).jpeg',
#  'Viral (86).png',
#  'Viral (497).png',
#  'Viral (401).jpeg',
#  'Viral (1084).jpeg',
#  'Viral (923).jpeg',
#  'Viral (1587).jpeg',
#  'Viral (1079).jpeg',
#  'Viral (626).jpeg',
#  'Viral (802).png',
#  'Viral (966).png',
#  'Viral (325).jpeg',
#  'Viral (799).png',
#  'Viral (849).png',
#  'Viral (435).png',
#  'Viral (502).jpeg',
#  'Viral (24).png',
#  'Viral (38).jpeg',
#  'Viral (551).png',
#  'Viral (169).png',
#  'Viral (590).jpeg',
#  'Viral (57).jpeg',
#  'Viral (1332).jpeg',
#  'Viral (1631).jpeg',
#  'Viral (649).jpeg',
#  'Viral (1344).png',
#  'Viral (122).png',
#  'Viral (1220).png',
#  'Viral (1515).jpeg',
#  'Viral (1016).jpeg',
#  'Viral (1576).jpeg',
#  'Viral (1088).jpeg',
#  'Viral (1075).jpeg',
#  'Viral (329).jpeg',
#  'Viral (712).png',
#  'Viral (676).png',
#  'Viral (1351).jpeg',
#  'Viral (1652).jpeg',
#  'Viral (759).png',
#  'Viral (591).png',
#  'Viral (34).jpeg',
#  'Viral (889).png',
#  'Viral (361).png',
#  'Viral (1063).png',
#  'Viral (561).jpeg',
#  'Viral (205).png',
#  'Viral (1107).png',
#  'Viral (1028).png',
#  'Viral (645).jpeg',
#  'Viral (346).jpeg',
#  'Viral (940).jpeg',
#  'Viral (1519).jpeg',
#  'Viral (161).jpeg',
#  'Viral (462).jpeg',
#  'Viral (1209).png',
#  'Viral (843).jpeg',
#  'Viral (1119).jpeg',
#  'Viral (746).jpeg',
#  'Viral (1326).png',
#  'Viral (1242).png',
#  'Viral (140).png',
#  'Viral (388).png',
#  'Viral (245).jpeg',
#  'Viral (729).jpeg',
#  'Viral (860).png',
#  'Viral (578).png',
#  'Viral (904).png',
#  'Viral (1475).jpeg',
#  'Viral (1488).jpeg',
#  'Viral (1176).jpeg',
#  'Viral (457).png',
#  'Viral (46).png',
#  'Viral (533).png',
#  'Viral (1252).jpeg',
#  'Viral (87).jpeg',
#  'Viral (1273).png',
#  'Viral (171).png',
#  'Viral (1317).png',
#  'Viral (540).jpeg',
#  'Viral (1538).jpeg',
#  'Viral (961).jpeg',
#  'Viral (1238).png',
#  'Viral (664).jpeg',
#  'Viral (367).jpeg',
#  'Viral (699).jpeg',
#  'Viral (296).png',
#  'Viral (1194).png',
#  'Viral (502).png',
#  'Viral (308).jpeg',
#  'Viral (77).png',
#  'Viral (466).png',
#  'Viral (1557).jpeg',
#  'Viral (1054).jpeg',
#  'Viral (549).png',
#  'Viral (935).png',
#  'Viral (851).png',
#  'Viral (781).png',
#  'Viral (15).jpeg',
#  'Viral (1370).jpeg',
#  'Viral (1673).jpeg',
#  'Viral (1454).jpeg',
#  'Viral (1157).jpeg',
#  'Viral (708).jpeg',
#  'Viral (768).png',
#  'Viral (1273).jpeg',
#  'Viral (647).png',
#  'Viral (723).png',
#  'Viral (997).png',
#  'Viral (140).jpeg',
#  'Viral (443).jpeg',
#  'Viral (1019).png',
#  'Viral (234).png',
#  'Viral (299).jpeg',
#  'Viral (1136).png',
#  'Viral (767).jpeg',
#  'Viral (350).png',
#  'Viral (1052).png',
#  'Viral (198).png',
#  'Viral (264).jpeg',
#  'Viral (862).jpeg',
#  'Viral (1138).jpeg',
#  'Viral (1590).jpeg',
#  'Viral (1093).jpeg',
#  'Viral (934).jpeg',
#  'Viral (332).jpeg',
#  'Viral (816).png',
#  'Viral (972).png',
#  'Viral (631).jpeg',
#  'Viral (1649).jpeg',
#  'Viral (30).png',
#  'Viral (421).png',
#  'Viral (939).png',
#  'Viral (545).png',
#  'Viral (515).jpeg',
#  'Viral (40).jpeg',
#  'Viral (587).jpeg',
#  'Viral (1626).jpeg',
#  'Viral (1325).jpeg',
#  'Viral (136).png',
#  'Viral (1234).png',
#  'Viral (6).png',
#  'Viral (1198).png',
#  'Viral (1001).jpeg',
#  'Viral (1502).jpeg',
#  'Viral (1725).jpeg',
#  'Viral (1226).jpeg',
#  'Viral (187).jpeg',
#  'Viral (479).jpeg',
#  'Viral (1015).png',
#  'Viral (317).png',
#  'Viral (1171).png',
#  'Viral (484).jpeg',
#  'Viral (273).png',
#  'Viral (1102).jpeg',
#  'Viral (858).jpeg',
#  'Viral (1401).jpeg',
#  'Viral (238).png',
#  'Viral (194).png',
#  'Viral (1296).png',
#  'Viral (231).jpeg',
#  'Viral (764).png',
#  'Viral (732).jpeg',
#  'Viral (600).png',
#  'Viral (1493).jpeg',
#  'Viral (837).jpeg',
#  'Viral (1190).jpeg',
#  'Viral (416).jpeg',
#  'Viral (115).jpeg',
#  'Viral (483).png',
#  'Viral (92).png',
#  'Viral (1249).jpeg',
#  'Viral (1607).jpeg',
#  'Viral (1304).jpeg',
#  'Viral (61).jpeg',
#  'Viral (209).png',
#  'Viral (987).jpeg',
#  'Viral (1020).jpeg',
#  'Viral (1523).jpeg',
#  'Viral (1140).png',
#  'Viral (242).png',
#  'Viral (682).jpeg',
#  'Viral (1024).png',
#  'Viral (326).png',
#  'Viral (381).jpeg',
#  'Viral (313).jpeg',
#  'Viral (610).jpeg',
#  'Viral (915).jpeg',
#  'Viral (631).png',
#  'Viral (755).png',
#  'Viral (534).jpeg',
#  'Viral (885).png',
#  'Viral (1668).jpeg',
#  'Viral (1396).jpeg',
#  'Viral (1695).jpeg',
#  'Viral (816).jpeg',
#  'Viral (210).jpeg',
#  'Viral (908).png',
#  'Viral (713).jpeg',
#  'Viral (574).png',
#  'Viral (410).png',
#  'Viral (1295).jpeg',
#  'Viral (1268).jpeg',
#  'Viral (943).png',
#  'Viral (437).jpeg',
#  'Viral (827).png',
#  'Viral (693).png',
#  'Viral (134).jpeg',
#  'Viral (458).jpeg',
#  'Viral (107).png',
#  'Viral (1205).png',
#  'Viral (1704).jpeg',
#  'Viral (1207).jpeg',
#  'Viral (781).jpeg',
#  'Viral (1086).png',
#  'Viral (282).jpeg',
#  'Viral (384).png',
#  'Viral (2).jpeg',
#  'Viral (1123).jpeg',
#  'Viral (884).jpeg',
#  'Viral (1420).jpeg',
#  'Viral (879).jpeg',
#  'Viral (1140).jpeg',
#  'Viral (1443).jpeg',
#  'Viral (618).png',
#  'Viral (1299).jpeg',
#  'Viral (1264).jpeg',
#  'Viral (983).png',
#  'Viral (138).jpeg',
#  'Viral (653).png',
#  'Viral (737).png',
#  'Viral (1169).png',
#  'Viral (454).jpeg',
#  'Viral (157).jpeg',
#  'Viral (1708).jpeg',
#  'Viral (273).jpeg',
#  'Viral (220).png',
#  'Viral (1122).png',
#  'Viral (344).png',
#  'Viral (770).jpeg',
#  'Viral (1046).png',
#  'Viral (888).jpeg',
#  'Viral (875).jpeg',
#  'Viral (1308).jpeg',
#  'Viral (1267).png',
#  'Viral (557).jpeg',
#  'Viral (165).png',
#  'Viral (1303).png',
#  'Viral (90).jpeg',
#  'Viral (976).jpeg',
#  'Viral (282).png',
#  'Viral (370).jpeg',
#  'Viral (1180).png',
#  'Viral (673).jpeg',
#  'Viral (516).png',
#  'Viral (472).png',
#  'Viral (63).png',
#  'Viral (1043).jpeg',
#  'Viral (1540).jpeg',
#  'Viral (919).jpeg',
#  'Viral (538).jpeg',
#  'Viral (795).png',
#  'Viral (921).png',
#  'Viral (28).png',
#  'Viral (439).png',
#  'Viral (845).png',
#  'Viral (1664).jpeg',
#  'Viral (1699).jpeg',
#  'Viral (1367).jpeg',
#  'Viral (1729).jpeg',
#  'Viral (475).jpeg',
#  'Viral (176).jpeg',
#  'Viral (488).jpeg',
#  'Viral (854).jpeg',
#  'Viral (252).jpeg',
#  'Viral (1332).png',
#  'Viral (1256).png',
#  'Viral (751).jpeg',
#  'Viral (154).png',
#  'Viral (408).png',
#  'Viral (19).png',
#  'Viral (874).png',
#  'Viral (910).png',
#  'Viral (1161).jpeg',
#  'Viral (1462).jpeg',
#  'Viral (52).png',
#  'Viral (443).png',
#  'Viral (119).jpeg',
#  'Viral (527).png',
#  'Viral (1746).jpeg',
#  'Viral (1245).jpeg',
#  'Viral (1062).jpeg',
#  'Viral (938).jpeg',
#  'Viral (1561).jpeg',
#  'Viral (706).png',
#  'Viral (662).png',
#  'Viral (1645).jpeg',
#  'Viral (1346).jpeg',
#  'Viral (519).jpeg',
#  'Viral (585).png',
#  'Viral (23).jpeg',
#  'Viral (629).png',
#  'Viral (576).jpeg',
#  'Viral (375).png',
#  'Viral (1077).png',
#  'Viral (211).png',
#  'Viral (1113).png',
#  'Viral (1329).jpeg',
#  'Viral (351).jpeg',
#  'Viral (652).jpeg',
#  'Viral (1158).png',
#  'Viral (957).jpeg',
#  'Viral (246).png',
#  'Viral (1144).png',
#  'Viral (322).png',
#  'Viral (694).jpeg',
#  'Viral (1020).png',
#  'Viral (669).jpeg',
#  'Viral (397).jpeg',
#  'Viral (1036).jpeg',
#  'Viral (991).jpeg',
#  'Viral (1535).jpeg',
#  'Viral (77).jpeg',
#  'Viral (369).png',
#  'Viral (1611).jpeg',
#  'Viral (1312).jpeg',
#  'Viral (1380).jpeg',
#  'Viral (1683).jpeg',
#  'Viral (522).jpeg',
#  'Viral (635).png',
#  'Viral (751).png',
#  'Viral (18).jpeg',
#  'Viral (881).png',
#  'Viral (599).png',
#  'Viral (1059).jpeg',
#  'Viral (903).jpeg',
#  'Viral (305).jpeg',
#  'Viral (606).jpeg',
#  'Viral (947).png',
#  'Viral (421).jpeg',
#  'Viral (823).png',
#  'Viral (122).jpeg',
#  'Viral (697).png',
#  'Viral (1283).jpeg',
#  'Viral (206).jpeg',
#  'Viral (570).png',
#  'Viral (414).png',
#  'Viral (705).jpeg',
#  'Viral (868).png',
#  'Viral (800).jpeg',
#  'Viral (1459).jpeg',
#  'Viral (892).jpeg',
#  'Viral (1135).jpeg',
#  'Viral (1436).jpeg',
#  'Viral (148).png',
#  'Viral (797).jpeg',
#  'Viral (269).jpeg',
#  'Viral (380).png',
#  'Viral (1082).png',
#  'Viral (294).jpeg',
#  'Viral (1712).jpeg',
#  'Viral (1211).jpeg',
#  'Viral (1201).png',
#  'Viral (103).png',
#  'Viral (503).jpeg',
#  'Viral (34).png',
#  'Viral (425).png',
#  'Viral (859).png',
#  'Viral (541).png',
#  'Viral (39).jpeg',
#  'Viral (789).png',
#  'Viral (324).jpeg',
#  'Viral (812).png',
#  'Viral (627).jpeg',
#  'Viral (976).png',
#  'Viral (1078).jpeg',
#  'Viral (1586).jpeg',
#  'Viral (922).jpeg',
#  'Viral (1085).jpeg',
#  'Viral (1017).jpeg',
#  'Viral (1514).jpeg',
#  'Viral (1230).png',
#  'Viral (2).png',
#  'Viral (132).png',
#  'Viral (648).jpeg',
#  'Viral (1630).jpeg',
#  'Viral (1333).jpeg',
#  'Viral (56).jpeg',
#  'Viral (591).jpeg',
#  'Viral (179).png',
#  'Viral (358).png',
#  'Viral (248).jpeg',
#  'Viral (1292).png',
#  'Viral (190).png',
#  'Viral (1114).jpeg',
#  'Viral (1417).jpeg',
#  'Viral (191).jpeg',
#  'Viral (313).png',
#  'Viral (492).jpeg',
#  'Viral (1011).png',
#  'Viral (277).png',
#  'Viral (1175).png',
#  'Viral (1733).jpeg',
#  'Viral (1230).jpeg',
#  'Viral (400).jpeg',
#  'Viral (103).jpeg',
#  'Viral (487).png',
#  'Viral (96).png',
#  'Viral (1485).jpeg',
#  'Viral (1186).jpeg',
#  'Viral (1478).jpeg',
#  'Viral (821).jpeg',
#  'Viral (227).jpeg',
#  'Viral (760).png',
#  'Viral (724).jpeg',
#  'Viral (604).png',
#  'Viral (244).jpeg',
#  'Viral (398).png',
#  'Viral (747).jpeg',
#  'Viral (1336).png',
#  'Viral (150).png',
#  'Viral (1252).png',
#  'Viral (1118).jpeg',
#  'Viral (842).jpeg',
#  'Viral (463).jpeg',
#  'Viral (1219).png',
#  'Viral (160).jpeg',
#  'Viral (1750).jpeg',
#  'Viral (1253).jpeg',
#  'Viral (56).png',
#  'Viral (447).png',
#  'Viral (523).png',
#  'Viral (1177).jpeg',
#  'Viral (1489).jpeg',
#  'Viral (1474).jpeg',
#  'Viral (870).png',
#  'Viral (914).png',
#  'Viral (568).png',
#  'Viral (728).jpeg',
#  'Viral (35).jpeg',
#  'Viral (581).png',
#  'Viral (899).png',
#  'Viral (749).png',
#  'Viral (1653).jpeg',
#  'Viral (1350).jpeg',
#  'Viral (702).png',
#  'Viral (328).jpeg',
#  'Viral (666).png',
#  'Viral (1074).jpeg',
#  'Viral (1089).jpeg',
#  'Viral (1577).jpeg',
#  'Viral (1518).jpeg',
#  'Viral (941).jpeg',
#  'Viral (347).jpeg',
#  'Viral (1038).png',
#  'Viral (644).jpeg',
#  'Viral (1073).png',
#  'Viral (371).png',
#  'Viral (1117).png',
#  'Viral (215).png',
#  'Viral (560).jpeg',
#  'Viral (987).png',
#  'Viral (657).png',
#  'Viral (733).png',
#  'Viral (1272).jpeg',
#  'Viral (778).png',
#  'Viral (709).jpeg',
#  'Viral (1156).jpeg',
#  'Viral (1455).jpeg',
#  'Viral (1139).jpeg',
#  'Viral (863).jpeg',
#  'Viral (265).jpeg',
#  'Viral (188).png',
#  'Viral (1126).png',
#  'Viral (766).jpeg',
#  'Viral (298).jpeg',
#  'Viral (224).png',
#  'Viral (1042).png',
#  'Viral (340).png',
#  'Viral (442).jpeg',
#  'Viral (1009).png',
#  'Viral (141).jpeg',
#  'Viral (698).jpeg',
#  'Viral (366).jpeg',
#  'Viral (1184).png',
#  'Viral (286).png',
#  'Viral (1228).png',
#  'Viral (665).jpeg',
#  'Viral (960).jpeg',
#  'Viral (1539).jpeg',
#  'Viral (161).png',
#  'Viral (1263).png',
#  'Viral (541).jpeg',
#  'Viral (1307).png',
#  'Viral (86).jpeg',
#  'Viral (1672).jpeg',
#  'Viral (1371).jpeg',
#  'Viral (14).jpeg',
#  'Viral (791).png',
#  'Viral (925).png',
#  'Viral (559).png',
#  'Viral (841).png',
#  'Viral (1055).jpeg',
#  'Viral (1556).jpeg',
#  'Viral (309).jpeg',
#  'Viral (512).png',
#  'Viral (476).png',
#  'Viral (67).png',
#  'Viral (158).jpeg',
#  'Viral (137).png',
#  'Viral (7).png',
#  'Viral (1235).png',
#  'Viral (1199).png',
#  'Viral (1204).jpeg',
#  'Viral (1707).jpeg',
#  'Viral (1).jpeg',
#  'Viral (281).jpeg',
#  'Viral (782).jpeg',
#  'Viral (1423).jpeg',
#  'Viral (1120).jpeg',
#  'Viral (887).jpeg',
#  'Viral (815).jpeg',
#  'Viral (420).png',
#  'Viral (31).png',
#  'Viral (938).png',
#  'Viral (710).jpeg',
#  'Viral (544).png',
#  'Viral (213).jpeg',
#  'Viral (1296).jpeg',
#  'Viral (137).jpeg',
#  'Viral (817).png',
#  'Viral (973).png',
#  'Viral (434).jpeg',
#  'Viral (613).jpeg',
#  'Viral (93).png',
#  'Viral (310).jpeg',
#  'Viral (482).png',
#  'Viral (916).jpeg',
#  'Viral (765).png',
#  'Viral (537).jpeg',
#  'Viral (601).png',
#  'Viral (1696).jpeg',
#  'Viral (1368).jpeg',
#  'Viral (1395).jpeg',
#  'Viral (1307).jpeg',
#  'Viral (1604).jpeg',
#  'Viral (239).png',
#  'Viral (195).png',
#  'Viral (558).jpeg',
#  'Viral (1297).png',
#  'Viral (62).jpeg',
#  'Viral (979).jpeg',
#  'Viral (1520).jpeg',
#  'Viral (984).jpeg',
#  'Viral (1023).jpeg',
#  'Viral (382).jpeg',
#  'Viral (1014).png',
#  'Viral (316).png',
#  'Viral (1170).png',
#  'Viral (681).jpeg',
#  'Viral (272).png',
#  'Viral (630).png',
#  'Viral (754).png',
#  'Viral (731).jpeg',
#  'Viral (884).png',
#  'Viral (232).jpeg',
#  'Viral (834).jpeg',
#  'Viral (1193).jpeg',
#  'Viral (1490).jpeg',
#  'Viral (116).jpeg',
#  'Viral (415).jpeg',
#  'Viral (1749).jpeg',
#  'Viral (1225).jpeg',
#  'Viral (1726).jpeg',
#  'Viral (1141).png',
#  'Viral (179).jpeg',
#  'Viral (487).jpeg',
#  'Viral (243).png',
#  'Viral (1025).png',
#  'Viral (327).png',
#  'Viral (184).jpeg',
#  'Viral (1402).jpeg',
#  'Viral (1101).jpeg',
#  'Viral (208).png',
#  'Viral (584).jpeg',
#  'Viral (1087).png',
#  'Viral (385).png',
#  'Viral (579).jpeg',
#  'Viral (43).jpeg',
#  'Viral (1326).jpeg',
#  'Viral (1625).jpeg',
#  'Viral (106).png',
#  'Viral (1204).png',
#  'Viral (1501).jpeg',
#  'Viral (958).jpeg',
#  'Viral (1002).jpeg',
#  'Viral (1090).jpeg',
#  'Viral (937).jpeg',
#  'Viral (1593).jpeg',
#  'Viral (632).jpeg',
#  'Viral (942).png',
#  'Viral (826).png',
#  'Viral (692).png',
#  'Viral (331).jpeg',
#  'Viral (1349).jpeg',
#  'Viral (909).png',
#  'Viral (575).png',
#  'Viral (516).jpeg',
#  'Viral (411).png',
#  'Viral (588).jpeg',
#  'Viral (221).png',
#  'Viral (1123).png',
#  'Viral (575).jpeg',
#  'Viral (345).png',
#  'Viral (1047).png',
#  'Viral (1629).jpeg',
#  'Viral (1168).png',
#  'Viral (651).jpeg',
#  'Viral (352).jpeg',
#  'Viral (954).jpeg',
#  'Viral (1562).jpeg',
#  'Viral (1061).jpeg',
#  'Viral (982).png',
#  'Viral (652).png',
#  'Viral (736).png',
#  'Viral (1345).jpeg',
#  'Viral (1646).jpeg',
#  'Viral (619).png',
#  'Viral (20).jpeg',
#  'Viral (794).png',
#  'Viral (920).png',
#  'Viral (438).png',
#  'Viral (29).png',
#  'Viral (844).png',
#  'Viral (1461).jpeg',
#  'Viral (838).jpeg',
#  'Viral (1162).jpeg',
#  'Viral (517).png',
#  'Viral (62).png',
#  'Viral (473).png',
#  'Viral (419).jpeg',
#  'Viral (1246).jpeg',
#  'Viral (1745).jpeg',
#  'Viral (1229).jpeg',
#  'Viral (283).png',
#  'Viral (175).jpeg',
#  'Viral (1181).png',
#  'Viral (188).jpeg',
#  'Viral (476).jpeg',
#  'Viral (857).jpeg',
#  'Viral (1266).png',
#  'Viral (752).jpeg',
#  'Viral (164).png',
#  'Viral (1302).png',
#  'Viral (251).jpeg',
#  'Viral (442).png',
#  'Viral (53).png',
#  'Viral (526).png',
#  'Viral (1543).jpeg',
#  'Viral (1040).jpeg',
#  'Viral (18).png',
#  'Viral (409).png',
#  'Viral (875).png',
#  'Viral (911).png',
#  'Viral (1364).jpeg',
#  'Viral (1667).jpeg',
#  'Viral (1399).jpeg',
#  'Viral (1608).jpeg',
#  'Viral (93).jpeg',
#  'Viral (1333).png',
#  'Viral (1257).png',
#  'Viral (554).jpeg',
#  'Viral (155).png',
#  'Viral (975).jpeg',
#  'Viral (988).jpeg',
#  'Viral (670).jpeg',
#  'Viral (373).jpeg',
#  'Viral (154).jpeg',
#  'Viral (457).jpeg',
#  'Viral (1159).png',
#  'Viral (1208).jpeg',
#  'Viral (374).png',
#  'Viral (773).jpeg',
#  'Viral (1076).png',
#  'Viral (210).png',
#  'Viral (1112).png',
#  'Viral (270).jpeg',
#  'Viral (876).jpeg',
#  'Viral (819).jpeg',
#  'Viral (1440).jpeg',
#  'Viral (1143).jpeg',
#  'Viral (584).png',
#  'Viral (628).png',
#  'Viral (1267).jpeg',
#  'Viral (707).png',
#  'Viral (663).png',
#  'Viral (438).jpeg',
#  'Viral (100).jpeg',
#  'Viral (403).jpeg',
#  'Viral (1185).jpeg',
#  'Viral (822).jpeg',
#  'Viral (1178).jpeg',
#  'Viral (1486).jpeg',
#  'Viral (727).jpeg',
#  'Viral (634).png',
#  'Viral (750).png',
#  'Viral (880).png',
#  'Viral (598).png',
#  'Viral (224).jpeg',
#  'Viral (748).jpeg',
#  'Viral (368).png',
#  'Viral (1414).jpeg',
#  'Viral (1117).jpeg',
#  'Viral (247).png',
#  'Viral (1145).png',
#  'Viral (323).png',
#  'Viral (491).jpeg',
#  'Viral (1021).png',
#  'Viral (192).jpeg',
#  'Viral (1233).jpeg',
#  'Viral (1730).jpeg',
#  'Viral (1517).jpeg',
#  'Viral (1014).jpeg',
#  'Viral (1200).png',
#  'Viral (348).jpeg',
#  'Viral (102).png',
#  'Viral (1330).jpeg',
#  'Viral (1633).jpeg',
#  'Viral (592).jpeg',
#  'Viral (149).png',
#  'Viral (381).png',
#  'Viral (55).jpeg',
#  'Viral (1083).png',
#  'Viral (571).png',
#  'Viral (500).jpeg',
#  'Viral (415).png',
#  ...]

# %%
# val 简介
dataloaders['val'].dataset
# Out:
# Dataset ImageFolder
#     Number of datapoints: 15
#     Root location: normalViral/val/
#     StandardTransform
# Transform: Compose(
#                Resize(size=300, interpolation=bilinear, max_size=None, antialias=None)
#                CenterCrop(size=(256, 256))
#                ToTensor()
#                Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
#            )

# %%
# test 简介
dataloaders['test'].dataset
# Out:
# Dataset ImageFolder
#     Number of datapoints: 382
#     Root location: normalViral/test/
#     StandardTransform
# Transform: Compose(
#                Resize(size=300, interpolation=bilinear, max_size=None, antialias=None)
#                CenterCrop(size=(256, 256))
#                ToTensor()
#                Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
#            )

# %% [markdown]
# ### 提示：需要安装库：tb-nightly
# ### pip3 install tb-nightly

# %%
# 导入SummaryWriter
from torch.utils.tensorboard import SummaryWriter
# SummaryWriter() 向事件文件写入事件和概要

# 定义日志路径
log_path = 'logdir2/'

# 定义函数：获取tensorboard writer
def tb_writer():
    timestr = time.strftime("%Y%m%d_%H%M%S") # 时间格式
    writer = SummaryWriter(log_path+timestr) # 写入日志
    return writer


writer = tb_writer()

# 第1种方法：显示部分图片集
images, labels = next(iter(dataloaders['train'])) # 获取到一批数据

# 定义图片显示方法
def imshow(img):
    img = img / 2 + 0.5 # 逆正则化
    np_img = img.numpy() # tensor --> numpy
    plt.imshow(np.transpose(np_img, (1, 2, 0))) # 改变通道顺序
    plt.show()
    
grid = utils.make_grid(images) # make_grid的作用是将若干幅图像拼成一幅图像
imshow(grid) # 展示图片

# 在summary中添加图片数据
writer.add_image('X-Ray grid', grid, 0) # add_image(tag, img_tensor, global_step=None, walltime=None, dataformats='CHW')

writer.flush() # 把事件文件写入到磁盘
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
# 获取一张图片tensor
dataloaders['train'].dataset[4] # 返回：tensor, label
# Out:
# (tensor([[[-1.9467, -1.9638, -1.9467,  ..., -1.6213, -1.5699, -1.5014],
#           [-1.8610, -1.8268, -1.8097,  ..., -1.5528, -1.5357, -1.4329],
#           [-1.8097, -1.7412, -1.7069,  ..., -1.5014, -1.4672, -1.4158],
#           ...,
#           [ 0.9988,  0.9988,  0.7933,  ..., -0.4911, -0.5424, -0.2513],
#           [ 1.0844,  0.9817,  0.7077,  ..., -0.6452, -0.7822, -0.1828],
#           [ 1.1015,  0.9817,  0.7933,  ..., -0.6794, -1.0219, -0.5596]],
#
#          [[-1.8606, -1.8782, -1.8606,  ..., -1.5280, -1.4755, -1.4055],
#           [-1.7731, -1.7381, -1.7206,  ..., -1.4580, -1.4405, -1.3354],
#           [-1.7206, -1.6506, -1.6155,  ..., -1.4055, -1.3704, -1.3179],
#           ...,
#           [ 1.1506,  1.1506,  0.9405,  ..., -0.3725, -0.4251, -0.1275],
#           [ 1.2381,  1.1331,  0.8529,  ..., -0.5301, -0.6702, -0.0574],
#           [ 1.2556,  1.1331,  0.9405,  ..., -0.5651, -0.9153, -0.4426]],
#
#          [[-1.6302, -1.6476, -1.6302,  ..., -1.2990, -1.2467, -1.1770],
#           [-1.5430, -1.5081, -1.4907,  ..., -1.2293, -1.2119, -1.1073],
#           [-1.4907, -1.4210, -1.3861,  ..., -1.1770, -1.1421, -1.0898],
#           ...,
#           [ 1.3677,  1.3677,  1.1585,  ..., -0.1487, -0.2010,  0.0953],
#           [ 1.4548,  1.3502,  1.0714,  ..., -0.3055, -0.4450,  0.1651],
#           [ 1.4722,  1.3502,  1.1585,  ..., -0.3404, -0.6890, -0.2184]]]),
#  0)

# %%
# 第2种方法：显示一张图片
def show_sample(img, label):
    print("Label : ", dataloaders['train'].dataset.classes[label]) # 输出标签
    img = img.numpy().transpose((1, 2, 0)) # 改变shape顺序
    mean = np.array([0.485, 0.456, 0.406]) # 均值
    std = np.array([0.229, 0.224, 0.225]) # 标准差
    img = img * std + mean # 逆向复原
    img = np.clip(img, 0, 1) # np.clip() 将inp中的元素值限制在(0,1)之间，最小值为0，最大值为1。小于min的等于min，大于max等于max
    plt.imshow(img)
    plt.axis('off') # 关闭坐标轴

show_sample(*dataloaders['train'].dataset[4]) # 显示第5张图片
# Out:
# Label :  Normal

# %%
# 第3种方法：显示一张图片
def show_image(img):
    plt.figure(figsize=(8,8)) # 显示大小
    plt.imshow(img) # 显示图片
    plt.axis('off') # 关闭坐标轴
    plt.show()
    
# 读取图片
one_img = Image.open(dataloaders['train'].dataset.root+'Normal/Normal (100).jpeg')

# 调用函数
show_image(one_img)

# %%
# 记录错误分类的图片
def misclassified_images(pred, writer, target, images, output, epoch, count=10):
    misclassified = (pred != target.data) # 判断是否一致
    for index, image_tensor in enumerate(images[misclassified][:count]):
        img_name = 'Epoch:{}-->Predict:{}-->Actual:{}'.format(epoch, LABEL[pred[misclassified].tolist()[index]],
                                                              LABEL[target.data[misclassified].tolist()[index]])
        writer.add_image(img_name, image_tensor, epoch)

# %%
# 自定义池化层

class AdaptiveConcatPool2d(nn.Module):
    def __init__(self, size=None):
        super(AdaptiveConcatPool2d,self).__init__()
        size = size or (1, 1) # kernel大小
        # 自适应算法能够自动帮助我们计算核的大小和每次移动的步长。
        self.avgPooling = nn.AdaptiveAvgPool2d(size) # 自适应平均池化
        self.maxPooling = nn.AdaptiveMaxPool2d(size) # 最大池化
    def forward(self, x):
        # 拼接avg和max
        return torch.cat([self.maxPooling(x), self.avgPooling(x)], dim=1)

# %%
# 迁移学习：获取预训练模型，并替换池化层和全连接层
# def get_model():
#     # 获取欲训练模型 restnet50
#     model = models.resnet50(pretrained=True) 
#     # 冻结模型参数
#     for param in model.parameters():
#         param.requires_grad = False 
#     # 替换最后2层：池化层和全连接层
#     # 池化层
#     model.avgpool = AdaptiveConcatPool2d()
#     # 全连接层
#     model.fc = nn.Sequential(
#         nn.Flatten(), # 拉平
#         nn.BatchNorm1d(4096), # 加速神经网络的收敛过程，提高训练过程中的稳定性
#         nn.Dropout(0.5), # 丢掉部分神经元
#         nn.Linear(4096, 512), # 全连接层
#         nn.ReLU(), # 激活函数
#         nn.BatchNorm1d(512), 
#         nn.Dropout(0.5),
#         nn.Linear(512, 2), # 2个输出
#         nn.LogSoftmax(dim=1) # 损失函数：将input转换成概率分布的形式，输出2个概率
#     )
#     return model
# def get_model():
#     # 使用VGG-16预训练模型
#     model = models.vgg16(pretrained=True)
#     # 冻结模型参数
#     for param in model.parameters():
#         param.requires_grad = False
#     # 替换最后两层
#     model.avgpool = AdaptiveConcatPool2d()
#     model.classifier = nn.Sequential(
#         nn.Dropout(),
#         nn.Linear(2 * 512, 256),
#         nn.ReLU(inplace=True),
#         nn.Dropout(),
#         nn.Linear(256, 4),
#         nn.LogSoftmax(dim=1)
#     )
#     return model

def get_model():
    # 获取欲训练模型 restnet50
    model = models.resnet101(pretrained=True) 
    # 冻结模型参数
    for param in model.parameters():
        param.requires_grad = False 
    # 替换最后2层：池化层和全连接层
    # 池化层
    model.avgpool = AdaptiveConcatPool2d()
    # 全连接层
    model.fc = nn.Sequential(
        nn.Flatten(), # 拉平
        nn.BatchNorm1d(4096), # 加速神经网络的收敛过程，提高训练过程中的稳定性
        nn.Dropout(0.5), # 丢掉部分神经元
        nn.Linear(4096, 512), # 全连接层
        nn.ReLU(), # 激活函数
        nn.BatchNorm1d(512), 
        nn.Dropout(0.5),
        nn.Linear(512, 2), # 2个输出
        nn.LogSoftmax(dim=1) # 损失函数：将input转换成概率分布的形式，输出2个概率
    )
    return model

# %%
# 定义训练函数
def train_val(model, device, train_loader, val_loader, optimizer, criterion, epoch, writer):
    model.train()
    total_loss = 0.0
    val_loss = 0.0
    val_acc = 0
    for batch_id, (images, labels) in enumerate(train_loader):
        # 部署到device上
        images, labels = images.to(device), labels.to(device)
        # 梯度置0
        optimizer.zero_grad()
        # 模型输出
        outputs = model(images)
        # 计算损失
        loss = criterion(outputs, labels)
        # 反向传播
        loss.backward()
        # 更新参数
        optimizer.step()
        # 累计损失
        total_loss += loss.item() * images.size(0)
    # 平均训练损失
    train_loss = total_loss / len(train_loader.dataset)
    #写入到writer中
    writer.add_scalar('Training Loss', train_loss, epoch)
    # 写入到磁盘
    writer.flush()
    
    model.eval() 
    with torch.no_grad():
        for images, labels in val_loader:
            images, labels = images.to(device), labels.to(device)
            outputs = model(images) # 前向传播输出
            loss = criterion(outputs, labels) # 损失
            val_loss += loss.item() * images.size(0) # 累计损失
            _, pred = torch.max(outputs, dim=1) # 获取最大概率的索引
            correct = pred.eq(labels.view_as(pred)) # 返回：tensor([ True,False,True,...,False])
            accuracy = torch.mean(correct.type(torch.FloatTensor)) # 准确率
            val_acc += accuracy.item() * images.size(0) # 累计准确率
        # 平均验证损失
        val_loss = val_loss / len(val_loader.dataset)
        # 平均准确率
        val_acc = val_acc / len(val_loader.dataset)
        
    return train_loss, val_loss, val_acc

# %%
# 定义测试函数
def test(model, device, test_loader, criterion, epoch, writer):
    model.eval()
    total_loss = 0.0
    correct = 0.0 # 正确数
    with torch.no_grad():
        for batch_id, (images, labels) in enumerate(test_loader):
            images, labels = images.to(device), labels.to(device)
            # 输出
            outputs = model(images)
            # 损失
            loss = criterion(outputs, labels)
            # 累计损失
            total_loss += loss.item()
            # 获取预测概率最大值的索引
            _, predicted = torch.max(outputs, dim=1)
            # 累计正确预测的数
            correct += predicted.eq(labels.view_as(predicted)).sum().item()
            # 错误分类的图片
            misclassified_images(predicted, writer, labels, images, outputs, epoch)
        # 平均损失
        avg_loss = total_loss / len(test_loader.dataset)
        # 计算正确率
        accuracy = 100 * correct / len(test_loader.dataset)
        # 将test的结果写入write
        writer.add_scalar("Test Loss", total_loss, epoch)
        writer.add_scalar("Accuracy", accuracy, epoch)
        writer.flush()
        return total_loss, accuracy

# %%
# 定义训练流程

# 是否有GPU
device = torch.device('cuda:4' if torch.cuda.is_available() else 'cpu')

print(device.type)

# 模型部署到device
model = get_model().to(device)

# 损失函数
criterion = nn.NLLLoss()

# 优化器
optimizer = optim.SGD(model.parameters(), lr=0.001)

# 定义训练流程函数
def train_epochs(model, device, dataloaders, criterion, optimizer, epochs, writer):
    # 输出信息
    print("{0:>15} | {1:>15} | {2:>15} | {3:>15} | {4:>15} | {5:>15}".format('Epoch', 'Train Loss', 'val_loss', 'val_acc', 'Test Loss', 'Test_acc'))
    # 初始最小的损失
    best_loss = np.inf
    # 开始训练、测试
    for epoch in range(epochs):
        # 训练，return: loss
        train_loss, val_loss, val_acc = train_val(model, device, dataloaders['train'], dataloaders['val'], optimizer, criterion, epoch, writer)
        # 测试，return: loss + accuracy
        test_loss, test_acc = test(model, device, dataloaders['test'], criterion, epoch, writer)
        # 判断损失是否最小
        if test_loss < best_loss:
            best_loss = test_loss # 保存最小损失
            # 保存模型
            torch.save(model.state_dict(), 'model3.pth')
        # 输出结果
        print("{0:>15} | {1:>15} | {2:>15} | {3:>15} | {4:>15} | {5:>15}".format(epoch, train_loss, val_loss, val_acc, test_loss, test_acc))
        writer.flush()
# Out:
# cuda
# /home/huang/anaconda3/envs/pt1.12/lib/python3.7/site-packages/torchvision/models/_utils.py:209: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and will be removed in 0.15, please use 'weights' instead.
#   f"The parameter '{pretrained_param}' is deprecated since 0.13 and will be removed in 0.15, "
# /home/huang/anaconda3/envs/pt1.12/lib/python3.7/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and will be removed in 0.15. The current behavior is equivalent to passing `weights=ResNet101_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet101_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)

# %%
# 调用函数
epochs=40
train_epochs(model, device, dataloaders, criterion, optimizer, epochs, writer)
writer.close()
# Out:
#           Epoch |      Train Loss |        val_loss |         val_acc |       Test Loss |        Test_acc
#               0 | 0.6363521181495073 | 0.7146624326705933 | 0.6000000238418579 | 2.063304901123047 | 55.23560209424084
#               1 | 0.47393896978381356 | 0.5968669652938843 | 0.7333333492279053 | 1.324274331331253 | 82.19895287958116
#               2 | 0.40697967155799925 | 0.546657383441925 | 0.7333333492279053 | 1.3397979140281677 | 82.19895287958116
#               3 | 0.37875844104441053 | 0.5408395528793335 | 0.7333333492279053 | 1.361337572336197 | 81.93717277486911
#               4 | 0.347854572539341 | 0.5374906659126282 | 0.7333333492279053 | 1.3395648300647736 | 82.46073298429319
#               5 | 0.3310115493816094 | 0.5585723519325256 | 0.7333333492279053 | 1.460990309715271 | 80.36649214659685
#               6 | 0.31169872159659623 | 0.500167191028595 | 0.7333333492279053 | 1.4025065302848816 | 81.93717277486911
#               7 | 0.30971979908495784 | 0.495265930891037 | 0.7333333492279053 | 1.454722285270691 | 81.67539267015707
#               8 | 0.30231667268534324 | 0.4997769892215729 | 0.7333333492279053 | 1.464691936969757 | 81.15183246073299
#               9 | 0.29713757269460866 | 0.4983612298965454 | 0.7333333492279053 | 1.461726814508438 | 82.46073298429319
#              10 | 0.29355622080678256 | 0.5005147457122803 | 0.7333333492279053 | 1.5335533618927002 | 81.41361256544502
#              11 | 0.2934397683013604 | 0.4736963212490082 | 0.7333333492279053 | 1.4976971745491028 | 81.93717277486911
#              12 | 0.28770688561888436 | 0.4849933087825775 | 0.7333333492279053 | 1.5441323220729828 | 81.93717277486911
#              13 | 0.2793168173614462 | 0.47766903042793274 | 0.7333333492279053 | 1.5871115624904633 | 80.89005235602095
#              14 | 0.2697860117425131 | 0.44843876361846924 | 0.7333333492279053 | 1.5649085342884064 | 81.15183246073299
#              15 | 0.2757503913609429 | 0.4428237974643707 | 0.7333333492279053 | 1.547847330570221 | 81.41361256544502
#              16 | 0.27234440844060903 | 0.4305889904499054 | 0.7333333492279053 | 1.521932601928711 | 82.46073298429319
#              17 | 0.2754651084028441 | 0.4636100232601166 | 0.7333333492279053 | 1.6084533333778381 | 81.15183246073299
#              18 | 0.27371917819393665 | 0.45472732186317444 | 0.7333333492279053 | 1.561467558145523 | 81.93717277486911
#              19 | 0.263542358803099 | 0.465401291847229 | 0.7333333492279053 | 1.6386495232582092 | 80.6282722513089
#              20 | 0.26253404742541464 | 0.431939959526062 | 0.7333333492279053 | 1.5754438042640686 | 81.67539267015707
#              21 | 0.26270423335080734 | 0.4316032826900482 | 0.7333333492279053 | 1.6299488246440887 | 80.89005235602095
#              22 | 0.258835281370732 | 0.43721574544906616 | 0.7333333492279053 | 1.6469158828258514 | 81.15183246073299
#              23 | 0.263972568234732 | 0.4574759900569916 | 0.7333333492279053 | 1.6666488647460938 | 80.6282722513089
#              24 | 0.2496152799800576 | 0.42140498757362366 | 0.7333333492279053 | 1.644009679555893 | 80.89005235602095
#              25 | 0.2499332353556357 | 0.4156184494495392 | 0.7333333492279053 | 1.6752019822597504 | 80.36649214659685
#              26 | 0.25458766561846974 | 0.42245015501976013 | 0.7333333492279053 | 1.6443873047828674 | 81.41361256544502
#              27 | 0.24570645114710166 | 0.40187615156173706 | 0.7333333492279053 | 1.6593204736709595 | 80.89005235602095
#              28 | 0.2505910289985424 | 0.4129628837108612 | 0.7333333492279053 | 1.6351971626281738 | 80.89005235602095
#              29 | 0.24915375106317478 | 0.4356783926486969 | 0.7333333492279053 | 1.730238139629364 | 80.89005235602095
#              30 | 0.23898529899579196 | 0.3801652193069458 | 0.7333333492279053 | 1.616001456975937 | 81.15183246073299
#              31 | 0.2392015726258493 | 0.3879808783531189 | 0.7333333492279053 | 1.638538122177124 | 80.89005235602095
#              32 | 0.24627951732519252 | 0.4088011384010315 | 0.7333333492279053 | 1.731656551361084 | 81.41361256544502
#              33 | 0.23056226878904207 | 0.3955346941947937 | 0.7333333492279053 | 1.7032976746559143 | 80.89005235602095
#              34 | 0.23808688843546624 | 0.38964155316352844 | 0.7333333492279053 | 1.6735438704490662 | 81.15183246073299
#              35 | 0.2309874447040206 | 0.4006041884422302 | 0.7333333492279053 | 1.7075108885765076 | 80.89005235602095
#              36 | 0.23270529134089982 | 0.3957122564315796 | 0.7333333492279053 | 1.680781364440918 | 81.15183246073299
#              37 | 0.24385949521420378 | 0.35954704880714417 | 0.800000011920929 | 1.5769427716732025 | 82.46073298429319
#              38 | 0.24467344099555668 | 0.3704198896884918 | 0.7333333492279053 | 1.652193546295166 | 81.93717277486911
#              39 | 0.24022534481266927 | 0.3890823721885681 | 0.7333333492279053 | 1.7392478585243225 | 81.41361256544502

# %%
# import cv2


# # 定义 Grad-CAM 类
# class GradCAM:
#     def __init__(self, model, target_layer):
#         self.model = model
#         self.target_layer = target_layer
#         self.feature_maps = None
#         self.gradient = None

#     def save_gradient(self, gradient):
#         self.gradient = gradient
        
#     def __call__(self, input):
#         # 调整维度
#         input = input.squeeze(0)
#         input = torch.transpose(input, 0, 1)

#         # 前向传播，记录目标层的特征图
#         for name, module in self.model.named_modules():
#             input = module(input)
#             if name == self.target_layer:
#                 input.register_hook(self.save_gradient)
#                 self.feature_maps = input.detach()
#         output = input

#         # 反向传播，计算梯度
#         output.backward(torch.ones_like(output))
#         # 计算梯度加权特征图
#         gradients = self.gradient.detach().cpu().numpy()[0]
#         weights = np.mean(gradients, axis=(1, 2), keepdims=True)
#         cam = np.sum(weights * self.feature_maps.cpu().numpy()[0], axis=0)
#         cam = np.maximum(cam, 0)  # ReLU
#         cam = cv2.resize(cam, input.shape[1:])  # 调整特征图尺寸
#         cam = cam - np.min(cam)  # 线性规范化
#         cam = cam / np.max(cam)

#         return cam


#     def __call__(self, x):
#         # 前向传播，记录目标层的特征图
#         for name, module in self.model.named_modules():
#             x = module(x)
#             if name == self.target_layer:
#                 x.register_hook(self.save_gradient)
#                 self.feature_maps = x.detach()
#         output = x
#         # 反向传播，计算梯度
#         output.backward(torch.ones_like(output))
#         # 计算梯度加权特征图
#         gradients = self.gradient.detach().cpu().numpy()[0]
#         weights = np.mean(gradients, axis=(1, 2), keepdims=True)
#         cam = np.sum(weights * self.feature_maps.cpu().numpy()[0], axis=0)
#         cam = np.maximum(cam, 0)  # ReLU
#         cam = cv2.resize(cam, x.shape[2:])  # 调整特征图尺寸
#         cam = cam - np.min(cam)  # 线性规范化
#         cam = cam / np.max(cam)
#         return cam

# 获取模型
# model = get_model()
# # 加载预训练权重
# model.load_state_dict(torch.load('model2.pth', map_location=torch.device('cpu')))
# # 设置为评估模式
# model.eval()
# # 定义 Grad-CAM 对象
# grad_cam = GradCAM(model, 'layer4') # 这里选择 ResNet50 的 layer4 层作为目标层

# # 加载目标图像并预处理
# image = cv2.imread('newDataset_binary/train/BacterialPneumonia/101.jpeg')
# image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
# image = cv2.resize(image, (224, 224))
# image = image / 255.
# image = (image - [0.485, 0.456, 0.406]) / [0.229, 0.224, 0.225]
# image = np.transpose(image, (2, 0, 1))
# image = np.expand_dims(image, axis=0)
# image = torch.from_numpy(image).float()

# # 使用 Grad-CAM 进行可视化
# with torch.set_grad_enabled(True):
#     output = model(image)
#     _, pred = output.max(dim=1)
#     cam = grad_cam(image)
#     cam = cv2.resize(cam, (224, 224))
#     heatmap = cv2.applyColorMap(np.uint8(255*cam), cv2.COLORMAP_JET)
#     heatmap = np.float32(heatmap) / 255
#     cam_on_image = heatmap + np.float32(cv2.cvtColor(np.uint8(255*image[0].permute(1,2,0).cpu().numpy()), cv2.COLOR_BGR2RGB))
#     cam_on_image = cam_on_image / np.max(cam_on_image)

# # 显示结果
# import matplotlib.pyplot as plt
# plt.imshow(cam_on_image)
# plt.axis('off')
# plt.show()

# %%
# import cv2
# import numpy as np
# import torch
# from torchvision import models, transforms
# from torch.nn import functional as F
# from matplotlib import pyplot as plt

# # 定义Grad-CAM可视化函数
# class GradCam:
#     def __init__(self, model, target_layer_names):
#         self.model = model
#         self.target_layer_names = target_layer_names
#         self.feature_maps = []
#         self.gradient_maps = []
#         self.model.eval()
#         self.handlers = []
#         for name in self.target_layer_names:
#             self.handlers.append(
#                 self.register_hook(self.model._modules.get(name))
#             )

#     def register_hook(self, module):
#         def hook(module, input, output):
#             self.feature_maps.append(output.cpu().data.numpy())

#         return module.register_forward_hook(hook)

#     def remove_handlers(self):
#         for handle in self.handlers:
#             handle.remove()

#     def __call__(self, x):
#         self.feature_maps = []
#         self.gradient_maps = []
#         self.handlers = []
#         for name in self.target_layer_names:
#             self.handlers.append(
#                 self.register_hook(self.model._modules.get(name))
#             )

#         outputs = self.model(x)
#         one_hot = outputs.detach().zero_()
#         one_hot[0][torch.argmax(outputs)] = 1
#         one_hot.requires_grad = True
#         one_hot = torch.sum(one_hot * outputs)

#         self.model.zero_grad()
#         one_hot.backward(retain_graph=True)

#         self.gradient_maps = []
#         for i, name in enumerate(self.target_layer_names):
#             gradient_map = (
#                 self.feature_maps[i][0] * self.gradient_maps[-1]
#                 if len(self.gradient_maps) > 0
#                 else self.feature_maps[i][0]
#             )
#             self.gradient_maps.append(gradient_map)

#         self.remove_handlers()
#         return self.gradient_maps[-1]

# # 定义输入图像预处理函数
# def preprocess_image(img_path):
#     img = cv2.imread(img_path)
#     img = cv2.resize(img, (224, 224))
#     img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
#     img_tensor = transforms.ToTensor()(img)
#     img_tensor = transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])(img_tensor)
#     img_tensor = img_tensor.unsqueeze(0)
#     return img_tensor

# # 加载模型
# model = get_model()
# # 加载图像
# img_tensor = preprocess_image('newDataset_binary/train/BacterialPneumonia/101.jpeg')
# # 运行Grad-CAM可视化
# torch.autograd.set_detect_anomaly(True)
# cam = GradCam(model, ['layer4'])
# grad_cam = cam(img_tensor)
# # 将可视化结果转换为热力图
# grad_cam = np.mean(grad_cam, axis=(1, 2), keepdims=True)
# grad_cam = np.maximum(grad_cam, 0)
# grad_cam = grad_cam / grad_cam.max()
# # 将热力图叠加到原始图像上
# img = cv2.imread(dataloaders['train'].dataset.root+'BacterialPneumonia/101.jpeg')
# grad_cam = cv2.resize(grad_cam[0], (img.shape[1], img.shape[0]))
# grad_cam = cv2.applyColorMap(np.uint8(255 * grad_cam), cv2.COLORMAP_JET)
# output_image = cv2.addWeighted(img, 0.8, grad_cam, 0.4, 0)
# # 显示结果
# plt.imshow(output_image[...,::-1])
# plt.axis('off')
# plt

# %%
def plot_confusion(cm):
    plt.figure()
    plot_confusion_matrix(cm, figsize=(12, 8), cmap=plt.cm.Blues) # 参数设置
    plt.xticks(range(2), ['Normal', 'Viral'], fontsize=14)
    plt.yticks(range(2), ['Normal', 'Viral'], fontsize=14)
    plt.xlabel('Predicted Label', fontsize=16)
    plt.ylabel('True Label', fontsize=16)
    plt.show()

# %%
# def accuracy(outputs, labels):
#     # 计算正确率
#     _, preds = torch.max(outputs, dim=1)
#     correct = torch.tensor(torch.sum(preds == labels).item() / len(preds))
#     return correct

# %%
# def metrics(outputs, labels):
#     _, preds = torch.max(outputs, dim=1)
#     # precision, recall, F1
#     # 混淆矩阵
#     cm = confusion_matrix(labels.cpu().numpy(), preds.cpu().numpy())
#     # 绘制混淆矩阵
#     plot_confusion(cm) 
#     # 获取tn, fp, fn, tp
# #     tn, fp, fn, tp = cm.ravel()
#     fp = cm.sum(axis=0) - np.diag(cm)
#     fn = cm.sum(axis=1) - np.diag(cm)
#     tp = np.diag(cm)
#     tn = cm.sum() - (fp + fn + tp)
#     print(tn)
#     print(fp)
#     # 精准率
#     precision = tp / (tp + fp)
#     # 召回率
#     recall = tp / (tp + fn)
#     # f1 score
#     f1 = 2 * ((precision * recall) / (precision + recall))
#     return precision, recall, f1

# %%
all_preds = []
all_labels = []

with torch.no_grad():
    model.eval()
    for datas, labels in dataloaders['test']:
        datas, labels = datas.to(device), labels.to(device)
        # 预测输出 前向传播
        outputs = model(datas)
        _, preds = torch.max(outputs, dim=1)
#     将预测结果和真实标签添加到列表中
        all_preds.extend(preds.cpu().numpy())
        all_labels.extend(labels.cpu().numpy())
        # precision, recall, F1
        # 混淆矩阵
    cm = confusion_matrix(all_labels, all_preds)
    # 绘制混淆矩阵
    plot_confusion(cm) 
#     fp = cm.sum(axis=0) - np.diag(cm)
#     fn = cm.sum(axis=1) - np.diag(cm)
#     tp = np.diag(cm)
#     tn = cm.sum() - (fp + fn + tp)
    tn, fp, fn, tp = cm.ravel()
    # 精准率
    precision = tp / (tp + fp)
    # 召回率
    recall = tp / (tp + fn)
    # f1 score
    f1 = 2 * ((precision * recall) / (precision + recall))
    num_correct = 0
    num_total = len(all_labels)
    for pred, label in zip(all_preds, all_labels):
        if pred == label:
            num_correct += 1
            acc = num_correct / num_total
#     acc = torch.tensor(torch.sum(all_preds == all_labels.data).item() / len(all_preds))
    print(precision)
    print(recall)
    print(f1)
    print(acc)

# with torch.no_grad():
#     model.eval()
#     for datas, labels in dataloaders['val']:
#         datas, labels = datas.to(device), labels.to(device)
#         # 预测输出
#         outputs = model(datas)
#         # 计算metrics
#         precision, recall, f1 = metrics(outputs, labels)
#         acc = accuracy(outputs, labels)
#         # 保存结果
#         precisions.append(precision)
#         recalls.append(recall)
#         f1s.append(f1)
#         accuracies.append(acc.item())
#         print(precisions)
#         print(recalls)
# Out:
# 0.6807511737089202
# 0.9797297297297297
# 0.8033240997229918
# 0.8141361256544503

# %%
# ['{:.2f}%'.format(pre*100) for pre in precisions]# 精准率 precision

# %%
# ['{:.2f}%'.format(r*100) for r in recalls]# 召回率 recall

# %%
# ['{:.2f}%'.format(f*100) for f in f1s]# f1

# %%
# ['{:.2f}%'.format(a*100) for a in accuracies]# 准确率 accuracy
